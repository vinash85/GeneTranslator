# %% [markdown]
# # prepare Y data, and split into training and test sets

# %%
import pandas as pd
df_omic = pd.read_csv('/mnt/data/macaulay/datas/OmicExpression_embeddings.csv')
df_omic
# Out:
#        Cell_line         0         1         2         3         4         5  \
# 0     ACH-001289  0.000364  0.000712  0.000426 -0.000169  0.000310 -0.004777
# 1     ACH-001538  0.000003  0.000009 -0.000139  0.000040 -0.000273  0.000309
# 2     ACH-000233 -0.000001  0.000017 -0.000145  0.000040 -0.000268  0.000300
# 3     ACH-000461 -0.000003  0.000013 -0.000141  0.000035 -0.000269  0.000302
# 4     ACH-001794 -0.000008  0.000018 -0.000138  0.000037 -0.000269  0.000305
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128 -0.000161  0.000083  0.000215  0.000011  0.000161  0.000663
# 997   ACH-002669 -0.000167  0.000080  0.000215  0.000015  0.000158  0.000668
# 998   ACH-001858 -0.000164  0.000083  0.000214  0.000011  0.000156  0.000669
# 999   ACH-001997 -0.000166  0.000082  0.000214  0.000013  0.000159  0.000664
# 1000  ACH-000052 -0.000167  0.000083  0.000214  0.000014  0.000157  0.000664
#
# ...

# %%
import pandas as pd
df_crispr = pd.read_csv('/mnt/data/macaulay/datas/processed_CRISPRGeneEffect.csv')
df_crispr
# Out:
#        Cell_line    TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH  \
# 0     ACH-001289  0.137300  0.006342 -0.015745 -0.125717 -0.261121 -0.161989
# 1     ACH-001538  0.046140  0.061051 -0.163273 -0.214942 -0.013712 -0.082683
# 2     ACH-000233  0.100397  0.115036 -0.171173 -0.046492  0.051241 -0.038589
# 3     ACH-000461 -0.021387  0.176118 -0.266618 -0.066337  0.200848 -0.305074
# 4     ACH-001794  0.163785  0.056389 -0.325990 -0.184216 -0.055608 -0.132250
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128  0.203070  0.136577  0.081536 -0.162938  0.148705 -0.097906
# 997   ACH-002669 -0.005513  0.033543 -0.303284 -0.044312  0.028767  0.007448
# 998   ACH-001858  0.053078  0.046338 -0.378492 -0.164583  0.134620 -0.137761
# 999   ACH-001997  0.161430  0.101912 -0.195104 -0.290554  0.114781 -0.171986
# 1000  ACH-000052 -0.067528  0.170661  0.003581 -0.179196 -0.274973 -0.244126
#
# ...

# %%
df_cellline = df_crispr[['Cell_line']]
df_cellline
# Out:
#        Cell_line
# 0     ACH-001289
# 1     ACH-001538
# 2     ACH-000233
# 3     ACH-000461
# 4     ACH-001794
# ...          ...
# 996   ACH-001128
# 997   ACH-002669
# 998   ACH-001858
# 999   ACH-001997
# 1000  ACH-000052
#
# [1001 rows x 1 columns]

# %%
df_crispr2 = df_crispr.drop(['Cell_line'], axis=1)
df_crispr2
# Out:
#         TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH     FUCA2  \
# 0     0.137300  0.006342 -0.015745 -0.125717 -0.261121 -0.161989  0.130913
# 1     0.046140  0.061051 -0.163273 -0.214942 -0.013712 -0.082683 -0.105280
# 2     0.100397  0.115036 -0.171173 -0.046492  0.051241 -0.038589  0.049083
# 3    -0.021387  0.176118 -0.266618 -0.066337  0.200848 -0.305074 -0.014210
# 4     0.163785  0.056389 -0.325990 -0.184216 -0.055608 -0.132250 -0.044385
# ...        ...       ...       ...       ...       ...       ...       ...
# 996   0.203070  0.136577  0.081536 -0.162938  0.148705 -0.097906 -0.055781
# 997  -0.005513  0.033543 -0.303284 -0.044312  0.028767  0.007448 -0.145405
# 998   0.053078  0.046338 -0.378492 -0.164583  0.134620 -0.137761 -0.055897
# 999   0.161430  0.101912 -0.195104 -0.290554  0.114781 -0.171986 -0.006843
# 1000 -0.067528  0.170661  0.003581 -0.179196 -0.274973 -0.244126  0.194501
#
# ...

# %%
import pandas as pd
import qnorm


# Normalize column-wise (default behavior, axis=1)
df_normalized_columns = qnorm.quantile_normalize(df_crispr2)

# Normalize row-wise (set axis=0)
df_crispr = qnorm.quantile_normalize(df_normalized_columns.T).T

df_crispr
# Out:
#         TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH     FUCA2  \
# 0    -0.058859 -0.262101 -0.040379 -0.139263 -0.431481 -0.252992  0.034324
# 1    -0.168933 -0.159083 -0.114409 -0.262343 -0.141892 -0.168197 -0.329158
# 2    -0.077129 -0.048995 -0.117879 -0.009152 -0.052863 -0.112493 -0.022041
# 3    -0.286888  0.034646 -0.188554 -0.056085  0.065444 -0.434075 -0.159467
# 4     0.033051 -0.162171 -0.229914 -0.221579 -0.197000 -0.238484 -0.213237
# ...        ...       ...       ...       ...       ...       ...       ...
# 996  -0.019649 -0.075004 -0.015638 -0.179056 -0.038350 -0.179331 -0.212135
# 997  -0.273906 -0.223768 -0.216414  0.004244 -0.072176 -0.030312 -0.417935
# 998  -0.152244 -0.193598 -0.291492 -0.195109  0.098697 -0.269140 -0.265434
# 999   0.011716 -0.075651 -0.130847 -0.391453  0.009878 -0.299060 -0.142731
# 1000 -0.318776 -0.015220 -0.037675 -0.197063 -0.404490 -0.328474  0.105014
#
# ...

# %%
df_crispr = pd.concat([df_cellline, df_crispr], axis=1)
df_crispr
# Out:
#        Cell_line    TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH  \
# 0     ACH-001289 -0.058859 -0.262101 -0.040379 -0.139263 -0.431481 -0.252992
# 1     ACH-001538 -0.168933 -0.159083 -0.114409 -0.262343 -0.141892 -0.168197
# 2     ACH-000233 -0.077129 -0.048995 -0.117879 -0.009152 -0.052863 -0.112493
# 3     ACH-000461 -0.286888  0.034646 -0.188554 -0.056085  0.065444 -0.434075
# 4     ACH-001794  0.033051 -0.162171 -0.229914 -0.221579 -0.197000 -0.238484
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128 -0.019649 -0.075004 -0.015638 -0.179056 -0.038350 -0.179331
# 997   ACH-002669 -0.273906 -0.223768 -0.216414  0.004244 -0.072176 -0.030312
# 998   ACH-001858 -0.152244 -0.193598 -0.291492 -0.195109  0.098697 -0.269140
# 999   ACH-001997  0.011716 -0.075651 -0.130847 -0.391453  0.009878 -0.299060
# 1000  ACH-000052 -0.318776 -0.015220 -0.037675 -0.197063 -0.404490 -0.328474
#
# ...

# %%
display(df_omic)
display(df_crispr)
# Out:
#        Cell_line         0         1         2         3         4         5  \
# 0     ACH-001289  0.000364  0.000712  0.000426 -0.000169  0.000310 -0.004777
# 1     ACH-001538  0.000003  0.000009 -0.000139  0.000040 -0.000273  0.000309
# 2     ACH-000233 -0.000001  0.000017 -0.000145  0.000040 -0.000268  0.000300
# 3     ACH-000461 -0.000003  0.000013 -0.000141  0.000035 -0.000269  0.000302
# 4     ACH-001794 -0.000008  0.000018 -0.000138  0.000037 -0.000269  0.000305
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128 -0.000161  0.000083  0.000215  0.000011  0.000161  0.000663
# 997   ACH-002669 -0.000167  0.000080  0.000215  0.000015  0.000158  0.000668
# 998   ACH-001858 -0.000164  0.000083  0.000214  0.000011  0.000156  0.000669
# 999   ACH-001997 -0.000166  0.000082  0.000214  0.000013  0.000159  0.000664
# 1000  ACH-000052 -0.000167  0.000083  0.000214  0.000014  0.000157  0.000664
#
# ...

# %%
df_gene_embedding = pd.read_csv('/mnt/data/macaulay/datas/processed_gene_embeddings.csv')
df_gene_embedding
# Out:
#             Gene         0         1         2         3         4         5  \
# 0         TSPAN6  0.007388 -0.041370  0.096356 -0.013784  0.135280  0.096368
# 1           TNMD  0.002693 -0.107533  0.110958 -0.021181  0.022778  0.011800
# 2           DPM1 -0.002555  0.036781  0.138810 -0.017648 -0.134064 -0.016296
# 3          SCYL3  0.006960 -0.047992  0.046699 -0.008121 -0.069281 -0.005902
# 4            FGR  0.017676 -0.029940  0.061751 -0.006631 -0.163318  0.000847
# ...          ...       ...       ...       ...       ...       ...       ...
# 17638    TMEM247  0.007376 -0.055579  0.015968  0.000652 -0.090398  0.004820
# 17639  EEF1AKMT4  0.006579  0.054662  0.058391 -0.011576 -0.136212 -0.006775
# 17640       TBCE  0.004036 -0.087206  0.031435 -0.010328  0.106398  0.000606
# 17641     CCDC39  0.006182 -0.038689  0.041625 -0.007740 -0.266323 -0.044024
# 17642     NPBWR1  0.077194 -0.032025  0.066356 -0.011709 -0.088859  0.154841
#
# ...

# %%
test_cell_crispr = df_crispr.iloc[:30]
test_cell_crispr
# Out:
#      Cell_line    TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH  \
# 0   ACH-001289 -0.058859 -0.262101 -0.040379 -0.139263 -0.431481 -0.252992
# 1   ACH-001538 -0.168933 -0.159083 -0.114409 -0.262343 -0.141892 -0.168197
# 2   ACH-000233 -0.077129 -0.048995 -0.117879 -0.009152 -0.052863 -0.112493
# 3   ACH-000461 -0.286888  0.034646 -0.188554 -0.056085  0.065444 -0.434075
# 4   ACH-001794  0.033051 -0.162171 -0.229914 -0.221579 -0.197000 -0.238484
# 5   ACH-002023 -0.141807 -0.292286 -0.085268 -0.069787 -0.279973 -0.157098
# 6   ACH-000528 -0.101304 -0.252664 -0.222704 -0.109381 -0.105597 -0.142182
# 7   ACH-001655 -0.261678 -0.328656 -0.128749 -0.397272 -0.273068 -0.386091
# 8   ACH-000792 -0.305547 -0.123769 -0.564733 -0.208991 -0.182422 -0.310567
# 9   ACH-001098  0.020816 -0.248030 -0.264903 -0.057584 -0.204478 -0.101928
# 10  ACH-000570  0.040993 -0.108460 -0.166625 -0.172575 -0.160954 -0.344650
# ...

# %%
test_gene_crispr = df_crispr.iloc[:30, 101:]
test_gene_crispr
# Out:
#          ZFX     LAMP2    ITGA2B      ASB4      GDE1    REX1BD     CRLF1  \
# 0   0.149915 -0.136516  0.006690 -0.315111 -0.409718 -0.118458 -0.066306
# 1  -0.317777 -0.483539 -0.268709 -0.304017 -0.195438 -0.040239 -0.179931
# 2  -0.283308 -0.295088 -0.246149 -0.115080 -0.117028 -0.178461 -0.184435
# 3  -0.313420  0.004282 -0.611467 -0.190572 -0.305461  0.238675 -0.228804
# 4  -0.147726 -0.147325 -0.091786 -0.243388  0.056478 -0.026945 -0.144270
# 5  -0.230061 -0.177509 -0.154850 -0.441510 -0.134412  0.045218 -0.213192
# 6  -0.007323 -0.101304 -0.368306 -0.279972  0.060166 -0.049163  0.054616
# 7  -0.273068 -0.103061 -0.174104 -0.100358 -0.097942 -0.218001 -0.007855
# 8  -0.240590 -0.122297 -0.024515 -0.246080 -0.135134 -0.194721 -0.429874
# 9  -0.120892 -0.223826 -0.182691 -0.116059 -0.335815  0.051326 -0.104154
# 10 -0.183440  0.036213 -0.313491 -0.151179 -0.229890 -0.103619 -0.061431
# 11 -0.079995 -0.161191 -0.046973 -0.322766  0.076557 -0.154200 -0.196024
# ...

# %%
train_crispr = df_crispr.iloc[30:,101:]
train_crispr
# Out:
#            ZFX     LAMP2    ITGA2B      ASB4      GDE1    REX1BD     CRLF1  \
# 30   -0.124642 -0.333860 -0.077493 -0.316474 -0.138752 -0.161690 -0.124642
# 31   -0.232653 -0.189330 -0.067205 -0.032715 -0.059508 -0.047477 -0.230743
# 32   -0.433349 -0.122040 -0.172825 -0.142924 -0.379317 -0.181969 -0.440498
# 33   -0.042193 -0.148706 -0.245498 -0.128713 -0.213704 -0.130423 -0.267134
# 34   -0.207329 -0.055958 -0.097875 -0.279374 -0.215898 -0.118790 -0.290847
# ...        ...       ...       ...       ...       ...       ...       ...
# 996  -0.241595 -0.306248 -0.155579 -0.255644 -0.335592 -0.282054 -0.099965
# 997  -0.236656 -0.293613 -0.058945 -0.522643 -0.013072 -0.145732 -0.325670
# 998  -0.005472 -0.209391 -0.140124 -0.175877 -0.017168  0.074228 -0.169052
# 999  -0.132310 -0.086287  0.003157 -0.091078 -0.032194  0.168414 -0.071444
# 1000 -0.132434 -0.123153 -0.135913 -0.126697 -0.423718 -0.320220 -0.196206
#
# ...

# %%
train_crispr.to_csv('/mnt/data/macaulay/datas/train_crispr.csv', index=False)

# %%
baseline_train_crispr = train_crispr.iloc[:,:500]
baseline_train_crispr
# Out:
#            ZFX     LAMP2    ITGA2B      ASB4      GDE1    REX1BD     CRLF1  \
# 30   -0.124642 -0.333860 -0.077493 -0.316474 -0.138752 -0.161690 -0.124642
# 31   -0.232653 -0.189330 -0.067205 -0.032715 -0.059508 -0.047477 -0.230743
# 32   -0.433349 -0.122040 -0.172825 -0.142924 -0.379317 -0.181969 -0.440498
# 33   -0.042193 -0.148706 -0.245498 -0.128713 -0.213704 -0.130423 -0.267134
# 34   -0.207329 -0.055958 -0.097875 -0.279374 -0.215898 -0.118790 -0.290847
# ...        ...       ...       ...       ...       ...       ...       ...
# 996  -0.241595 -0.306248 -0.155579 -0.255644 -0.335592 -0.282054 -0.099965
# 997  -0.236656 -0.293613 -0.058945 -0.522643 -0.013072 -0.145732 -0.325670
# 998  -0.005472 -0.209391 -0.140124 -0.175877 -0.017168  0.074228 -0.169052
# 999  -0.132310 -0.086287  0.003157 -0.091078 -0.032194  0.168414 -0.071444
# 1000 -0.132434 -0.123153 -0.135913 -0.126697 -0.423718 -0.320220 -0.196206
#
# ...

# %%
dddtrain_crispr = df_crispr.iloc[30:, :101]
dddtrain_crispr
# Out:
#        Cell_line    TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH  \
# 30    ACH-001864 -0.130182 -0.278739 -0.052335 -0.027524 -0.022010 -0.207140
# 31    ACH-000383 -0.204727 -0.122342 -0.157409 -0.377852  0.016320 -0.087549
# 32    ACH-001547 -0.175858 -0.187733 -0.171150 -0.062220 -0.202842 -0.042713
# 33    ACH-000917 -0.269314  0.032071 -0.206293 -0.124807 -0.031471 -0.146736
# 34    ACH-002471 -0.144880 -0.225691 -0.096903 -0.212283 -0.249217 -0.369843
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128 -0.019649 -0.075004 -0.015638 -0.179056 -0.038350 -0.179331
# 997   ACH-002669 -0.273906 -0.223768 -0.216414  0.004244 -0.072176 -0.030312
# 998   ACH-001858 -0.152244 -0.193598 -0.291492 -0.195109  0.098697 -0.269140
# 999   ACH-001997  0.011716 -0.075651 -0.130847 -0.391453  0.009878 -0.299060
# 1000  ACH-000052 -0.318776 -0.015220 -0.037675 -0.197063 -0.404490 -0.328474
#
# ...

# %%
unseen_crispr = df_crispr.iloc[:30, 1:101]
unseen_crispr
# Out:
#       TSPAN6      TNMD      DPM1     SCYL3       FGR       CFH     FUCA2  \
# 0  -0.058859 -0.262101 -0.040379 -0.139263 -0.431481 -0.252992  0.034324
# 1  -0.168933 -0.159083 -0.114409 -0.262343 -0.141892 -0.168197 -0.329158
# 2  -0.077129 -0.048995 -0.117879 -0.009152 -0.052863 -0.112493 -0.022041
# 3  -0.286888  0.034646 -0.188554 -0.056085  0.065444 -0.434075 -0.159467
# 4   0.033051 -0.162171 -0.229914 -0.221579 -0.197000 -0.238484 -0.213237
# 5  -0.141807 -0.292286 -0.085268 -0.069787 -0.279973 -0.157098 -0.215254
# 6  -0.101304 -0.252664 -0.222704 -0.109381 -0.105597 -0.142182 -0.203330
# 7  -0.261678 -0.328656 -0.128749 -0.397272 -0.273068 -0.386091 -0.167277
# 8  -0.305547 -0.123769 -0.564733 -0.208991 -0.182422 -0.310567 -0.269029
# 9   0.020816 -0.248030 -0.264903 -0.057584 -0.204478 -0.101928 -0.064069
# 10  0.040993 -0.108460 -0.166625 -0.172575 -0.160954 -0.344650 -0.027887
# 11 -0.030552 -0.020462  0.233779  0.137976 -0.127544 -0.152980 -0.163320
# ...

# %%
train_crispr
# Out:
#            ZFX     LAMP2    ITGA2B      ASB4      GDE1    REX1BD     CRLF1  \
# 30   -0.124642 -0.333860 -0.077493 -0.316474 -0.138752 -0.161690 -0.124642
# 31   -0.232653 -0.189330 -0.067205 -0.032715 -0.059508 -0.047477 -0.230743
# 32   -0.433349 -0.122040 -0.172825 -0.142924 -0.379317 -0.181969 -0.440498
# 33   -0.042193 -0.148706 -0.245498 -0.128713 -0.213704 -0.130423 -0.267134
# 34   -0.207329 -0.055958 -0.097875 -0.279374 -0.215898 -0.118790 -0.290847
# ...        ...       ...       ...       ...       ...       ...       ...
# 996  -0.241595 -0.306248 -0.155579 -0.255644 -0.335592 -0.282054 -0.099965
# 997  -0.236656 -0.293613 -0.058945 -0.522643 -0.013072 -0.145732 -0.325670
# 998  -0.005472 -0.209391 -0.140124 -0.175877 -0.017168  0.074228 -0.169052
# 999  -0.132310 -0.086287  0.003157 -0.091078 -0.032194  0.168414 -0.071444
# 1000 -0.132434 -0.123153 -0.135913 -0.126697 -0.423718 -0.320220 -0.196206
#
# ...

# %% [markdown]
# # *flatten the 2D array into 1D*

# %%
import pandas as pd
import numpy as np



# # Convert the DataFrame to a numpy array and then flatten it to a single column
# flattened_array = train_crispr.to_numpy().flatten()

# # Create a new DataFrame with a single column
# train_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

# train_crispr_flatten.to_csv('datas/training_crispr.csv', index=False)

# train_crispr_flatten





column_wise_array = train_crispr.T.values

# Reshape it into a 1D array
flattened_array = column_wise_array.reshape(-1)

# Create a new DataFrame with a single column
train_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

train_crispr_flatten.to_csv('/mnt/data/macaulay/datas/training_crispr.csv', index=False)
train_crispr_flatten
# Out:
#                  Y
# 0        -0.124642
# 1        -0.232653
# 2        -0.433349
# 3        -0.042193
# 4        -0.207329
# ...            ...
# 17034248 -0.278725
# 17034249 -0.025871
# 17034250 -0.250969
# 17034251 -0.107539
# 17034252 -0.423718
#
# [17034253 rows x 1 columns]

# %%
column_wise_array = baseline_train_crispr.T.values

# Reshape it into a 1D array
flattened_array = column_wise_array.reshape(-1)

# Create a new DataFrame with a single column
baseline_train_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

baseline_train_crispr_flatten.to_csv('/mnt/data/macaulay/datas/baseline_training_crispr.csv', index=False)
baseline_train_crispr_flatten
# Out:
#                Y
# 0      -0.124642
# 1      -0.232653
# 2      -0.433349
# 3      -0.042193
# 4      -0.207329
# ...          ...
# 485495 -0.045760
# 485496 -0.333168
# 485497 -0.146450
# 485498 -0.083076
# 485499  0.173399
#
# [485500 rows x 1 columns]

# %%
column_wise_array = test_gene_crispr.T.values

# Reshape it into a 1D array
flattened_array = column_wise_array.reshape(-1)

# Create a new DataFrame with a single column
test_gene_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

test_gene_crispr_flatten.to_csv('/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv', index=False)
test_gene_crispr_flatten
# Out:
#                Y
# 0       0.149915
# 1      -0.317777
# 2      -0.283308
# 3      -0.313420
# 4      -0.147726
# ...          ...
# 526285 -0.156120
# 526286  0.103145
# 526287 -0.100798
# 526288 -0.114969
# 526289  0.059285
#
# [526290 rows x 1 columns]

# %%
dddtrain_crispr = dddtrain_crispr.iloc[:, 1:]
column_wise_array = dddtrain_crispr.T.values
# Reshape it into a 1D array
flattened_array = column_wise_array.reshape(-1)

# Create a new DataFrame with a single column
dddtrain_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

dddtrain_crispr_flatten.to_csv('/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv', index=False)
dddtrain_crispr_flatten
# Out:
#               Y
# 0     -0.130182
# 1     -0.204727
# 2     -0.175858
# 3     -0.269314
# 4     -0.144880
# ...         ...
# 97095 -0.216173
# 97096 -0.135418
# 97097 -0.200129
# 97098 -0.434084
# 97099  0.043358
#
# [97100 rows x 1 columns]

# %%
column_wise_array = unseen_crispr.T.values
# Reshape it into a 1D array
flattened_array = column_wise_array.reshape(-1)

# Create a new DataFrame with a single column
unseen_crispr_flatten = pd.DataFrame(flattened_array, columns=['Y'])

unseen_crispr_flatten.to_csv('/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv', index=False)
unseen_crispr_flatten
# Out:
#              Y
# 0    -0.058859
# 1    -0.168933
# 2    -0.077129
# 3    -0.286888
# 4     0.033051
# ...        ...
# 2995 -0.219690
# 2996 -0.361401
# 2997 -0.082254
# 2998 -0.208468
# 2999 -0.546407
#
# [3000 rows x 1 columns]

# %%
df_omic
# Out:
#        Cell_line         0         1         2         3         4         5  \
# 0     ACH-001289  0.000364  0.000712  0.000426 -0.000169  0.000310 -0.004777
# 1     ACH-001538  0.000003  0.000009 -0.000139  0.000040 -0.000273  0.000309
# 2     ACH-000233 -0.000001  0.000017 -0.000145  0.000040 -0.000268  0.000300
# 3     ACH-000461 -0.000003  0.000013 -0.000141  0.000035 -0.000269  0.000302
# 4     ACH-001794 -0.000008  0.000018 -0.000138  0.000037 -0.000269  0.000305
# ...          ...       ...       ...       ...       ...       ...       ...
# 996   ACH-001128 -0.000161  0.000083  0.000215  0.000011  0.000161  0.000663
# 997   ACH-002669 -0.000167  0.000080  0.000215  0.000015  0.000158  0.000668
# 998   ACH-001858 -0.000164  0.000083  0.000214  0.000011  0.000156  0.000669
# 999   ACH-001997 -0.000166  0.000082  0.000214  0.000013  0.000159  0.000664
# 1000  ACH-000052 -0.000167  0.000083  0.000214  0.000014  0.000157  0.000664
#
# ...

# %%
test_omic = df_omic.iloc[:30, 1:]
test_omic


# test_omic = df_omic.iloc[:]
# test_omic.drop(test_omic.columns[0:1], axis=1, inplace=True)
# test_omic
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.000364  0.000712  0.000426 -0.000169  0.000310 -0.004777  0.000029
# 1   0.000003  0.000009 -0.000139  0.000040 -0.000273  0.000309  0.000109
# 2  -0.000001  0.000017 -0.000145  0.000040 -0.000268  0.000300  0.000110
# 3  -0.000003  0.000013 -0.000141  0.000035 -0.000269  0.000302  0.000113
# 4  -0.000008  0.000018 -0.000138  0.000037 -0.000269  0.000305  0.000115
# 5  -0.000004  0.000017 -0.000137  0.000036 -0.000270  0.000302  0.000113
# 6  -0.000004  0.000014 -0.000141  0.000039 -0.000271  0.000303  0.000114
# 7  -0.000004  0.000009 -0.000139  0.000039 -0.000270  0.000302  0.000112
# 8  -0.000002  0.000011 -0.000141  0.000037 -0.000274  0.000304  0.000115
# 9  -0.000004  0.000014 -0.000140  0.000040 -0.000277  0.000304  0.000118
# 10 -0.000004  0.000012 -0.000142  0.000038 -0.000273  0.000304  0.000114
# 11 -0.000002  0.000017 -0.000143  0.000038 -0.000269  0.000302  0.000114
# ...

# %%
test_omic.to_csv('/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv', index=False)

# %%
train_omic = df_omic.iloc[30:]
train_omic.drop(train_omic.columns[0:1], axis=1, inplace=True)
train_omic
# Out:
# /tmp/ipykernel_781936/1311577660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_omic.drop(train_omic.columns[0:1], axis=1, inplace=True)
#              0         1         2         3         4         5         6  \
# 30    0.000024  0.000033 -0.000010  0.000005  0.000176 -0.000150 -0.000153
# 31    0.000024  0.000033 -0.000011  0.000006  0.000174 -0.000148 -0.000154
# 32   -0.000017 -0.000032  0.000128 -0.000038  0.000098 -0.000182  0.000033
# 33   -0.000016 -0.000033  0.000127 -0.000041  0.000099 -0.000183  0.000032
# 34   -0.000018 -0.000031  0.000129 -0.000042  0.000096 -0.000185  0.000032
# ...        ...       ...       ...       ...       ...       ...       ...
# 996  -0.000161  0.000083  0.000215  0.000011  0.000161  0.000663 -0.000133
# ...

# %%
train_omic.to_csv('/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv', index=False)

# %%
df_gene_embedding
# Out:
#             Gene         0         1         2         3         4         5  \
# 0         TSPAN6  0.007388 -0.041370  0.096356 -0.013784  0.135280  0.096368
# 1           TNMD  0.002693 -0.107533  0.110958 -0.021181  0.022778  0.011800
# 2           DPM1 -0.002555  0.036781  0.138810 -0.017648 -0.134064 -0.016296
# 3          SCYL3  0.006960 -0.047992  0.046699 -0.008121 -0.069281 -0.005902
# 4            FGR  0.017676 -0.029940  0.061751 -0.006631 -0.163318  0.000847
# ...          ...       ...       ...       ...       ...       ...       ...
# 17638    TMEM247  0.007376 -0.055579  0.015968  0.000652 -0.090398  0.004820
# 17639  EEF1AKMT4  0.006579  0.054662  0.058391 -0.011576 -0.136212 -0.006775
# 17640       TBCE  0.004036 -0.087206  0.031435 -0.010328  0.106398  0.000606
# 17641     CCDC39  0.006182 -0.038689  0.041625 -0.007740 -0.266323 -0.044024
# 17642     NPBWR1  0.077194 -0.032025  0.066356 -0.011709 -0.088859  0.154841
#
# ...

# %%
df_gene_embedding1 = df_gene_embedding.iloc[:100]
df_gene_embedding1
# Out:
#       Gene         0         1         2         3         4         5  \
# 0   TSPAN6  0.007388 -0.041370  0.096356 -0.013784  0.135280  0.096368
# 1     TNMD  0.002693 -0.107533  0.110958 -0.021181  0.022778  0.011800
# 2     DPM1 -0.002555  0.036781  0.138810 -0.017648 -0.134064 -0.016296
# 3    SCYL3  0.006960 -0.047992  0.046699 -0.008121 -0.069281 -0.005902
# 4      FGR  0.017676 -0.029940  0.061751 -0.006631 -0.163318  0.000847
# ..     ...       ...       ...       ...       ...       ...       ...
# 95  ZNF195  0.014753 -0.068121  0.051103 -0.002561  0.017289 -0.005984
# 96   FBXL3  0.004705 -0.072247  0.031424 -0.003649  0.054899 -0.005931
# 97   ITGAL  0.005200  0.092978  0.092112 -0.012816 -0.457246  0.033225
# 98    PDK2  0.003095  0.000073  0.044778 -0.021635  0.329619  0.021055
# 99   ITGA3  0.009027 -0.035439  0.073355 -0.015053 -0.470641  0.004162
#
#            6         7         8  ...      1890      1891      1892      1893  \
# ...

# %%
df_gene_embedding1.to_csv('/mnt/data/macaulay/datas/test_gene_embeddings.csv', index=False)

# %%
df_gene_embedding2 = df_gene_embedding.iloc[100:]
df_gene_embedding2
# Out:
#             Gene         0         1         2         3         4         5  \
# 100          ZFX  0.013528 -0.073574  0.050425 -0.007168 -0.083504  0.009434
# 101        LAMP2  0.004373 -0.052026  0.115090 -0.018382 -0.366196  0.019519
# 102       ITGA2B  0.005604 -0.024311  0.063571 -0.014624 -0.464599  0.016603
# 103         ASB4  0.003966 -0.157932  0.034745 -0.003395  0.023854 -0.018922
# 104         GDE1  0.013251  0.258344  0.148767 -0.011984 -0.054923  0.024582
# ...          ...       ...       ...       ...       ...       ...       ...
# 17638    TMEM247  0.007376 -0.055579  0.015968  0.000652 -0.090398  0.004820
# 17639  EEF1AKMT4  0.006579  0.054662  0.058391 -0.011576 -0.136212 -0.006775
# 17640       TBCE  0.004036 -0.087206  0.031435 -0.010328  0.106398  0.000606
# 17641     CCDC39  0.006182 -0.038689  0.041625 -0.007740 -0.266323 -0.044024
# 17642     NPBWR1  0.077194 -0.032025  0.066356 -0.011709 -0.088859  0.154841
#
# ...

# %%
df_gene_embedding2.to_csv('/mnt/data/macaulay/datas/training_gene_embeddings.csv', index=False)
