# %%
import pandas as pd
df = pd.read_csv('/mnt/data/macaulay/datas/vae_expression.txt')
df
# Out:
#      Epoch  Combined Training Loss  Reconstruction Loss    KL Loss  \
# 0        1               1409.9749               1.3591  1408.6158
# 1        2                532.3530               1.3537   530.9993
# 2        3                158.4053               1.3487   157.0566
# 3        4                 62.0444               1.3481    60.6963
# 4        5                 34.6669               1.3495    33.3174
# ..     ...                     ...                  ...        ...
# 995    996                  1.2512               1.2493     0.0019
# 996    997                  1.2513               1.2492     0.0021
# 997    998                  1.2511               1.2491     0.0020
# 998    999                  1.2512               1.2492     0.0020
# 999   1000                  1.2513               1.2491     0.0023
#
#      Correlation
# 0         0.0056
# 1         0.0278
# 2         0.0477
# 3         0.0442
# 4         0.0254
# ..           ...
# 995      -0.0050
# ...

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(5, 5))
plt.plot(df['Epoch'].iloc[28:221], df['Reconstruction Loss'].iloc[28:221], label='Reconstruction Loss', color='green')
# plt.plot(df['Epoch'].iloc[28:221], df['KL Loss'].iloc[28:221], label='KL Loss', color='red')
# plt.plot(df['Epoch'].iloc[28:221], df['Combined Training Loss'].iloc[28:221], label='Combined Training Loss', color='blue')
# plt.plot(df['Epoch'].iloc[28:221], df['Correlation'].iloc[28:221], label='correlation', color='orange')

plt.show()
