# %% [markdown]
# # nn.py

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




# Initialization and Environment Setup
def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                    data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                      data1_test_path_C, data2_test_path_C, df_Y_test_path_C):
    
    data1_test_A = pd.read_csv(data1_test_path_A)
    data2_test_A = pd.read_csv(data2_test_path_A)
    df_Y_test_A = pd.read_csv(df_Y_test_path_A)
    data1_test_B = pd.read_csv(data1_test_path_B)
    data2_test_B = pd.read_csv(data2_test_path_B)
    df_Y_test_B = pd.read_csv(df_Y_test_path_B)
    data1_test_C = pd.read_csv(data1_test_path_C)
    data2_test_C = pd.read_csv(data2_test_path_C)
    df_Y_test_C = pd.read_csv(df_Y_test_path_C)
    print('Test data loaded successfully')
    return data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C



def cartesian_product(data1, data2):
    data1 = data1.iloc[:, 1:]
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        combined_data = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield combined_data, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model

# Evaluation Function
def evaluate_model_on_test_data(model, data1_test, data2_test, df_Y_test, epoch, loss_fn, device, test_batch_size=128):
    model.eval()
    avg_test_losses = []
    mae_values = []
    rmse_values = []
    r2_values = []
    correlation_coefficients = []
    p_values = []
    gene_batches = 1
    for batch_X, batch_Y in cartesian_product_generator(data1_test, data2_test, df_Y_test, gene_batches):
        X_test = torch.tensor(batch_X.values, dtype=torch.float32).to(device)
        Y_test = torch.tensor(batch_Y.values.reshape(-1, 1), dtype=torch.float32).to(device)
        test_data = TensorDataset(X_test, Y_test)
        test_dataloader = DataLoader(test_data, batch_size=test_batch_size, shuffle=True)

        test_loss = 0.0
        actual_outputs = []
        predicted_outputs = []
        with torch.no_grad():
            for inputs, targets in test_dataloader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                outputs = model(inputs)
                loss = loss_fn(outputs, targets)
                test_loss += loss.item()
                actual_outputs.extend(targets.cpu().numpy().flatten().tolist())
                predicted_outputs.extend(outputs.cpu().numpy().flatten().tolist())

        avg_test_loss = test_loss / len(test_dataloader)
        avg_test_losses.append(avg_test_loss)
        correlation_coefficient, p_value = pearsonr(actual_outputs, predicted_outputs)
        correlation_coefficients.append(correlation_coefficient)
        p_values.append(p_value)
        mae = mean_absolute_error(actual_outputs, predicted_outputs)
        rmse = np.sqrt(mean_squared_error(actual_outputs, predicted_outputs))
        r2 = r2_score(actual_outputs, predicted_outputs)
        mae_values.append(mae)
        rmse_values.append(rmse)
        r2_values.append(r2)

    epochs = []
    for minor in range(1, len(data1_test) + 1):
        epoched = f'{epoch}.{minor:02}'  
        epochs.append(float(epoched))

    metrics_df = pd.DataFrame({
        'Epoch': epochs,
        'Correlation_Coefficient': correlation_coefficients,
        'P_Value': p_values,
        'Test_Loss': avg_test_losses,
        'MAE': mae_values,
        'RMSE': rmse_values,
        'R2_Score': r2_values
    })
    return metrics_df

# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)

        
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs
    
    for epoch in range(start_epoch, end_epoch):
        model.train()
        counter = 0
        model = load_model(model, epoch, model_save_path)
        for batch_X, batch_Y in cartesian_product_generator(data1, data2, df_Y, batch_size1):
            X_train = torch.tensor(batch_X.values, dtype=torch.float32).to(device)
            Y_train = torch.tensor(batch_Y.values.reshape(-1, 1), dtype=torch.float32).to(device)
            train_data = TensorDataset(X_train, Y_train)
            train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)

            train_loss = 0.0
            for inputs, targets in train_dataloader:
                inputs, targets = inputs.to(device), targets.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = loss_fn(outputs, targets)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            counter += 1
            print(f"Epoch {epoch}.{counter}: Avg. training loss = {train_loss / len(train_dataloader):.4f}")

        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        
        # Evaluate the model on test data after each epoch

        data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C = load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                                                                                                                                                data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                                                                                                                                                  data1_test_path_C, data2_test_path_C, df_Y_test_path_C)



        metrics_df_A = evaluate_model_on_test_data(model, data1_test_A, data2_test_A, df_Y_test_A, epoch, loss_fn, device, test_batch_size)
        metrics_path_A = os.path.join(model_save_path, f"A_metrics_epoch_{epoch}.csv")
        metrics_df_A.to_csv(metrics_path_A, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_A}')

        metrics_df_B = evaluate_model_on_test_data(model, data1_test_B, data2_test_B, df_Y_test_B, epoch, loss_fn, device, test_batch_size)
        metrics_path_B = os.path.join(model_save_path, f"B_metrics_epoch_{epoch}.csv")
        metrics_df_B.to_csv(metrics_path_B, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_B}')

        metrics_df_C = evaluate_model_on_test_data(model, data1_test_C, data2_test_C, df_Y_test_C, epoch, loss_fn, device, test_batch_size)
        metrics_path_C = os.path.join(model_save_path, f"C_metrics_epoch_{epoch}.csv")
        metrics_df_C.to_csv(metrics_path_C, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_C}')

main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=20,
                   model_save_path='/mnt/data/macaulay/model_state2/',test_batch_size=128)

# %% [markdown]
# ## OPTIMIZATION AND BATCHING

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




# Initialization and Environment Setup
def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                    data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                      data1_test_path_C, data2_test_path_C, df_Y_test_path_C):
    
    data1_test_A = pd.read_csv(data1_test_path_A)
    data2_test_A = pd.read_csv(data2_test_path_A)
    df_Y_test_A = pd.read_csv(df_Y_test_path_A)
    data1_test_B = pd.read_csv(data1_test_path_B)
    data2_test_B = pd.read_csv(data2_test_path_B)
    df_Y_test_B = pd.read_csv(df_Y_test_path_B)
    data1_test_C = pd.read_csv(data1_test_path_C)
    data2_test_C = pd.read_csv(data2_test_path_C)
    df_Y_test_C = pd.read_csv(df_Y_test_path_C)
    print('Test data loaded successfully')
    return data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C



def cartesian_product(data1, data2):
    data1 = data1.iloc[:, 1:]
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        combined_data = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield combined_data, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model

# Evaluation Function
def evaluate_model_on_test_data(model, data1_test, data2_test, df_Y_test, epoch, loss_fn, device, test_batch_size=128):
    model.eval()
    avg_test_losses = []
    mae_values = []
    rmse_values = []
    r2_values = []
    correlation_coefficients = []
    p_values = []
    gene_batches = 1
    for batch_X, batch_Y in cartesian_product_generator(data1_test, data2_test, df_Y_test, gene_batches):
        X_test = torch.tensor(batch_X.values, dtype=torch.float32).to(device)
        Y_test = torch.tensor(batch_Y.values.reshape(-1, 1), dtype=torch.float32).to(device)
        test_data = TensorDataset(X_test, Y_test)
        test_dataloader = DataLoader(test_data, batch_size=test_batch_size, shuffle=True)

        test_loss = 0.0
        actual_outputs = []
        predicted_outputs = []
        with torch.no_grad():
            for inputs, targets in test_dataloader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                outputs = model(inputs)
                loss = loss_fn(outputs, targets)
                test_loss += loss.item()
                actual_outputs.extend(targets.cpu().numpy().flatten().tolist())
                predicted_outputs.extend(outputs.cpu().numpy().flatten().tolist())

        avg_test_loss = test_loss / len(test_dataloader)
        avg_test_losses.append(avg_test_loss)
        correlation_coefficient, p_value = pearsonr(actual_outputs, predicted_outputs)
        correlation_coefficients.append(correlation_coefficient)
        p_values.append(p_value)
        mae = mean_absolute_error(actual_outputs, predicted_outputs)
        rmse = np.sqrt(mean_squared_error(actual_outputs, predicted_outputs))
        r2 = r2_score(actual_outputs, predicted_outputs)
        mae_values.append(mae)
        rmse_values.append(rmse)
        r2_values.append(r2)

    epochs = []
    for minor in range(1, len(data1_test) + 1):
        epoched = f'{epoch}.{minor:02}'  
        epochs.append(float(epoched))

    metrics_df = pd.DataFrame({
        'Epoch': epochs,
        'Correlation_Coefficient': correlation_coefficients,
        'P_Value': p_values,
        'Test_Loss': avg_test_losses,
        'MAE': mae_values,
        'RMSE': rmse_values,
        'R2_Score': r2_values
    })
    return metrics_df

# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)

        
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs
    
    for epoch in range(start_epoch, end_epoch):
        model.train()
        counter = 0
        model = load_model(model, epoch, model_save_path)
        for batch_X, batch_Y in cartesian_product_generator(data1, data2, df_Y, batch_size1):
            X_train = torch.tensor(batch_X.values, dtype=torch.float32).to(device)
            Y_train = torch.tensor(batch_Y.values.reshape(-1, 1), dtype=torch.float32).to(device)
            train_data = TensorDataset(X_train, Y_train)
            train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)

            train_loss = 0.0
            for inputs, targets in train_dataloader:
                inputs, targets = inputs.to(device), targets.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = loss_fn(outputs, targets)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            counter += 1
            print(f"Epoch {epoch}.{counter}: Avg. training loss = {train_loss / len(train_dataloader):.4f}")

        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        
        # Evaluate the model on test data after each epoch

        data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C = load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                                                                                                                                                data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                                                                                                                                                  data1_test_path_C, data2_test_path_C, df_Y_test_path_C)



        metrics_df_A = evaluate_model_on_test_data(model, data1_test_A, data2_test_A, df_Y_test_A, epoch, loss_fn, device, test_batch_size)
        metrics_path_A = os.path.join(model_save_path, f"A_metrics_epoch_{epoch}.csv")
        metrics_df_A.to_csv(metrics_path_A, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_A}')

        metrics_df_B = evaluate_model_on_test_data(model, data1_test_B, data2_test_B, df_Y_test_B, epoch, loss_fn, device, test_batch_size)
        metrics_path_B = os.path.join(model_save_path, f"B_metrics_epoch_{epoch}.csv")
        metrics_df_B.to_csv(metrics_path_B, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_B}')

        metrics_df_C = evaluate_model_on_test_data(model, data1_test_C, data2_test_C, df_Y_test_C, epoch, loss_fn, device, test_batch_size)
        metrics_path_C = os.path.join(model_save_path, f"C_metrics_epoch_{epoch}.csv")
        metrics_df_C.to_csv(metrics_path_C, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_C}')

main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=20,
                   model_save_path='/mnt/data/macaulay/model_state2/',test_batch_size=128)

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




# Initialization and Environment Setup
def initialize_environment(data1_path, data2_path, df_Y_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')

    return device, data1, data2, df_Y



def main_training_loop(data1_path, data2_path, df_Y_path, num_epochs, model_save_path):
    

    data1, data2, df_Y = initialize_environment(data1_path, data2_path, df_Y_path)
    display(data1)
    display(data2)
    display(df_Y)

        
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs



main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   num_epochs=20,
                   model_save_path='/mnt/data/macaulay/model_state2/')
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 60
#      55     start_epoch = last_epoch + 1
#      56     end_epoch = start_epoch + num_epochs
# ---> 60 main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#      61                    data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#      62                    df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
#      63                    num_epochs=20,
#      64                    model_save_path='/mnt/data/macaulay/model_state2/')
#
# Cell In[4], line 46, in main_training_loop(data1_path, data2_path, df_Y_path, num_epochs, model_save_path)
#      43 def main_training_loop(data1_path, data2_path, df_Y_path, num_epochs, model_save_path):
# ---> 46     data1, data2, df_Y = initialize_environment(data1_path, data2_path, df_Y_path)
#      47     display(data1)
#      48     display(data2)
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# ## Training

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs

    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []

        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            model = load_model(model, epoch, model_save_path)
            train_correlations = []
            train_lossess = []
            test_correlations = []
            test_lossess = []
            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                # Shuffle data
                combined = combined.sample(frac=1).reset_index(drop=True)
                # display(shuffled_combined)
                # print('shuffled')
                # time.sleep(1000)

                # Split shuffled data back into X and Y
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.1)
                X_train = X_train.drop(columns=["Gene"])
                X_test = X_test.drop(columns=["Gene"])

                # print(X_train.select_dtypes(include=['object']).head())
                # display(X_test)
                # display(Y_train)
                # display(Y_test)
                # Convert training data to tensor and create dataloader
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations.append(train_correlation)
                    train_lossess.append(loss.item())

                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    test_correlations.append(correlation)
                    test_lossess.append(test_loss.item())
            
            mean_train_correlation = np.mean(train_correlations)
            mean_train_loss = np.mean(train_lossess)
            mean_test_correlation = np.mean(test_correlations)
            mean_test_loss = np.mean(test_lossess)

            epoch_train_correlations.append(mean_train_correlation)
            epoch_train_losses.append(mean_train_loss)
            epoch_test_correlations.append(mean_test_correlation)
            epoch_test_losses.append(mean_test_loss)



            print(f"Epoch {epoch}.{j}: Avg. training loss = {mean_train_loss:.4f}, Training Pearson correlation = {mean_train_correlation:.4f}")
            print(f"Epoch {epoch}.{j}: Test loss = {mean_test_loss:.4f}, Pearson correlation = {mean_test_correlation:.4f}")

        print(f"Epoch {epoch}: Avg. training loss = {np.mean(epoch_train_losses):.4f}, Training Pearson correlation = {np.mean(epoch_train_correlations):.4f}")
        print(f"Epoch {epoch}: Test loss = {np.mean(epoch_test_losses):.4f}, Pearson correlation = {np.mean(epoch_test_correlations):.4f}")

        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=10,
                   model_save_path='/mnt/data/macaulay/datas/genepedia/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# 300
# 300
# No saved model found. Training from scratch.
# 97100
# 1
# Epoch 1.0: Avg. training loss = 0.1570, Training Pearson correlation = 0.3173
# Epoch 1.0: Test loss = 0.0829, Pearson correlation = 0.6449
# No saved model found. Training from scratch.
# 97100
# 1
# Epoch 1.100: Avg. training loss = 0.1385, Training Pearson correlation = 0.2063
# Epoch 1.100: Test loss = 0.1055, Pearson correlation = 0.4553
# No saved model found. Training from scratch.
# 97100
# 1
# Epoch 1.200: Avg. training loss = 0.1419, Training Pearson correlation = 0.0836
# Epoch 1.200: Test loss = 0.1219, Pearson correlation = 0.2599
# Epoch 1: Avg. training loss = 0.1458, Training Pearson correlation = 0.2024
# Epoch 1: Test loss = 0.1034, Pearson correlation = 0.4533
# 300
# Model 1 loaded successfully for epoch 2
# 97100
# 1
# Epoch 2.0: Avg. training loss = 0.0948, Training Pearson correlation = 0.4904
# Epoch 2.0: Test loss = 0.0715, Pearson correlation = 0.6847
# Model 1 loaded successfully for epoch 2
# 97100
# 1
# Epoch 2.100: Avg. training loss = 0.1133, Training Pearson correlation = 0.3487
# Epoch 2.100: Test loss = 0.0977, Pearson correlation = 0.5287
# Model 1 loaded successfully for epoch 2
# 97100
# 1
# Epoch 2.200: Avg. training loss = 0.1281, Training Pearson correlation = 0.2129
# Epoch 2.200: Test loss = 0.1242, Pearson correlation = 0.3665
# Epoch 2: Avg. training loss = 0.1121, Training Pearson correlation = 0.3507
# Epoch 2: Test loss = 0.0978, Pearson correlation = 0.5267
# 300
# Model 2 loaded successfully for epoch 3
# 97100
# 1
# Epoch 3.0: Avg. training loss = 0.0953, Training Pearson correlation = 0.4978
# Epoch 3.0: Test loss = 0.0664, Pearson correlation = 0.6807
# Model 2 loaded successfully for epoch 3
# 97100
# 1
# Epoch 3.100: Avg. training loss = 0.1142, Training Pearson correlation = 0.3482
# Epoch 3.100: Test loss = 0.0950, Pearson correlation = 0.5008
# Model 2 loaded successfully for epoch 3
# 97100
# 1
# Epoch 3.200: Avg. training loss = 0.1207, Training Pearson correlation = 0.3012
# Epoch 3.200: Test loss = 0.1099, Pearson correlation = 0.4299
# Epoch 3: Avg. training loss = 0.1101, Training Pearson correlation = 0.3824
# Epoch 3: Test loss = 0.0904, Pearson correlation = 0.5371
# 300
# Model 3 loaded successfully for epoch 4
# 97100
# 1
# Epoch 4.0: Avg. training loss = 0.0941, Training Pearson correlation = 0.4923
# Epoch 4.0: Test loss = 0.0703, Pearson correlation = 0.6965
# Model 3 loaded successfully for epoch 4
# 97100
# 1
# Epoch 4.100: Avg. training loss = 0.1141, Training Pearson correlation = 0.3419
# Epoch 4.100: Test loss = 0.0989, Pearson correlation = 0.5145
# Model 3 loaded successfully for epoch 4
# 97100
# 1
# Epoch 4.200: Avg. training loss = 0.1113, Training Pearson correlation = 0.3987
# Epoch 4.200: Test loss = 0.0916, Pearson correlation = 0.5294
# Epoch 4: Avg. training loss = 0.1065, Training Pearson correlation = 0.4109
# Epoch 4: Test loss = 0.0869, Pearson correlation = 0.5802
# 300
# Model 4 loaded successfully for epoch 5
# 97100
# 1
# Epoch 5.0: Avg. training loss = 0.0929, Training Pearson correlation = 0.5062
# Epoch 5.0: Test loss = 0.0710, Pearson correlation = 0.6864
# Model 4 loaded successfully for epoch 5
# 97100
# 1
# Epoch 5.100: Avg. training loss = 0.1146, Training Pearson correlation = 0.3426
# Epoch 5.100: Test loss = 0.0958, Pearson correlation = 0.5061
# Model 4 loaded successfully for epoch 5
# 97100
# 1
# Epoch 5.200: Avg. training loss = 0.0992, Training Pearson correlation = 0.4885
# Epoch 5.200: Test loss = 0.0788, Pearson correlation = 0.6348
# Epoch 5: Avg. training loss = 0.1022, Training Pearson correlation = 0.4458
# Epoch 5: Test loss = 0.0818, Pearson correlation = 0.6091
# 300
# Model 5 loaded successfully for epoch 6
# 97100
# 1
# Epoch 6.0: Avg. training loss = 0.0936, Training Pearson correlation = 0.4963
# Epoch 6.0: Test loss = 0.0756, Pearson correlation = 0.6713
# Model 5 loaded successfully for epoch 6
# 97100
# 1
# Epoch 6.100: Avg. training loss = 0.1144, Training Pearson correlation = 0.3514
# Epoch 6.100: Test loss = 0.0961, Pearson correlation = 0.4967
# Model 5 loaded successfully for epoch 6
# 97100
# 1
# Epoch 6.200: Avg. training loss = 0.0855, Training Pearson correlation = 0.5798
# Epoch 6.200: Test loss = 0.0737, Pearson correlation = 0.6756
# Epoch 6: Avg. training loss = 0.0978, Training Pearson correlation = 0.4758
# Epoch 6: Test loss = 0.0818, Pearson correlation = 0.6145
# 300
# Model 6 loaded successfully for epoch 7
# 97100
# 1
# Epoch 7.0: Avg. training loss = 0.0922, Training Pearson correlation = 0.5079
# Epoch 7.0: Test loss = 0.0712, Pearson correlation = 0.6899
# Model 6 loaded successfully for epoch 7
# 97100
# 1
# Epoch 7.100: Avg. training loss = 0.1129, Training Pearson correlation = 0.3553
# Epoch 7.100: Test loss = 0.0986, Pearson correlation = 0.5183
# Model 6 loaded successfully for epoch 7
# 97100
# 1
# Epoch 7.200: Avg. training loss = 0.0729, Training Pearson correlation = 0.6553
# Epoch 7.200: Test loss = 0.0590, Pearson correlation = 0.7536
# Epoch 7: Avg. training loss = 0.0927, Training Pearson correlation = 0.5062
# Epoch 7: Test loss = 0.0763, Pearson correlation = 0.6539
# 300
# Model 7 loaded successfully for epoch 8
# 97100
# 1
# Epoch 8.0: Avg. training loss = 0.0920, Training Pearson correlation = 0.5159
# Epoch 8.0: Test loss = 0.0719, Pearson correlation = 0.6747
# Model 7 loaded successfully for epoch 8
# 97100
# 1
# Epoch 8.100: Avg. training loss = 0.1124, Training Pearson correlation = 0.3671
# Epoch 8.100: Test loss = 0.0964, Pearson correlation = 0.5313
# Model 7 loaded successfully for epoch 8
# 97100
# 1
# Epoch 8.200: Avg. training loss = 0.0637, Training Pearson correlation = 0.7068
# Epoch 8.200: Test loss = 0.0516, Pearson correlation = 0.7807
# Epoch 8: Avg. training loss = 0.0894, Training Pearson correlation = 0.5299
# Epoch 8: Test loss = 0.0733, Pearson correlation = 0.6622
# 300
# Model 8 loaded successfully for epoch 9
# 97100
# 1
# Epoch 9.0: Avg. training loss = 0.0903, Training Pearson correlation = 0.5285
# Epoch 9.0: Test loss = 0.0669, Pearson correlation = 0.7159
# Model 8 loaded successfully for epoch 9
# 97100
# 1
# Epoch 9.100: Avg. training loss = 0.1106, Training Pearson correlation = 0.3709
# Epoch 9.100: Test loss = 0.1016, Pearson correlation = 0.5338
# Model 8 loaded successfully for epoch 9
# 97100
# 1
# Epoch 9.200: Avg. training loss = 0.0581, Training Pearson correlation = 0.7428
# Epoch 9.200: Test loss = 0.0449, Pearson correlation = 0.8050
# Epoch 9: Avg. training loss = 0.0863, Training Pearson correlation = 0.5474
# Epoch 9: Test loss = 0.0711, Pearson correlation = 0.6849
# 300
# Model 9 loaded successfully for epoch 10
# 97100
# 1
# Epoch 10.0: Avg. training loss = 0.0906, Training Pearson correlation = 0.5228
# Epoch 10.0: Test loss = 0.0681, Pearson correlation = 0.7077
# Model 9 loaded successfully for epoch 10
# 97100
# 1
# Epoch 10.100: Avg. training loss = 0.1114, Training Pearson correlation = 0.3703
# Epoch 10.100: Test loss = 0.0953, Pearson correlation = 0.5463
# Model 9 loaded successfully for epoch 10
# 97100
# 1
# Epoch 10.200: Avg. training loss = 0.0541, Training Pearson correlation = 0.7627
# Epoch 10.200: Test loss = 0.0450, Pearson correlation = 0.8188
# Epoch 10: Avg. training loss = 0.0854, Training Pearson correlation = 0.5519
# Epoch 10: Test loss = 0.0695, Pearson correlation = 0.6910
# 300
# Model 10 loaded successfully for epoch 11
# 97100
# 1
# Epoch 11.0: Avg. training loss = 0.0910, Training Pearson correlation = 0.5190
# Epoch 11.0: Test loss = 0.0658, Pearson correlation = 0.7140
# Model 10 loaded successfully for epoch 11
# 97100
# 1
# Epoch 11.100: Avg. training loss = 0.1100, Training Pearson correlation = 0.3877
# Epoch 11.100: Test loss = 0.0976, Pearson correlation = 0.5484
# Model 10 loaded successfully for epoch 11
# 97100
# 1
# Epoch 11.200: Avg. training loss = 0.0509, Training Pearson correlation = 0.7757
# Epoch 11.200: Test loss = 0.0404, Pearson correlation = 0.8423
# Epoch 11: Avg. training loss = 0.0840, Training Pearson correlation = 0.5608
# Epoch 11: Test loss = 0.0679, Pearson correlation = 0.7016
# 300
# Model 11 loaded successfully for epoch 12
# 97100
# 1
# Epoch 12.0: Avg. training loss = 0.0888, Training Pearson correlation = 0.5367
# Epoch 12.0: Test loss = 0.0667, Pearson correlation = 0.7139
# Model 11 loaded successfully for epoch 12
# 97100
# 1
# Epoch 12.100: Avg. training loss = 0.1101, Training Pearson correlation = 0.3778
# Epoch 12.100: Test loss = 0.0959, Pearson correlation = 0.5361
# Model 11 loaded successfully for epoch 12
# 97100
# 1
# Epoch 12.200: Avg. training loss = 0.0484, Training Pearson correlation = 0.7913
# Epoch 12.200: Test loss = 0.0397, Pearson correlation = 0.8454
# Epoch 12: Avg. training loss = 0.0824, Training Pearson correlation = 0.5686
# Epoch 12: Test loss = 0.0675, Pearson correlation = 0.6985
# 300
# Model 12 loaded successfully for epoch 13
# 97100
# 1
# Epoch 13.0: Avg. training loss = 0.0889, Training Pearson correlation = 0.5294
# Epoch 13.0: Test loss = 0.0649, Pearson correlation = 0.7352
# Model 12 loaded successfully for epoch 13
# 97100
# 1
# Epoch 13.100: Avg. training loss = 0.1097, Training Pearson correlation = 0.3933
# Epoch 13.100: Test loss = 0.0911, Pearson correlation = 0.5520
# Model 12 loaded successfully for epoch 13
# 97100
# 1
# Epoch 13.200: Avg. training loss = 0.0470, Training Pearson correlation = 0.7987
# Epoch 13.200: Test loss = 0.0397, Pearson correlation = 0.8413
# Epoch 13: Avg. training loss = 0.0819, Training Pearson correlation = 0.5738
# Epoch 13: Test loss = 0.0652, Pearson correlation = 0.7095
# 300
# Model 13 loaded successfully for epoch 14
# 97100
# 1
# Epoch 14.0: Avg. training loss = 0.0899, Training Pearson correlation = 0.5316
# Epoch 14.0: Test loss = 0.0647, Pearson correlation = 0.7009
# Model 13 loaded successfully for epoch 14
# 97100
# 1
# Epoch 14.100: Avg. training loss = 0.1077, Training Pearson correlation = 0.4011
# Epoch 14.100: Test loss = 0.0994, Pearson correlation = 0.5595
# Model 13 loaded successfully for epoch 14
# 97100
# 1
# Epoch 14.200: Avg. training loss = 0.0452, Training Pearson correlation = 0.8067
# Epoch 14.200: Test loss = 0.0388, Pearson correlation = 0.8467
# Epoch 14: Avg. training loss = 0.0810, Training Pearson correlation = 0.5798
# Epoch 14: Test loss = 0.0677, Pearson correlation = 0.7024
# 300
# Model 14 loaded successfully for epoch 15
# 97100
# 1
# Epoch 15.0: Avg. training loss = 0.0877, Training Pearson correlation = 0.5373
# Epoch 15.0: Test loss = 0.0680, Pearson correlation = 0.7146
# Model 14 loaded successfully for epoch 15
# 97100
# 1
# Epoch 15.100: Avg. training loss = 0.1075, Training Pearson correlation = 0.4064
# Epoch 15.100: Test loss = 0.0979, Pearson correlation = 0.5431
# Model 14 loaded successfully for epoch 15
# 97100
# 1
# Epoch 15.200: Avg. training loss = 0.0439, Training Pearson correlation = 0.8136
# Epoch 15.200: Test loss = 0.0355, Pearson correlation = 0.8549
# Epoch 15: Avg. training loss = 0.0797, Training Pearson correlation = 0.5858
# Epoch 15: Test loss = 0.0671, Pearson correlation = 0.7042
# 300
# Model 15 loaded successfully for epoch 16
# 97100
# 1
# Epoch 16.0: Avg. training loss = 0.0867, Training Pearson correlation = 0.5453
# Epoch 16.0: Test loss = 0.0693, Pearson correlation = 0.7185
# Model 15 loaded successfully for epoch 16
# 97100
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 206
#     200                 f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
#     201             f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
# --> 206 main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     207                    data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     208                    df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
#     209                    data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     210                    data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     211                    df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
#     212                    data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     213                    data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     214                    df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
#     215                    data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     216                    data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     217                    df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
#     218                    batch_size1=100,learning_rate=0.001,num_epochs=1,
#     219                    model_save_path='/mnt/data/macaulay/datas/genepedia/',test_batch_size=128)
#
# Cell In[1], line 121, in main_training_loop(data1_path, data2_path, df_Y_path, data1_test_path_A, data2_test_path_A, df_Y_test_path_A, data1_test_path_B, data2_test_path_B, df_Y_test_path_B, data1_test_path_C, data2_test_path_C, df_Y_test_path_C, batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size)
#     118 print(counter)
#     120 # Concatenate X and Y DataFrames along the columns axis
# --> 121 combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)
#     123 # Shuffle data
#     124 combined = combined.sample(frac=1).reset_index(drop=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:6154, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6152     new_obj = self
#    6153 else:
# -> 6154     new_obj = self.copy(deep=None)
#    6155 if allow_duplicates is not lib.no_default:
#    6156     allow_duplicates = validate_bool_kwarg(allow_duplicates, "allow_duplicates")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6452, in NDFrame.copy(self, deep)
#    6342 @final
#    6343 def copy(self: NDFrameT, deep: bool_t | None = True) -> NDFrameT:
#    6344     """
#    6345     Make a copy of this object's indices and data.
#    6346
#    (...)
#    6450     dtype: object
#    6451     """
# -> 6452     data = self._mgr.copy(deep=deep)
#    6453     self._clear_item_cache()
#    6454     return self._constructor(data).__finalize__(self, method="copy")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:653, in BaseBlockManager.copy(self, deep)
#     650 else:
#     651     new_axes = list(self.axes)
# --> 653 res = self.apply("copy", deep=deep)
#     654 res.axes = new_axes
#     656 if self.ndim > 1:
#     657     # Avoid needing to re-compute these
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:540, in Block.copy(self, deep)
#     538 refs: BlockValuesRefs | None
#     539 if deep:
# --> 540     values = values.copy()
#     541     refs = None
#     542 else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## GROUP A VAL SET

# %%
# #a.py
# """

# Goal
# Test the model on the saved models, and calculate the metrics for each gene concatinated with the cell line embeddings

# it calculate the correlation by each seen gene
# """
# import torch 
# from torch import nn
# from torch.utils.data import DataLoader, TensorDataset
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import pearsonr
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# import os
# import torch.nn.functional as F
# from functions import FullConnectedBlock, NeuralNetwork
# pd.options.mode.chained_assignment = None





# # Initialize lists to store metrics


# avg_test_losses = []
# mae_values = []
# rmse_values = []
# r2_values = []
# correlation_coefficients = []
# p_values = []



# # Loop through the saved models
# # for epoch in range(num_epochs):

# target_epochs = [2]

# # Loop through the target epochs
# for epoch in target_epochs:
#     #model_epoch = epoch
#     Y_data_count = 0

#     model_path = f'/mnt/data/macaulay/datas/genepedia/crispr_fc1_model_state_epoch_{epoch}.pth'
#     if os.path.exists(model_path):
        

#         data1_test = pd.read_csv("/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv") #30 >>
#         data2_test = pd.read_csv("/mnt/data/macaulay/datas/training_gene_embeddings.csv") #17000 >>
#         df_Y_test = pd.read_csv('/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv') #>>
#         print('Test data loaded successfully')




#         batch_size1 = len(data1_test)
#         batch_size_Y = len(data1_test)
#         batch_size2 = 1
#         combined_batches_test = []

#         input_dim = data1_test.shape[1] + data2_test.shape[1] - 1
#         device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#         print('Device:', device)
#         model = NeuralNetwork(input_dim)

#         # If multiple GPUs
#         if torch.cuda.device_count() >= 4:
#             print("Using 4 GPUs!")
#             model = nn.DataParallel(model, device_ids=list(range(4)))

#         model.to(device)
#         model.load_state_dict(torch.load(model_path))
#         model.eval()  # Set the model to evaluation mode

#         # Define the loss function as Mean Squared Error
#         loss_fn = nn.MSELoss()

        

#         for i in range(0, len(data2_test), batch_size2):  # Loop through data2_test
#             batch_data2_test = data2_test.iloc[i:i+batch_size2]
#             for j in range(0, len(data1_test), batch_size1):  # Loop through data1_test
#                 batch_data1_test = data1_test.iloc[j:j+batch_size1]
#                 batch_data1_test['key'] = 1
#                 batch_data2_test['key'] = 1
#                 batch_data1_test = batch_data1_test[list(data1_test.columns[0:]) + ['key']]
#                 batch_data2_test = batch_data2_test[list(data2_test.columns[1:]) + ['key']]
#                 combined_batch_test = pd.merge(batch_data1_test, batch_data2_test, on='key').drop(columns=['key'])
#                 combined_batches_test.append(combined_batch_test)

#                 X_test = pd.concat(combined_batches_test)
#                 combined_batches_test = []
#                 Y_test = df_Y_test.iloc[Y_data_count:(batch_size_Y * (i+1))]
#                 Y_data_count += batch_size_Y

                
#                 X_test1 = torch.tensor(X_test.values, dtype=torch.float32)
#                 Y_test1 = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32)
#                 test_data = TensorDataset(X_test1, Y_test1)
#                 test_dataloader = DataLoader(test_data, batch_size=128, shuffle=True)

#                 #print('Test data preprocessed successfully')
#                 ##################### The first 1 Batch which forms 100 rows after concat, are preprocessed and fed to the neural network under the same loop #####################

#                 # Evaluate the model on the test data
#                 test_loss = 0.0
#                 actual_outputs = []
#                 predicted_outputs = []
#                 with torch.no_grad():  # Disable gradient calculation
#                     for inputs, targets in test_dataloader:
#                         inputs = inputs.to(device)
#                         targets = targets.to(device)
#                         outputs = model(inputs)
#                         loss = loss_fn(outputs, targets)
#                         test_loss += loss.item()
#                         actual_outputs.extend(targets.cpu().numpy().flatten().tolist())
#                         predicted_outputs.extend(outputs.cpu().numpy().flatten().tolist())

#                 avg_test_loss = test_loss / len(test_dataloader)
#                 avg_test_losses.append(avg_test_loss)

#                 # Calculate Pearson correlation coefficient
#                 correlation_coefficient, p_value = pearsonr(actual_outputs, predicted_outputs)
#                 correlation_coefficients.append(correlation_coefficient)
#                 p_values.append(p_value)  # Append the p-value

#                 mae = mean_absolute_error(actual_outputs, predicted_outputs)
#                 rmse = np.sqrt(mean_squared_error(actual_outputs, predicted_outputs))
#                 r2 = r2_score(actual_outputs, predicted_outputs)

#                 # Append metrics to their respective lists
#                 mae_values.append(mae)
#                 rmse_values.append(rmse)
#                 r2_values.append(r2)

#                 print(f'Epoch {epoch} : gene {i+1}/{target_epochs}: Avg. test loss = {avg_test_loss:.4f}')
#                 print(f'Epoch {epoch} : gene {i+1}/{target_epochs}: Correlation Coefficient = {correlation_coefficient:.4f}')
#                 print(f'Epoch {epoch} : gene {i+1}/{target_epochs}: Mean Absolute Error = {mae:.4f}')
#                 print(f'Epoch {epoch} : gene {i+1}/{target_epochs}: Root Mean Square Error = {rmse:.4f}')
#                 print(f'Epoch {epoch} : gene {i+1}/{target_epochs}: R2 Score = {r2:.4f}')


#     else:
#         print(f'Model for epoch {epoch} not found!')


# # Create a list to store the full epoch labels
# epochs = []

# # Loop through the target epochs
# for major in target_epochs:
#     for minor in range(1, len(data2_test) + 1):
#         epoch = f'{major}.{minor:02}'  # Format as a string with two decimal places
#         epochs.append(float(epoch))

# # Create a DataFrame to hold the metrics
# metrics_df = pd.DataFrame({
#     'Epoch': epochs,
#     'Correlation_Coefficient': correlation_coefficients,
#     'P_Value': p_values,  # Include the p-values
#     'Test_Loss': avg_test_losses,
#     'MAE': mae_values,
#     'RMSE': rmse_values,
#     'R2_Score': r2_values
# })

# # Write the DataFrame to a CSV file
# metrics_path = f'/mnt/data/macaulay/datas/genepedia/A_seen_genewise_correlation_metrics_summary_crispr_{target_epochs[0]}.csv'
# metrics_df.to_csv(metrics_path, index=False)
# print(f'Metrics saved to {metrics_path}')

























import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr



def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


def load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                    data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                      data1_test_path_C, data2_test_path_C, df_Y_test_path_C):
    
    data1_test_A = pd.read_csv(data1_test_path_A)
    data2_test_A = pd.read_csv(data2_test_path_A)
    df_Y_test_A = pd.read_csv(df_Y_test_path_A)
    data1_test_B = pd.read_csv(data1_test_path_B)
    data2_test_B = pd.read_csv(data2_test_path_B)
    df_Y_test_B = pd.read_csv(df_Y_test_path_B)
    data1_test_C = pd.read_csv(data1_test_path_C)
    data2_test_C = pd.read_csv(data2_test_path_C)
    df_Y_test_C = pd.read_csv(df_Y_test_path_C)
    print('Test data loaded successfully')
    return data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C


# Evaluation Function
def evaluate_model_on_test_data(model, data1_test, data2_test, df_Y_test, epoch, loss_fn, device, test_batch_size=128):
    model.eval()
    # print('data1_test')
    # display(data1_test)
    # print('data2_test')
    # display(data2_test)
    # print('df_Y_test')
    # display(df_Y_test)

    



    avg_test_losses = []
    mae_values = []
    rmse_values = []
    r2_values = []
    correlation_coefficients = []
    p_values = []
    gene_batches = 1
    counter = 0
    for batch_X, batch_Y in cartesian_product_generator(data1_test, data2_test, df_Y_test, gene_batches):
        
        batch_X = batch_X.drop(columns=["Gene"])

        
        # print('batch_X')
        # display(batch_X)
        # print('batch_Y')
        # display(batch_Y)
        

        
        X_test = torch.tensor(batch_X.values, dtype=torch.float32).to(device)
        Y_test = torch.tensor(batch_Y.values.reshape(-1, 1), dtype=torch.float32).to(device)
        predictions = model(X_test)
        test_loss = loss_fn(predictions, Y_test)
        predictions_np = predictions.cpu().detach().numpy()

        Y_test_np = Y_test.cpu().numpy()
        
        correlation, pval = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
        
        correlation_coefficients.append(correlation)
        avg_test_losses.append(test_loss.item())
        p_values.append(pval)
        counter += 1
        print(f'Epoch {epoch} gene {counter} : Avg. test loss = {test_loss.item():.4f}, correlation = {correlation:.4f}, p-value = {pval:.4f}')



    epochs = []
    for minor in range(1, len(data1_test) + 1):
        epoched = f'{epoch}.{minor:02}'  
        epochs.append(float(epoched))

    metrics_df = pd.DataFrame({
        'Epoch': epochs,
        'Correlation_Coefficient': correlation_coefficients,
        'P_Value': p_values,
        'Test_Loss': avg_test_losses,
        # 'MAE': mae_values,
        # 'RMSE': rmse_values,
        # 'R2_Score': r2_values
    })
    return metrics_df



# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    
# Evaluate the model on test data after each epoch
    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)

    data1_test_A, data2_test_A, df_Y_test_A, data1_test_B, data2_test_B, df_Y_test_B, data1_test_C, data2_test_C, df_Y_test_C = load_test_data(data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
                                                                                                                                                data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                                                                                                                                                  data1_test_path_C, data2_test_path_C, df_Y_test_path_C)
    target_epochs = [20]

    
    for epoch in target_epochs:


        metrics_df_A = evaluate_model_on_test_data(model, data1_test_A, data2_test_A, df_Y_test_A, epoch, loss_fn, device, test_batch_size)
        metrics_path_A = os.path.join(model_save_path, f"A_metrics_epoch_{epoch}.csv")
        metrics_df_A.to_csv(metrics_path_A, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_A}')

        metrics_df_B = evaluate_model_on_test_data(model, data1_test_B, data2_test_B, df_Y_test_B, epoch, loss_fn, device, test_batch_size)
        metrics_path_B = os.path.join(model_save_path, f"B_metrics_epoch_{epoch}.csv")
        metrics_df_B.to_csv(metrics_path_B, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_B}')

        metrics_df_C = evaluate_model_on_test_data(model, data1_test_C, data2_test_C, df_Y_test_C, epoch, loss_fn, device, test_batch_size)
        metrics_path_C = os.path.join(model_save_path, f"C_metrics_epoch_{epoch}.csv")
        metrics_df_C.to_csv(metrics_path_C, index=False)
        print(f'Metrics for epoch {epoch} saved to {metrics_path_C}')







main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=10,
                   model_save_path='/mnt/data/macaulay/datas/genepedia/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# Test data loaded successfully
# 30
# Epoch 20 gene 1 : Avg. test loss = 0.2071, correlation = -0.2081, p-value = 0.2699
# 30
# Epoch 20 gene 2 : Avg. test loss = 0.0287, correlation = 0.0570, p-value = 0.7650
# 30
# Epoch 20 gene 3 : Avg. test loss = 0.1351, correlation = -0.2641, p-value = 0.1584
# 30
# Epoch 20 gene 4 : Avg. test loss = 0.0171, correlation = -0.0503, p-value = 0.7918
# 30
# Epoch 20 gene 5 : Avg. test loss = 0.0551, correlation = 0.0297, p-value = 0.8764
# 30
# Epoch 20 gene 6 : Avg. test loss = 0.0659, correlation = 0.2530, p-value = 0.1773
# 30
# Epoch 20 gene 7 : Avg. test loss = 0.0236, correlation = -0.1901, p-value = 0.3143
# 30
# Epoch 20 gene 8 : Avg. test loss = 0.0673, correlation = -0.0127, p-value = 0.9468
# 30
# Epoch 20 gene 9 : Avg. test loss = 0.0475, correlation = -0.4006, p-value = 0.0282
# 30
# Epoch 20 gene 10 : Avg. test loss = 0.0420, correlation = 0.2018, p-value = 0.2848
# 30
# Epoch 20 gene 11 : Avg. test loss = 0.2183, correlation = -0.3575, p-value = 0.0525
# 30
# Epoch 20 gene 12 : Avg. test loss = 0.0059, correlation = 0.2528, p-value = 0.1778
# 30
# Epoch 20 gene 13 : Avg. test loss = 0.0119, correlation = 0.1555, p-value = 0.4119
# 30
# Epoch 20 gene 14 : Avg. test loss = 0.0432, correlation = -0.0274, p-value = 0.8855
# 30
# Epoch 20 gene 15 : Avg. test loss = 0.0531, correlation = -0.1627, p-value = 0.3903
# 30
# Epoch 20 gene 16 : Avg. test loss = 0.0183, correlation = -0.2689, p-value = 0.1508
# 30
# Epoch 20 gene 17 : Avg. test loss = 0.0358, correlation = -0.2280, p-value = 0.2255
# 30
# Epoch 20 gene 18 : Avg. test loss = 0.0104, correlation = 0.2578, p-value = 0.1691
# 30
# Epoch 20 gene 19 : Avg. test loss = 0.0331, correlation = 0.1105, p-value = 0.5610
# 30
# Epoch 20 gene 20 : Avg. test loss = 0.0918, correlation = -0.0967, p-value = 0.6112
# 30
# Epoch 20 gene 21 : Avg. test loss = 0.0868, correlation = -0.0289, p-value = 0.8797
# 30
# Epoch 20 gene 22 : Avg. test loss = 0.0234, correlation = 0.0266, p-value = 0.8890
# 30
# Epoch 20 gene 23 : Avg. test loss = 0.0102, correlation = -0.0511, p-value = 0.7887
# 30
# Epoch 20 gene 24 : Avg. test loss = 0.0549, correlation = -0.2108, p-value = 0.2636
# 30
# Epoch 20 gene 25 : Avg. test loss = 0.0152, correlation = 0.0929, p-value = 0.6255
# 30
# Epoch 20 gene 26 : Avg. test loss = 0.0163, correlation = -0.0555, p-value = 0.7707
# 30
# Epoch 20 gene 27 : Avg. test loss = 0.0262, correlation = -0.0963, p-value = 0.6125
# 30
# Epoch 20 gene 28 : Avg. test loss = 0.0159, correlation = -0.2252, p-value = 0.2315
# 30
# Epoch 20 gene 29 : Avg. test loss = 0.0927, correlation = 0.1100, p-value = 0.5629
# 30
# Epoch 20 gene 30 : Avg. test loss = 0.0146, correlation = 0.1228, p-value = 0.5178
# 30
# Epoch 20 gene 31 : Avg. test loss = 0.0469, correlation = -0.3000, p-value = 0.1073
# 30
# Epoch 20 gene 32 : Avg. test loss = 0.0087, correlation = -0.2240, p-value = 0.2340
# 30
# Epoch 20 gene 33 : Avg. test loss = 0.0058, correlation = 0.2636, p-value = 0.1593
# 30
# Epoch 20 gene 34 : Avg. test loss = 0.0095, correlation = 0.0345, p-value = 0.8562
# 30
# Epoch 20 gene 35 : Avg. test loss = 1.3181, correlation = 0.0150, p-value = 0.9375
# 30
# Epoch 20 gene 36 : Avg. test loss = 0.0199, correlation = 0.2907, p-value = 0.1191
# 30
# Epoch 20 gene 37 : Avg. test loss = 0.0080, correlation = 0.0752, p-value = 0.6928
# 30
# Epoch 20 gene 38 : Avg. test loss = 0.0550, correlation = 0.0588, p-value = 0.7575
# 30
# Epoch 20 gene 39 : Avg. test loss = 0.1527, correlation = -0.3890, p-value = 0.0336
# 30
# Epoch 20 gene 40 : Avg. test loss = 0.0464, correlation = -0.0709, p-value = 0.7095
# 30
# Epoch 20 gene 41 : Avg. test loss = 0.7570, correlation = -0.0793, p-value = 0.6770
# 30
# Epoch 20 gene 42 : Avg. test loss = 0.4417, correlation = -0.1054, p-value = 0.5794
# 30
# Epoch 20 gene 43 : Avg. test loss = 0.0112, correlation = 0.0629, p-value = 0.7413
# 30
# Epoch 20 gene 44 : Avg. test loss = 1.2318, correlation = -0.0827, p-value = 0.6640
# 30
# Epoch 20 gene 45 : Avg. test loss = 0.0067, correlation = 0.1388, p-value = 0.4646
# 30
# Epoch 20 gene 46 : Avg. test loss = 0.0264, correlation = -0.1882, p-value = 0.3194
# 30
# Epoch 20 gene 47 : Avg. test loss = 0.0128, correlation = -0.0426, p-value = 0.8233
# 30
# Epoch 20 gene 48 : Avg. test loss = 0.0133, correlation = -0.1349, p-value = 0.4771
# 30
# Epoch 20 gene 49 : Avg. test loss = 0.0080, correlation = -0.0660, p-value = 0.7289
# 30
# Epoch 20 gene 50 : Avg. test loss = 0.0423, correlation = -0.2007, p-value = 0.2877
# 30
# Epoch 20 gene 51 : Avg. test loss = 0.0265, correlation = -0.2398, p-value = 0.2018
# 30
# Epoch 20 gene 52 : Avg. test loss = 0.0305, correlation = 0.0398, p-value = 0.8345
# 30
# Epoch 20 gene 53 : Avg. test loss = 0.0147, correlation = 0.2525, p-value = 0.1782
# 30
# Epoch 20 gene 54 : Avg. test loss = 0.0042, correlation = -0.2027, p-value = 0.2828
# 30
# Epoch 20 gene 55 : Avg. test loss = 0.0459, correlation = -0.0133, p-value = 0.9445
# 30
# Epoch 20 gene 56 : Avg. test loss = 0.0060, correlation = -0.1651, p-value = 0.3834
# 30
# Epoch 20 gene 57 : Avg. test loss = 5.2126, correlation = -0.0360, p-value = 0.8501
# 30
# Epoch 20 gene 58 : Avg. test loss = 0.0228, correlation = -0.2367, p-value = 0.2080
# 30
# Epoch 20 gene 59 : Avg. test loss = 0.0117, correlation = -0.1912, p-value = 0.3114
# 30
# Epoch 20 gene 60 : Avg. test loss = 0.0905, correlation = -0.1677, p-value = 0.3759
# 30
# Epoch 20 gene 61 : Avg. test loss = 0.0257, correlation = 0.0329, p-value = 0.8632
# 30
# Epoch 20 gene 62 : Avg. test loss = 0.0819, correlation = 0.1713, p-value = 0.3655
# 30
# Epoch 20 gene 63 : Avg. test loss = 0.0438, correlation = 0.0732, p-value = 0.7009
# 30
# Epoch 20 gene 64 : Avg. test loss = 0.0121, correlation = -0.2784, p-value = 0.1363
# 30
# Epoch 20 gene 65 : Avg. test loss = 0.0182, correlation = -0.0834, p-value = 0.6611
# 30
# Epoch 20 gene 66 : Avg. test loss = 0.0109, correlation = -0.1730, p-value = 0.3605
# 30
# Epoch 20 gene 67 : Avg. test loss = 0.0490, correlation = -0.3554, p-value = 0.0539
# 30
# Epoch 20 gene 68 : Avg. test loss = 0.0411, correlation = 0.0263, p-value = 0.8902
# 30
# Epoch 20 gene 69 : Avg. test loss = 0.0067, correlation = 0.2101, p-value = 0.2650
# 30
# Epoch 20 gene 70 : Avg. test loss = 0.0062, correlation = 0.1090, p-value = 0.5663
# 30
# Epoch 20 gene 71 : Avg. test loss = 0.2140, correlation = -0.1149, p-value = 0.5455
# 30
# Epoch 20 gene 72 : Avg. test loss = 0.0083, correlation = 0.0465, p-value = 0.8072
# 30
# Epoch 20 gene 73 : Avg. test loss = 0.0722, correlation = -0.2265, p-value = 0.2288
# 30
# Epoch 20 gene 74 : Avg. test loss = 0.0176, correlation = 0.0414, p-value = 0.8281
# 30
# Epoch 20 gene 75 : Avg. test loss = 0.0704, correlation = 0.2851, p-value = 0.1268
# 30
# Epoch 20 gene 76 : Avg. test loss = 0.0298, correlation = -0.2248, p-value = 0.2323
# 30
# Epoch 20 gene 77 : Avg. test loss = 0.1243, correlation = -0.0418, p-value = 0.8262
# 30
# Epoch 20 gene 78 : Avg. test loss = 0.1983, correlation = -0.2365, p-value = 0.2083
# 30
# Epoch 20 gene 79 : Avg. test loss = 0.0107, correlation = -0.0333, p-value = 0.8612
# 30
# Epoch 20 gene 80 : Avg. test loss = 0.7351, correlation = 0.1102, p-value = 0.5621
# 30
# Epoch 20 gene 81 : Avg. test loss = 0.0041, correlation = 0.1462, p-value = 0.4407
# 30
# Epoch 20 gene 82 : Avg. test loss = 0.0184, correlation = 0.1997, p-value = 0.2900
# 30
# Epoch 20 gene 83 : Avg. test loss = 0.0497, correlation = -0.0761, p-value = 0.6892
# 30
# Epoch 20 gene 84 : Avg. test loss = 0.0171, correlation = 0.0382, p-value = 0.8412
# 30
# Epoch 20 gene 85 : Avg. test loss = 3.9908, correlation = -0.0578, p-value = 0.7618
# 30
# Epoch 20 gene 86 : Avg. test loss = 0.0061, correlation = -0.0027, p-value = 0.9887
# 30
# Epoch 20 gene 87 : Avg. test loss = 0.0175, correlation = 0.0033, p-value = 0.9863
# 30
# Epoch 20 gene 88 : Avg. test loss = 0.0064, correlation = 0.0057, p-value = 0.9762
# 30
# Epoch 20 gene 89 : Avg. test loss = 0.0102, correlation = 0.0192, p-value = 0.9196
# 30
# Epoch 20 gene 90 : Avg. test loss = 0.0490, correlation = 0.0928, p-value = 0.6257
# 30
# Epoch 20 gene 91 : Avg. test loss = 0.0249, correlation = 0.0260, p-value = 0.8915
# 30
# Epoch 20 gene 92 : Avg. test loss = 0.0573, correlation = -0.2992, p-value = 0.1082
# 30
# Epoch 20 gene 93 : Avg. test loss = 0.0466, correlation = -0.1076, p-value = 0.5713
# 30
# Epoch 20 gene 94 : Avg. test loss = 0.0266, correlation = 0.0198, p-value = 0.9173
# 30
# Epoch 20 gene 95 : Avg. test loss = 0.0276, correlation = -0.2095, p-value = 0.2666
# 30
# Epoch 20 gene 96 : Avg. test loss = 0.0119, correlation = -0.3852, p-value = 0.0356
# 30
# Epoch 20 gene 97 : Avg. test loss = 0.0873, correlation = -0.0998, p-value = 0.5998
# 30
# Epoch 20 gene 98 : Avg. test loss = 0.1373, correlation = -0.0929, p-value = 0.6254
# 30
# Epoch 20 gene 99 : Avg. test loss = 0.0560, correlation = -0.1064, p-value = 0.5758
# 30
# Epoch 20 gene 100 : Avg. test loss = 0.0124, correlation = 0.2435, p-value = 0.1948
# 30
# Epoch 20 gene 101 : Avg. test loss = 0.0364, correlation = -0.0210, p-value = 0.9122
# 30
# Epoch 20 gene 102 : Avg. test loss = 5.4154, correlation = 0.2388, p-value = 0.2037
# 30
# Epoch 20 gene 103 : Avg. test loss = 0.0386, correlation = 0.1712, p-value = 0.3657
# 30
# Epoch 20 gene 104 : Avg. test loss = 0.0522, correlation = -0.1568, p-value = 0.4080
# 30
# Epoch 20 gene 105 : Avg. test loss = 0.0106, correlation = -0.2665, p-value = 0.1546
# 30
# Epoch 20 gene 106 : Avg. test loss = 0.0504, correlation = -0.0795, p-value = 0.6763
# 30
# Epoch 20 gene 107 : Avg. test loss = 0.0105, correlation = 0.2868, p-value = 0.1244
# 30
# Epoch 20 gene 108 : Avg. test loss = 0.1266, correlation = -0.0794, p-value = 0.6765
# 30
# Epoch 20 gene 109 : Avg. test loss = 0.0440, correlation = 0.2352, p-value = 0.2110
# 30
# Epoch 20 gene 110 : Avg. test loss = 0.0072, correlation = -0.3243, p-value = 0.0804
# 30
# Epoch 20 gene 111 : Avg. test loss = 0.0098, correlation = 0.0254, p-value = 0.8938
# 30
# Epoch 20 gene 112 : Avg. test loss = 0.3609, correlation = -0.3492, p-value = 0.0586
# 30
# Epoch 20 gene 113 : Avg. test loss = 0.0143, correlation = -0.0770, p-value = 0.6859
# 30
# Epoch 20 gene 114 : Avg. test loss = 0.1088, correlation = -0.3662, p-value = 0.0466
# 30
# Epoch 20 gene 115 : Avg. test loss = 0.2022, correlation = 0.2390, p-value = 0.2034
# 30
# Epoch 20 gene 116 : Avg. test loss = 8.4470, correlation = -0.0209, p-value = 0.9129
# 30
# Epoch 20 gene 117 : Avg. test loss = 0.2367, correlation = -0.2227, p-value = 0.2369
# 30
# Epoch 20 gene 118 : Avg. test loss = 0.0193, correlation = -0.1180, p-value = 0.5346
# 30
# Epoch 20 gene 119 : Avg. test loss = 0.3038, correlation = -0.1336, p-value = 0.4814
# 30
# Epoch 20 gene 120 : Avg. test loss = 0.0060, correlation = -0.1463, p-value = 0.4404
# 30
# Epoch 20 gene 121 : Avg. test loss = 0.0083, correlation = -0.3659, p-value = 0.0468
# 30
# Epoch 20 gene 122 : Avg. test loss = 0.0164, correlation = -0.1013, p-value = 0.5944
# 30
# Epoch 20 gene 123 : Avg. test loss = 0.0254, correlation = 0.2139, p-value = 0.2563
# 30
# Epoch 20 gene 124 : Avg. test loss = 0.0233, correlation = -0.0876, p-value = 0.6452
# 30
# Epoch 20 gene 125 : Avg. test loss = 0.0097, correlation = -0.0224, p-value = 0.9065
# 30
# Epoch 20 gene 126 : Avg. test loss = 0.0182, correlation = 0.0955, p-value = 0.6158
# 30
# Epoch 20 gene 127 : Avg. test loss = 0.0161, correlation = -0.0251, p-value = 0.8954
# 30
# Epoch 20 gene 128 : Avg. test loss = 0.0500, correlation = -0.4359, p-value = 0.0160
# 30
# Epoch 20 gene 129 : Avg. test loss = 0.1942, correlation = -0.2502, p-value = 0.1824
# 30
# Epoch 20 gene 130 : Avg. test loss = 0.0786, correlation = -0.0657, p-value = 0.7301
# 30
# Epoch 20 gene 131 : Avg. test loss = 0.0212, correlation = -0.0744, p-value = 0.6959
# 30
# Epoch 20 gene 132 : Avg. test loss = 0.6482, correlation = -0.1022, p-value = 0.5911
# 30
# Epoch 20 gene 133 : Avg. test loss = 0.0167, correlation = 0.1677, p-value = 0.3758
# 30
# Epoch 20 gene 134 : Avg. test loss = 1.6836, correlation = 0.0379, p-value = 0.8423
# 30
# Epoch 20 gene 135 : Avg. test loss = 0.3938, correlation = -0.1319, p-value = 0.4873
# 30
# Epoch 20 gene 136 : Avg. test loss = 0.0147, correlation = 0.1646, p-value = 0.3847
# 30
# Epoch 20 gene 137 : Avg. test loss = 0.0439, correlation = -0.1142, p-value = 0.5481
# 30
# Epoch 20 gene 138 : Avg. test loss = 0.0250, correlation = -0.3804, p-value = 0.0381
# 30
# Epoch 20 gene 139 : Avg. test loss = 2.0210, correlation = 0.1717, p-value = 0.3643
# 30
# Epoch 20 gene 140 : Avg. test loss = 0.0262, correlation = -0.3018, p-value = 0.1051
# 30
# Epoch 20 gene 141 : Avg. test loss = 0.0345, correlation = 0.1784, p-value = 0.3455
# 30
# Epoch 20 gene 142 : Avg. test loss = 0.0220, correlation = -0.1651, p-value = 0.3832
# 30
# Epoch 20 gene 143 : Avg. test loss = 0.0337, correlation = 0.0942, p-value = 0.6205
# 30
# Epoch 20 gene 144 : Avg. test loss = 0.3279, correlation = 0.0152, p-value = 0.9364
# 30
# Epoch 20 gene 145 : Avg. test loss = 0.0420, correlation = 0.2648, p-value = 0.1574
# 30
# Epoch 20 gene 146 : Avg. test loss = 0.0116, correlation = 0.0688, p-value = 0.7178
# 30
# Epoch 20 gene 147 : Avg. test loss = 0.0153, correlation = 0.0113, p-value = 0.9529
# 30
# Epoch 20 gene 148 : Avg. test loss = 0.0084, correlation = -0.3163, p-value = 0.0886
# 30
# Epoch 20 gene 149 : Avg. test loss = 0.0209, correlation = 0.0337, p-value = 0.8597
# 30
# Epoch 20 gene 150 : Avg. test loss = 0.0157, correlation = 0.0219, p-value = 0.9085
# 30
# Epoch 20 gene 151 : Avg. test loss = 0.0103, correlation = 0.1970, p-value = 0.2967
# 30
# Epoch 20 gene 152 : Avg. test loss = 0.0118, correlation = 0.0443, p-value = 0.8161
# 30
# Epoch 20 gene 153 : Avg. test loss = 0.0068, correlation = 0.0229, p-value = 0.9043
# 30
# Epoch 20 gene 154 : Avg. test loss = 0.0101, correlation = -0.0456, p-value = 0.8110
# 30
# Epoch 20 gene 155 : Avg. test loss = 0.0261, correlation = 0.0201, p-value = 0.9159
# 30
# Epoch 20 gene 156 : Avg. test loss = 0.0102, correlation = -0.0134, p-value = 0.9440
# 30
# Epoch 20 gene 157 : Avg. test loss = 0.0133, correlation = -0.0283, p-value = 0.8821
# 30
# Epoch 20 gene 158 : Avg. test loss = 0.0388, correlation = -0.4141, p-value = 0.0229
# 30
# Epoch 20 gene 159 : Avg. test loss = 0.1625, correlation = -0.0605, p-value = 0.7507
# 30
# Epoch 20 gene 160 : Avg. test loss = 0.0704, correlation = -0.1943, p-value = 0.3035
# 30
# Epoch 20 gene 161 : Avg. test loss = 0.0655, correlation = 0.3092, p-value = 0.0964
# 30
# Epoch 20 gene 162 : Avg. test loss = 0.0210, correlation = -0.1005, p-value = 0.5972
# 30
# Epoch 20 gene 163 : Avg. test loss = 0.2897, correlation = -0.2168, p-value = 0.2498
# 30
# Epoch 20 gene 164 : Avg. test loss = 0.0435, correlation = 0.0937, p-value = 0.6225
# 30
# Epoch 20 gene 165 : Avg. test loss = 0.0222, correlation = 0.1580, p-value = 0.4042
# 30
# Epoch 20 gene 166 : Avg. test loss = 0.1245, correlation = 0.0838, p-value = 0.6599
# 30
# Epoch 20 gene 167 : Avg. test loss = 0.0207, correlation = -0.0261, p-value = 0.8910
# 30
# Epoch 20 gene 168 : Avg. test loss = 0.0350, correlation = -0.0099, p-value = 0.9586
# 30
# Epoch 20 gene 169 : Avg. test loss = 0.0151, correlation = -0.0761, p-value = 0.6895
# 30
# Epoch 20 gene 170 : Avg. test loss = 0.0132, correlation = 0.0726, p-value = 0.7031
# 30
# Epoch 20 gene 171 : Avg. test loss = 0.1040, correlation = -0.0381, p-value = 0.8415
# 30
# Epoch 20 gene 172 : Avg. test loss = 0.2780, correlation = 0.1640, p-value = 0.3865
# 30
# Epoch 20 gene 173 : Avg. test loss = 1.0476, correlation = -0.1306, p-value = 0.4914
# 30
# Epoch 20 gene 174 : Avg. test loss = 0.0383, correlation = -0.1742, p-value = 0.3572
# 30
# Epoch 20 gene 175 : Avg. test loss = 0.1266, correlation = 0.3244, p-value = 0.0803
# 30
# Epoch 20 gene 176 : Avg. test loss = 0.3601, correlation = 0.0383, p-value = 0.8406
# 30
# Epoch 20 gene 177 : Avg. test loss = 0.0477, correlation = -0.0907, p-value = 0.6335
# 30
# Epoch 20 gene 178 : Avg. test loss = 0.0823, correlation = -0.0626, p-value = 0.7424
# 30
# Epoch 20 gene 179 : Avg. test loss = 0.3413, correlation = -0.0447, p-value = 0.8146
# 30
# Epoch 20 gene 180 : Avg. test loss = 0.0090, correlation = 0.1254, p-value = 0.5090
# 30
# Epoch 20 gene 181 : Avg. test loss = 0.0448, correlation = 0.2208, p-value = 0.2410
# 30
# Epoch 20 gene 182 : Avg. test loss = 0.4190, correlation = -0.2932, p-value = 0.1159
# 30
# Epoch 20 gene 183 : Avg. test loss = 0.0495, correlation = 0.0182, p-value = 0.9241
# 30
# Epoch 20 gene 184 : Avg. test loss = 0.0060, correlation = -0.2876, p-value = 0.1232
# 30
# Epoch 20 gene 185 : Avg. test loss = 0.0100, correlation = -0.0449, p-value = 0.8139
# 30
# Epoch 20 gene 186 : Avg. test loss = 0.0521, correlation = 0.1367, p-value = 0.4713
# 30
# Epoch 20 gene 187 : Avg. test loss = 0.0496, correlation = 0.1459, p-value = 0.4417
# 30
# Epoch 20 gene 188 : Avg. test loss = 0.0829, correlation = 0.1696, p-value = 0.3702
# 30
# Epoch 20 gene 189 : Avg. test loss = 0.0149, correlation = -0.2003, p-value = 0.2885
# 30
# Epoch 20 gene 190 : Avg. test loss = 0.0182, correlation = -0.3024, p-value = 0.1043
# 30
# Epoch 20 gene 191 : Avg. test loss = 0.0434, correlation = -0.0037, p-value = 0.9844
# 30
# Epoch 20 gene 192 : Avg. test loss = 0.0606, correlation = -0.1100, p-value = 0.5627
# 30
# Epoch 20 gene 193 : Avg. test loss = 0.2149, correlation = -0.1142, p-value = 0.5480
# 30
# Epoch 20 gene 194 : Avg. test loss = 0.0930, correlation = -0.1631, p-value = 0.3893
# 30
# Epoch 20 gene 195 : Avg. test loss = 0.0212, correlation = -0.0916, p-value = 0.6302
# 30
# Epoch 20 gene 196 : Avg. test loss = 0.3287, correlation = 0.1786, p-value = 0.3449
# 30
# Epoch 20 gene 197 : Avg. test loss = 0.0078, correlation = -0.0117, p-value = 0.9510
# 30
# Epoch 20 gene 198 : Avg. test loss = 0.1438, correlation = 0.0026, p-value = 0.9892
# 30
# Epoch 20 gene 199 : Avg. test loss = 0.1777, correlation = 0.2135, p-value = 0.2572
# 30
# Epoch 20 gene 200 : Avg. test loss = 0.0599, correlation = -0.1649, p-value = 0.3839
# 30
# Epoch 20 gene 201 : Avg. test loss = 0.0084, correlation = 0.1367, p-value = 0.4712
# 30
# Epoch 20 gene 202 : Avg. test loss = 0.0520, correlation = -0.0664, p-value = 0.7272
# 30
# Epoch 20 gene 203 : Avg. test loss = 0.1383, correlation = 0.0112, p-value = 0.9534
# 30
# Epoch 20 gene 204 : Avg. test loss = 0.0614, correlation = 0.0468, p-value = 0.8060
# 30
# Epoch 20 gene 205 : Avg. test loss = 0.0139, correlation = -0.1479, p-value = 0.4355
# 30
# Epoch 20 gene 206 : Avg. test loss = 0.0099, correlation = 0.0113, p-value = 0.9529
# 30
# Epoch 20 gene 207 : Avg. test loss = 3.1794, correlation = -0.1580, p-value = 0.4042
# 30
# Epoch 20 gene 208 : Avg. test loss = 0.0079, correlation = 0.0042, p-value = 0.9825
# 30
# Epoch 20 gene 209 : Avg. test loss = 0.0142, correlation = 0.0831, p-value = 0.6624
# 30
# Epoch 20 gene 210 : Avg. test loss = 0.0327, correlation = -0.0359, p-value = 0.8508
# 30
# Epoch 20 gene 211 : Avg. test loss = 0.0379, correlation = -0.1904, p-value = 0.3134
# 30
# Epoch 20 gene 212 : Avg. test loss = 0.0115, correlation = 0.0847, p-value = 0.6564
# 30
# Epoch 20 gene 213 : Avg. test loss = 0.0191, correlation = -0.0095, p-value = 0.9604
# 30
# Epoch 20 gene 214 : Avg. test loss = 0.2284, correlation = 0.1235, p-value = 0.5157
# 30
# Epoch 20 gene 215 : Avg. test loss = 0.0074, correlation = 0.0051, p-value = 0.9785
# 30
# Epoch 20 gene 216 : Avg. test loss = 0.0449, correlation = 0.0359, p-value = 0.8504
# 30
# Epoch 20 gene 217 : Avg. test loss = 4.2827, correlation = 0.1211, p-value = 0.5239
# 30
# Epoch 20 gene 218 : Avg. test loss = 0.0121, correlation = -0.1764, p-value = 0.3511
# 30
# Epoch 20 gene 219 : Avg. test loss = 0.0717, correlation = -0.1458, p-value = 0.4419
# 30
# Epoch 20 gene 220 : Avg. test loss = 0.0218, correlation = 0.1318, p-value = 0.4875
# 30
# Epoch 20 gene 221 : Avg. test loss = 0.7075, correlation = -0.0226, p-value = 0.9055
# 30
# Epoch 20 gene 222 : Avg. test loss = 0.0059, correlation = 0.0579, p-value = 0.7611
# 30
# Epoch 20 gene 223 : Avg. test loss = 0.0252, correlation = -0.1617, p-value = 0.3933
# 30
# Epoch 20 gene 224 : Avg. test loss = 0.0071, correlation = -0.1404, p-value = 0.4593
# 30
# Epoch 20 gene 225 : Avg. test loss = 0.0409, correlation = -0.2480, p-value = 0.1864
# 30
# Epoch 20 gene 226 : Avg. test loss = 0.4691, correlation = -0.3049, p-value = 0.1013
# 30
# Epoch 20 gene 227 : Avg. test loss = 0.3457, correlation = 0.2138, p-value = 0.2566
# 30
# Epoch 20 gene 228 : Avg. test loss = 2.6158, correlation = -0.2710, p-value = 0.1474
# 30
# Epoch 20 gene 229 : Avg. test loss = 0.2250, correlation = -0.2172, p-value = 0.2490
# 30
# Epoch 20 gene 230 : Avg. test loss = 0.0677, correlation = -0.0505, p-value = 0.7911
# 30
# Epoch 20 gene 231 : Avg. test loss = 0.0124, correlation = -0.2648, p-value = 0.1573
# 30
# Epoch 20 gene 232 : Avg. test loss = 0.0261, correlation = -0.1835, p-value = 0.3316
# 30
# Epoch 20 gene 233 : Avg. test loss = 0.1490, correlation = -0.2099, p-value = 0.2655
# 30
# Epoch 20 gene 234 : Avg. test loss = 0.0337, correlation = -0.1700, p-value = 0.3690
# 30
# Epoch 20 gene 235 : Avg. test loss = 0.1193, correlation = -0.0389, p-value = 0.8383
# 30
# Epoch 20 gene 236 : Avg. test loss = 0.0120, correlation = -0.3545, p-value = 0.0546
# 30
# Epoch 20 gene 237 : Avg. test loss = 0.0252, correlation = 0.0782, p-value = 0.6813
# 30
# Epoch 20 gene 238 : Avg. test loss = 0.0261, correlation = -0.0237, p-value = 0.9009
# 30
# Epoch 20 gene 239 : Avg. test loss = 0.0068, correlation = -0.1433, p-value = 0.4500
# 30
# Epoch 20 gene 240 : Avg. test loss = 0.0301, correlation = 0.2604, p-value = 0.1646
# 30
# Epoch 20 gene 241 : Avg. test loss = 0.0353, correlation = 0.1010, p-value = 0.5954
# 30
# Epoch 20 gene 242 : Avg. test loss = 0.1777, correlation = -0.1395, p-value = 0.4622
# 30
# Epoch 20 gene 243 : Avg. test loss = 0.0562, correlation = -0.0128, p-value = 0.9465
# 30
# Epoch 20 gene 244 : Avg. test loss = 0.2737, correlation = 0.3153, p-value = 0.0897
# 30
# Epoch 20 gene 245 : Avg. test loss = 0.0096, correlation = -0.1439, p-value = 0.4480
# 30
# Epoch 20 gene 246 : Avg. test loss = 0.4358, correlation = -0.1823, p-value = 0.3351
# 30
# Epoch 20 gene 247 : Avg. test loss = 0.0264, correlation = 0.1016, p-value = 0.5931
# 30
# Epoch 20 gene 248 : Avg. test loss = 0.0194, correlation = -0.1497, p-value = 0.4297
# 30
# Epoch 20 gene 249 : Avg. test loss = 0.0051, correlation = 0.2491, p-value = 0.1844
# 30
# Epoch 20 gene 250 : Avg. test loss = 0.0136, correlation = -0.1310, p-value = 0.4903
# 30
# Epoch 20 gene 251 : Avg. test loss = 0.0281, correlation = -0.2457, p-value = 0.1905
# 30
# Epoch 20 gene 252 : Avg. test loss = 0.0259, correlation = -0.1797, p-value = 0.3420
# 30
# Epoch 20 gene 253 : Avg. test loss = 0.0650, correlation = 0.0768, p-value = 0.6866
# 30
# Epoch 20 gene 254 : Avg. test loss = 0.0151, correlation = -0.0998, p-value = 0.5996
# 30
# Epoch 20 gene 255 : Avg. test loss = 0.0145, correlation = 0.0483, p-value = 0.7998
# 30
# Epoch 20 gene 256 : Avg. test loss = 0.1082, correlation = 0.0075, p-value = 0.9687
# 30
# Epoch 20 gene 257 : Avg. test loss = 0.0137, correlation = -0.0913, p-value = 0.6313
# 30
# Epoch 20 gene 258 : Avg. test loss = 0.0696, correlation = 0.1544, p-value = 0.4151
# 30
# Epoch 20 gene 259 : Avg. test loss = 0.0206, correlation = 0.1635, p-value = 0.3880
# 30
# Epoch 20 gene 260 : Avg. test loss = 0.4478, correlation = 0.4379, p-value = 0.0155
# 30
# Epoch 20 gene 261 : Avg. test loss = 0.0254, correlation = -0.2746, p-value = 0.1420
# 30
# Epoch 20 gene 262 : Avg. test loss = 0.0118, correlation = -0.2718, p-value = 0.1462
# 30
# Epoch 20 gene 263 : Avg. test loss = 2.9202, correlation = 0.1456, p-value = 0.4425
# 30
# Epoch 20 gene 264 : Avg. test loss = 0.0218, correlation = -0.2184, p-value = 0.2462
# 30
# Epoch 20 gene 265 : Avg. test loss = 0.0104, correlation = -0.0114, p-value = 0.9523
# 30
# Epoch 20 gene 266 : Avg. test loss = 0.0210, correlation = 0.0863, p-value = 0.6501
# 30
# Epoch 20 gene 267 : Avg. test loss = 0.0166, correlation = -0.1383, p-value = 0.4662
# 30
# Epoch 20 gene 268 : Avg. test loss = 0.0187, correlation = 0.0840, p-value = 0.6591
# 30
# Epoch 20 gene 269 : Avg. test loss = 0.0139, correlation = -0.0930, p-value = 0.6249
# 30
# Epoch 20 gene 270 : Avg. test loss = 0.0090, correlation = -0.2210, p-value = 0.2405
# 30
# Epoch 20 gene 271 : Avg. test loss = 0.0725, correlation = -0.1683, p-value = 0.3739
# 30
# Epoch 20 gene 272 : Avg. test loss = 0.0089, correlation = 0.0769, p-value = 0.6861
# 30
# Epoch 20 gene 273 : Avg. test loss = 0.0135, correlation = -0.0120, p-value = 0.9497
# 30
# Epoch 20 gene 274 : Avg. test loss = 0.0279, correlation = -0.0401, p-value = 0.8335
# 30
# Epoch 20 gene 275 : Avg. test loss = 0.1275, correlation = 0.1637, p-value = 0.3873
# 30
# Epoch 20 gene 276 : Avg. test loss = 0.0188, correlation = 0.0703, p-value = 0.7122
# 30
# Epoch 20 gene 277 : Avg. test loss = 0.0089, correlation = -0.0226, p-value = 0.9057
# 30
# Epoch 20 gene 278 : Avg. test loss = 0.5492, correlation = 0.1730, p-value = 0.3605
# 30
# Epoch 20 gene 279 : Avg. test loss = 0.0790, correlation = -0.0066, p-value = 0.9726
# 30
# Epoch 20 gene 280 : Avg. test loss = 0.0425, correlation = -0.1203, p-value = 0.5264
# 30
# Epoch 20 gene 281 : Avg. test loss = 0.3465, correlation = -0.2097, p-value = 0.2661
# 30
# Epoch 20 gene 282 : Avg. test loss = 0.0615, correlation = -0.2166, p-value = 0.2503
# 30
# Epoch 20 gene 283 : Avg. test loss = 0.0085, correlation = -0.0195, p-value = 0.9187
# 30
# Epoch 20 gene 284 : Avg. test loss = 0.0545, correlation = 0.1217, p-value = 0.5219
# 30
# Epoch 20 gene 285 : Avg. test loss = 0.0267, correlation = -0.0803, p-value = 0.6733
# 30
# Epoch 20 gene 286 : Avg. test loss = 0.0150, correlation = 0.0960, p-value = 0.6139
# 30
# Epoch 20 gene 287 : Avg. test loss = 0.0053, correlation = -0.1770, p-value = 0.3495
# 30
# Epoch 20 gene 288 : Avg. test loss = 0.0141, correlation = 0.3628, p-value = 0.0488
# 30
# Epoch 20 gene 289 : Avg. test loss = 2.4011, correlation = 0.0392, p-value = 0.8369
# 30
# Epoch 20 gene 290 : Avg. test loss = 0.0100, correlation = -0.1617, p-value = 0.3934
# 30
# Epoch 20 gene 291 : Avg. test loss = 0.0077, correlation = 0.0986, p-value = 0.6042
# 30
# Epoch 20 gene 292 : Avg. test loss = 0.0104, correlation = -0.0199, p-value = 0.9169
# 30
# Epoch 20 gene 293 : Avg. test loss = 2.6194, correlation = -0.0560, p-value = 0.7687
# 30
# Epoch 20 gene 294 : Avg. test loss = 0.0143, correlation = -0.0022, p-value = 0.9907
# 30
# Epoch 20 gene 295 : Avg. test loss = 0.0145, correlation = -0.1172, p-value = 0.5375
# 30
# Epoch 20 gene 296 : Avg. test loss = 0.0170, correlation = 0.1341, p-value = 0.4799
# 30
# Epoch 20 gene 297 : Avg. test loss = 0.0196, correlation = -0.2040, p-value = 0.2795
# 30
# Epoch 20 gene 298 : Avg. test loss = 0.0481, correlation = 0.2063, p-value = 0.2741
# 30
# Epoch 20 gene 299 : Avg. test loss = 0.0070, correlation = 0.1853, p-value = 0.3268
# 30
# Epoch 20 gene 300 : Avg. test loss = 0.0162, correlation = 0.1417, p-value = 0.4550
# 30
# Epoch 20 gene 301 : Avg. test loss = 0.0797, correlation = -0.3115, p-value = 0.0938
# 30
# Epoch 20 gene 302 : Avg. test loss = 0.3056, correlation = -0.2864, p-value = 0.1250
# 30
# Epoch 20 gene 303 : Avg. test loss = 0.1514, correlation = -0.0603, p-value = 0.7514
# 30
# Epoch 20 gene 304 : Avg. test loss = 0.0174, correlation = 0.1785, p-value = 0.3453
# 30
# Epoch 20 gene 305 : Avg. test loss = 0.0447, correlation = -0.0737, p-value = 0.6986
# 30
# Epoch 20 gene 306 : Avg. test loss = 0.0112, correlation = 0.1096, p-value = 0.5641
# 30
# Epoch 20 gene 307 : Avg. test loss = 0.0103, correlation = -0.1107, p-value = 0.5605
# 30
# Epoch 20 gene 308 : Avg. test loss = 0.0539, correlation = 0.1709, p-value = 0.3665
# 30
# Epoch 20 gene 309 : Avg. test loss = 3.1370, correlation = 0.0353, p-value = 0.8532
# 30
# Epoch 20 gene 310 : Avg. test loss = 0.0197, correlation = 0.1461, p-value = 0.4410
# 30
# Epoch 20 gene 311 : Avg. test loss = 0.8391, correlation = -0.0439, p-value = 0.8180
# 30
# Epoch 20 gene 312 : Avg. test loss = 0.0144, correlation = 0.0477, p-value = 0.8024
# 30
# Epoch 20 gene 313 : Avg. test loss = 0.0144, correlation = 0.1782, p-value = 0.3461
# 30
# Epoch 20 gene 314 : Avg. test loss = 0.0219, correlation = -0.0426, p-value = 0.8231
# 30
# Epoch 20 gene 315 : Avg. test loss = 0.0282, correlation = -0.0743, p-value = 0.6965
# 30
# Epoch 20 gene 316 : Avg. test loss = 0.0815, correlation = -0.0750, p-value = 0.6935
# 30
# Epoch 20 gene 317 : Avg. test loss = 0.0102, correlation = 0.1779, p-value = 0.3469
# 30
# Epoch 20 gene 318 : Avg. test loss = 0.0962, correlation = -0.0797, p-value = 0.6753
# 30
# Epoch 20 gene 319 : Avg. test loss = 0.0135, correlation = 0.1602, p-value = 0.3976
# 30
# Epoch 20 gene 320 : Avg. test loss = 0.0239, correlation = -0.1587, p-value = 0.4022
# 30
# Epoch 20 gene 321 : Avg. test loss = 0.0444, correlation = -0.1775, p-value = 0.3479
# 30
# Epoch 20 gene 322 : Avg. test loss = 0.0659, correlation = -0.0280, p-value = 0.8834
# 30
# Epoch 20 gene 323 : Avg. test loss = 0.0180, correlation = 0.2301, p-value = 0.2212
# 30
# Epoch 20 gene 324 : Avg. test loss = 0.0111, correlation = 0.0066, p-value = 0.9725
# 30
# Epoch 20 gene 325 : Avg. test loss = 0.0247, correlation = 0.4198, p-value = 0.0209
# 30
# Epoch 20 gene 326 : Avg. test loss = 0.9542, correlation = 0.0609, p-value = 0.7493
# 30
# Epoch 20 gene 327 : Avg. test loss = 0.0134, correlation = -0.0835, p-value = 0.6610
# 30
# Epoch 20 gene 328 : Avg. test loss = 0.4622, correlation = 0.0644, p-value = 0.7352
# 30
# Epoch 20 gene 329 : Avg. test loss = 0.1416, correlation = -0.1061, p-value = 0.5770
# 30
# Epoch 20 gene 330 : Avg. test loss = 0.0166, correlation = -0.0968, p-value = 0.6108
# 30
# Epoch 20 gene 331 : Avg. test loss = 0.0479, correlation = -0.3262, p-value = 0.0786
# 30
# Epoch 20 gene 332 : Avg. test loss = 0.0157, correlation = -0.0338, p-value = 0.8591
# 30
# Epoch 20 gene 333 : Avg. test loss = 0.0614, correlation = 0.3364, p-value = 0.0691
# 30
# Epoch 20 gene 334 : Avg. test loss = 0.0330, correlation = -0.2023, p-value = 0.2836
# 30
# Epoch 20 gene 335 : Avg. test loss = 0.0057, correlation = 0.0586, p-value = 0.7585
# 30
# Epoch 20 gene 336 : Avg. test loss = 0.0101, correlation = -0.1369, p-value = 0.4708
# 30
# Epoch 20 gene 337 : Avg. test loss = 0.0046, correlation = -0.2216, p-value = 0.2393
# 30
# Epoch 20 gene 338 : Avg. test loss = 0.1398, correlation = 0.0025, p-value = 0.9894
# 30
# Epoch 20 gene 339 : Avg. test loss = 0.0267, correlation = -0.0350, p-value = 0.8543
# 30
# Epoch 20 gene 340 : Avg. test loss = 0.0484, correlation = 0.1471, p-value = 0.4378
# 30
# Epoch 20 gene 341 : Avg. test loss = 0.0071, correlation = -0.0047, p-value = 0.9802
# 30
# Epoch 20 gene 342 : Avg. test loss = 0.0559, correlation = 0.0041, p-value = 0.9828
# 30
# Epoch 20 gene 343 : Avg. test loss = 0.0203, correlation = 0.2977, p-value = 0.1101
# 30
# Epoch 20 gene 344 : Avg. test loss = 0.0062, correlation = -0.1294, p-value = 0.4956
# 30
# Epoch 20 gene 345 : Avg. test loss = 0.0206, correlation = 0.2023, p-value = 0.2836
# 30
# Epoch 20 gene 346 : Avg. test loss = 0.2753, correlation = 0.0774, p-value = 0.6844
# 30
# Epoch 20 gene 347 : Avg. test loss = 0.0152, correlation = -0.0348, p-value = 0.8551
# 30
# Epoch 20 gene 348 : Avg. test loss = 0.0580, correlation = -0.3307, p-value = 0.0743
# 30
# Epoch 20 gene 349 : Avg. test loss = 0.0787, correlation = 0.1584, p-value = 0.4032
# 30
# Epoch 20 gene 350 : Avg. test loss = 0.0148, correlation = -0.2654, p-value = 0.1564
# 30
# Epoch 20 gene 351 : Avg. test loss = 0.5465, correlation = -0.2901, p-value = 0.1199
# 30
# Epoch 20 gene 352 : Avg. test loss = 0.0490, correlation = -0.0220, p-value = 0.9083
# 30
# Epoch 20 gene 353 : Avg. test loss = 0.0069, correlation = -0.2178, p-value = 0.2476
# 30
# Epoch 20 gene 354 : Avg. test loss = 0.0107, correlation = -0.3027, p-value = 0.1040
# 30
# Epoch 20 gene 355 : Avg. test loss = 0.0887, correlation = -0.2368, p-value = 0.2078
# 30
# Epoch 20 gene 356 : Avg. test loss = 0.0139, correlation = 0.0243, p-value = 0.8984
# 30
# Epoch 20 gene 357 : Avg. test loss = 0.0143, correlation = 0.0558, p-value = 0.7695
# 30
# Epoch 20 gene 358 : Avg. test loss = 2.1960, correlation = 0.1995, p-value = 0.2906
# 30
# Epoch 20 gene 359 : Avg. test loss = 0.3376, correlation = -0.0917, p-value = 0.6297
# 30
# Epoch 20 gene 360 : Avg. test loss = 0.0041, correlation = -0.1936, p-value = 0.3054
# 30
# Epoch 20 gene 361 : Avg. test loss = 0.0141, correlation = -0.1461, p-value = 0.4410
# 30
# Epoch 20 gene 362 : Avg. test loss = 0.0998, correlation = 0.1947, p-value = 0.3024
# 30
# Epoch 20 gene 363 : Avg. test loss = 0.0157, correlation = -0.2226, p-value = 0.2371
# 30
# Epoch 20 gene 364 : Avg. test loss = 0.0257, correlation = -0.3422, p-value = 0.0642
# 30
# Epoch 20 gene 365 : Avg. test loss = 0.0870, correlation = -0.2125, p-value = 0.2596
# 30
# Epoch 20 gene 366 : Avg. test loss = 9.1368, correlation = 0.0377, p-value = 0.8433
# 30
# Epoch 20 gene 367 : Avg. test loss = 0.2073, correlation = 0.1250, p-value = 0.5103
# 30
# Epoch 20 gene 368 : Avg. test loss = 0.0469, correlation = -0.0225, p-value = 0.9060
# 30
# Epoch 20 gene 369 : Avg. test loss = 0.1083, correlation = -0.3993, p-value = 0.0288
# 30
# Epoch 20 gene 370 : Avg. test loss = 0.0509, correlation = -0.0432, p-value = 0.8206
# 30
# Epoch 20 gene 371 : Avg. test loss = 0.0151, correlation = 0.2130, p-value = 0.2584
# 30
# Epoch 20 gene 372 : Avg. test loss = 1.4178, correlation = -0.2160, p-value = 0.2515
# 30
# Epoch 20 gene 373 : Avg. test loss = 0.0175, correlation = 0.1336, p-value = 0.4814
# 30
# Epoch 20 gene 374 : Avg. test loss = 0.0073, correlation = -0.1058, p-value = 0.5778
# 30
# Epoch 20 gene 375 : Avg. test loss = 0.3588, correlation = -0.1596, p-value = 0.3995
# 30
# Epoch 20 gene 376 : Avg. test loss = 0.0641, correlation = -0.1947, p-value = 0.3026
# 30
# Epoch 20 gene 377 : Avg. test loss = 0.1002, correlation = 0.0884, p-value = 0.6424
# 30
# Epoch 20 gene 378 : Avg. test loss = 0.1721, correlation = 0.0433, p-value = 0.8201
# 30
# Epoch 20 gene 379 : Avg. test loss = 0.3810, correlation = -0.1201, p-value = 0.5272
# 30
# Epoch 20 gene 380 : Avg. test loss = 0.0691, correlation = -0.1985, p-value = 0.2930
# 30
# Epoch 20 gene 381 : Avg. test loss = 0.0115, correlation = 0.1368, p-value = 0.4709
# 30
# Epoch 20 gene 382 : Avg. test loss = 0.2698, correlation = 0.1126, p-value = 0.5536
# 30
# Epoch 20 gene 383 : Avg. test loss = 0.0157, correlation = -0.1526, p-value = 0.4207
# 30
# Epoch 20 gene 384 : Avg. test loss = 0.0356, correlation = 0.5277, p-value = 0.0027
# 30
# Epoch 20 gene 385 : Avg. test loss = 0.0205, correlation = 0.0115, p-value = 0.9517
# 30
# Epoch 20 gene 386 : Avg. test loss = 0.0091, correlation = 0.2176, p-value = 0.2481
# 30
# Epoch 20 gene 387 : Avg. test loss = 0.0233, correlation = 0.1730, p-value = 0.3606
# 30
# Epoch 20 gene 388 : Avg. test loss = 0.0274, correlation = 0.0259, p-value = 0.8918
# 30
# Epoch 20 gene 389 : Avg. test loss = 0.4591, correlation = 0.0226, p-value = 0.9057
# 30
# Epoch 20 gene 390 : Avg. test loss = 0.2658, correlation = 0.3250, p-value = 0.0797
# 30
# Epoch 20 gene 391 : Avg. test loss = 0.0135, correlation = 0.0864, p-value = 0.6499
# 30
# Epoch 20 gene 392 : Avg. test loss = 0.0188, correlation = -0.1757, p-value = 0.3531
# 30
# Epoch 20 gene 393 : Avg. test loss = 0.0211, correlation = -0.0227, p-value = 0.9051
# 30
# Epoch 20 gene 394 : Avg. test loss = 0.3029, correlation = -0.0477, p-value = 0.8026
# 30
# Epoch 20 gene 395 : Avg. test loss = 0.0053, correlation = 0.0840, p-value = 0.6589
# 30
# Epoch 20 gene 396 : Avg. test loss = 0.0188, correlation = -0.0363, p-value = 0.8488
# 30
# Epoch 20 gene 397 : Avg. test loss = 0.1978, correlation = -0.3540, p-value = 0.0550
# 30
# Epoch 20 gene 398 : Avg. test loss = 0.0467, correlation = 0.1413, p-value = 0.4565
# 30
# Epoch 20 gene 399 : Avg. test loss = 0.6120, correlation = -0.1813, p-value = 0.3376
# 30
# Epoch 20 gene 400 : Avg. test loss = 0.0107, correlation = 0.1571, p-value = 0.4070
# 30
# Epoch 20 gene 401 : Avg. test loss = 0.0053, correlation = -0.2067, p-value = 0.2731
# 30
# Epoch 20 gene 402 : Avg. test loss = 0.0122, correlation = -0.1242, p-value = 0.5131
# 30
# Epoch 20 gene 403 : Avg. test loss = 0.2020, correlation = -0.1381, p-value = 0.4667
# 30
# Epoch 20 gene 404 : Avg. test loss = 0.0064, correlation = -0.2354, p-value = 0.2105
# 30
# Epoch 20 gene 405 : Avg. test loss = 0.0244, correlation = 0.1340, p-value = 0.4803
# 30
# Epoch 20 gene 406 : Avg. test loss = 0.0127, correlation = -0.4284, p-value = 0.0182
# 30
# Epoch 20 gene 407 : Avg. test loss = 0.2083, correlation = 0.1288, p-value = 0.4977
# 30
# Epoch 20 gene 408 : Avg. test loss = 0.3998, correlation = 0.1863, p-value = 0.3244
# 30
# Epoch 20 gene 409 : Avg. test loss = 0.0132, correlation = 0.2531, p-value = 0.1772
# 30
# Epoch 20 gene 410 : Avg. test loss = 0.0212, correlation = 0.2178, p-value = 0.2475
# 30
# Epoch 20 gene 411 : Avg. test loss = 0.1844, correlation = 0.2536, p-value = 0.1764
# 30
# Epoch 20 gene 412 : Avg. test loss = 0.0074, correlation = -0.3051, p-value = 0.1012
# 30
# Epoch 20 gene 413 : Avg. test loss = 0.0393, correlation = -0.1333, p-value = 0.4824
# 30
# Epoch 20 gene 414 : Avg. test loss = 0.4690, correlation = 0.3137, p-value = 0.0914
# 30
# Epoch 20 gene 415 : Avg. test loss = 0.0544, correlation = -0.0330, p-value = 0.8627
# 30
# Epoch 20 gene 416 : Avg. test loss = 0.0058, correlation = -0.1964, p-value = 0.2982
# 30
# Epoch 20 gene 417 : Avg. test loss = 0.0115, correlation = 0.1432, p-value = 0.4505
# 30
# Epoch 20 gene 418 : Avg. test loss = 0.0660, correlation = -0.0465, p-value = 0.8071
# 30
# Epoch 20 gene 419 : Avg. test loss = 0.0060, correlation = 0.0881, p-value = 0.6435
# 30
# Epoch 20 gene 420 : Avg. test loss = 0.0095, correlation = -0.0669, p-value = 0.7253
# 30
# Epoch 20 gene 421 : Avg. test loss = 0.2478, correlation = -0.2191, p-value = 0.2447
# 30
# Epoch 20 gene 422 : Avg. test loss = 0.0620, correlation = -0.0029, p-value = 0.9879
# 30
# Epoch 20 gene 423 : Avg. test loss = 0.0357, correlation = 0.0525, p-value = 0.7830
# 30
# Epoch 20 gene 424 : Avg. test loss = 0.0179, correlation = -0.1709, p-value = 0.3666
# 30
# Epoch 20 gene 425 : Avg. test loss = 0.0105, correlation = -0.1509, p-value = 0.4260
# 30
# Epoch 20 gene 426 : Avg. test loss = 0.0704, correlation = -0.3690, p-value = 0.0448
# 30
# Epoch 20 gene 427 : Avg. test loss = 2.7194, correlation = -0.3382, p-value = 0.0676
# 30
# Epoch 20 gene 428 : Avg. test loss = 0.0739, correlation = 0.0416, p-value = 0.8272
# 30
# Epoch 20 gene 429 : Avg. test loss = 0.0368, correlation = -0.0653, p-value = 0.7316
# 30
# Epoch 20 gene 430 : Avg. test loss = 0.0070, correlation = 0.0295, p-value = 0.8768
# 30
# Epoch 20 gene 431 : Avg. test loss = 0.0063, correlation = -0.1329, p-value = 0.4838
# 30
# Epoch 20 gene 432 : Avg. test loss = 0.0080, correlation = -0.1565, p-value = 0.4089
# 30
# Epoch 20 gene 433 : Avg. test loss = 0.0865, correlation = 0.0298, p-value = 0.8757
# 30
# Epoch 20 gene 434 : Avg. test loss = 0.3370, correlation = 0.2012, p-value = 0.2863
# 30
# Epoch 20 gene 435 : Avg. test loss = 0.0391, correlation = -0.0829, p-value = 0.6632
# 30
# Epoch 20 gene 436 : Avg. test loss = 0.0323, correlation = -0.1659, p-value = 0.3809
# 30
# Epoch 20 gene 437 : Avg. test loss = 2.2876, correlation = -0.1191, p-value = 0.5309
# 30
# Epoch 20 gene 438 : Avg. test loss = 0.0118, correlation = 0.1290, p-value = 0.4969
# 30
# Epoch 20 gene 439 : Avg. test loss = 0.0133, correlation = 0.0631, p-value = 0.7405
# 30
# Epoch 20 gene 440 : Avg. test loss = 0.0183, correlation = 0.0295, p-value = 0.8770
# 30
# Epoch 20 gene 441 : Avg. test loss = 0.0416, correlation = -0.2268, p-value = 0.2282
# 30
# Epoch 20 gene 442 : Avg. test loss = 0.1148, correlation = 0.0848, p-value = 0.6561
# 30
# Epoch 20 gene 443 : Avg. test loss = 0.0200, correlation = 0.0361, p-value = 0.8500
# 30
# Epoch 20 gene 444 : Avg. test loss = 0.0427, correlation = -0.0561, p-value = 0.7683
# 30
# Epoch 20 gene 445 : Avg. test loss = 0.0035, correlation = 0.1878, p-value = 0.3204
# 30
# Epoch 20 gene 446 : Avg. test loss = 2.7391, correlation = -0.0047, p-value = 0.9802
# 30
# Epoch 20 gene 447 : Avg. test loss = 0.0048, correlation = -0.0955, p-value = 0.6157
# 30
# Epoch 20 gene 448 : Avg. test loss = 1.3024, correlation = 0.0083, p-value = 0.9654
# 30
# Epoch 20 gene 449 : Avg. test loss = 0.0218, correlation = -0.1368, p-value = 0.4709
# 30
# Epoch 20 gene 450 : Avg. test loss = 0.0149, correlation = 0.0373, p-value = 0.8449
# 30
# Epoch 20 gene 451 : Avg. test loss = 0.1034, correlation = 0.1095, p-value = 0.5644
# 30
# Epoch 20 gene 452 : Avg. test loss = 0.0395, correlation = -0.3074, p-value = 0.0985
# 30
# Epoch 20 gene 453 : Avg. test loss = 0.0302, correlation = -0.2840, p-value = 0.1283
# 30
# Epoch 20 gene 454 : Avg. test loss = 0.0153, correlation = -0.2464, p-value = 0.1894
# 30
# Epoch 20 gene 455 : Avg. test loss = 0.0105, correlation = -0.4596, p-value = 0.0106
# 30
# Epoch 20 gene 456 : Avg. test loss = 1.1796, correlation = -0.1552, p-value = 0.4129
# 30
# Epoch 20 gene 457 : Avg. test loss = 0.0744, correlation = 0.2553, p-value = 0.1734
# 30
# Epoch 20 gene 458 : Avg. test loss = 0.0408, correlation = 0.0490, p-value = 0.7971
# 30
# Epoch 20 gene 459 : Avg. test loss = 0.6811, correlation = 0.0259, p-value = 0.8919
# 30
# Epoch 20 gene 460 : Avg. test loss = 0.0067, correlation = 0.0704, p-value = 0.7116
# 30
# Epoch 20 gene 461 : Avg. test loss = 0.0117, correlation = -0.4084, p-value = 0.0251
# 30
# Epoch 20 gene 462 : Avg. test loss = 0.0086, correlation = 0.3463, p-value = 0.0609
# 30
# Epoch 20 gene 463 : Avg. test loss = 0.0081, correlation = -0.1537, p-value = 0.4175
# 30
# Epoch 20 gene 464 : Avg. test loss = 0.0110, correlation = 0.0261, p-value = 0.8909
# 30
# Epoch 20 gene 465 : Avg. test loss = 0.0211, correlation = 0.1530, p-value = 0.4196
# 30
# Epoch 20 gene 466 : Avg. test loss = 0.0304, correlation = -0.0057, p-value = 0.9760
# 30
# Epoch 20 gene 467 : Avg. test loss = 0.0259, correlation = 0.1840, p-value = 0.3303
# 30
# Epoch 20 gene 468 : Avg. test loss = 0.0048, correlation = 0.3149, p-value = 0.0901
# 30
# Epoch 20 gene 469 : Avg. test loss = 0.1776, correlation = 0.0003, p-value = 0.9988
# 30
# Epoch 20 gene 470 : Avg. test loss = 0.0139, correlation = 0.2548, p-value = 0.1743
# 30
# Epoch 20 gene 471 : Avg. test loss = 0.0163, correlation = -0.1386, p-value = 0.4651
# 30
# Epoch 20 gene 472 : Avg. test loss = 0.0450, correlation = -0.2860, p-value = 0.1255
# 30
# Epoch 20 gene 473 : Avg. test loss = 0.1196, correlation = -0.3162, p-value = 0.0887
# 30
# Epoch 20 gene 474 : Avg. test loss = 0.0093, correlation = 0.3513, p-value = 0.0570
# 30
# Epoch 20 gene 475 : Avg. test loss = 0.0075, correlation = 0.0116, p-value = 0.9516
# 30
# Epoch 20 gene 476 : Avg. test loss = 0.0241, correlation = 0.1315, p-value = 0.4887
# 30
# Epoch 20 gene 477 : Avg. test loss = 1.2530, correlation = 0.3196, p-value = 0.0851
# 30
# Epoch 20 gene 478 : Avg. test loss = 0.0434, correlation = 0.1170, p-value = 0.5379
# 30
# Epoch 20 gene 479 : Avg. test loss = 0.6528, correlation = -0.1756, p-value = 0.3533
# 30
# Epoch 20 gene 480 : Avg. test loss = 0.0134, correlation = 0.0793, p-value = 0.6771
# 30
# Epoch 20 gene 481 : Avg. test loss = 0.0158, correlation = -0.0263, p-value = 0.8902
# 30
# Epoch 20 gene 482 : Avg. test loss = 0.0088, correlation = -0.1348, p-value = 0.4776
# 30
# Epoch 20 gene 483 : Avg. test loss = 0.0085, correlation = -0.0520, p-value = 0.7848
# 30
# Epoch 20 gene 484 : Avg. test loss = 0.0142, correlation = 0.0191, p-value = 0.9201
# 30
# Epoch 20 gene 485 : Avg. test loss = 0.0236, correlation = 0.1515, p-value = 0.4243
# 30
# Epoch 20 gene 486 : Avg. test loss = 0.0174, correlation = -0.0987, p-value = 0.6040
# 30
# Epoch 20 gene 487 : Avg. test loss = 1.0592, correlation = 0.0970, p-value = 0.6100
# 30
# Epoch 20 gene 488 : Avg. test loss = 6.6529, correlation = -0.2060, p-value = 0.2748
# 30
# Epoch 20 gene 489 : Avg. test loss = 0.0090, correlation = 0.0115, p-value = 0.9517
# 30
# Epoch 20 gene 490 : Avg. test loss = 1.2409, correlation = -0.3903, p-value = 0.0330
# 30
# Epoch 20 gene 491 : Avg. test loss = 0.0078, correlation = 0.1350, p-value = 0.4769
# 30
# Epoch 20 gene 492 : Avg. test loss = 0.0165, correlation = -0.1126, p-value = 0.5537
# 30
# Epoch 20 gene 493 : Avg. test loss = 0.0354, correlation = 0.0667, p-value = 0.7262
# 30
# Epoch 20 gene 494 : Avg. test loss = 0.0081, correlation = -0.0416, p-value = 0.8272
# 30
# Epoch 20 gene 495 : Avg. test loss = 0.0408, correlation = 0.1457, p-value = 0.4423
# 30
# Epoch 20 gene 496 : Avg. test loss = 0.0034, correlation = -0.1014, p-value = 0.5940
# 30
# Epoch 20 gene 497 : Avg. test loss = 0.0049, correlation = 0.1631, p-value = 0.3891
# 30
# Epoch 20 gene 498 : Avg. test loss = 0.0066, correlation = 0.1027, p-value = 0.5893
# 30
# Epoch 20 gene 499 : Avg. test loss = 0.0219, correlation = -0.1024, p-value = 0.5901
# 30
# Epoch 20 gene 500 : Avg. test loss = 0.0206, correlation = 0.0534, p-value = 0.7791
# 30
# Epoch 20 gene 501 : Avg. test loss = 0.0086, correlation = -0.0150, p-value = 0.9373
# 30
# Epoch 20 gene 502 : Avg. test loss = 0.0081, correlation = -0.1043, p-value = 0.5835
# 30
# Epoch 20 gene 503 : Avg. test loss = 0.0288, correlation = -0.3191, p-value = 0.0857
# 30
# Epoch 20 gene 504 : Avg. test loss = 0.0094, correlation = 0.0301, p-value = 0.8746
# 30
# Epoch 20 gene 505 : Avg. test loss = 0.0157, correlation = -0.0933, p-value = 0.6238
# 30
# Epoch 20 gene 506 : Avg. test loss = 2.3236, correlation = 0.1999, p-value = 0.2896
# 30
# Epoch 20 gene 507 : Avg. test loss = 0.0287, correlation = -0.2677, p-value = 0.1527
# 30
# Epoch 20 gene 508 : Avg. test loss = 0.0257, correlation = -0.0565, p-value = 0.7670
# 30
# Epoch 20 gene 509 : Avg. test loss = 0.0091, correlation = -0.1358, p-value = 0.4742
# 30
# Epoch 20 gene 510 : Avg. test loss = 0.0358, correlation = 0.1728, p-value = 0.3612
# 30
# Epoch 20 gene 511 : Avg. test loss = 0.0175, correlation = 0.1250, p-value = 0.5105
# 30
# Epoch 20 gene 512 : Avg. test loss = 0.0031, correlation = 0.1492, p-value = 0.4315
# 30
# Epoch 20 gene 513 : Avg. test loss = 0.4702, correlation = -0.1629, p-value = 0.3897
# 30
# Epoch 20 gene 514 : Avg. test loss = 0.0198, correlation = 0.2000, p-value = 0.2894
# 30
# Epoch 20 gene 515 : Avg. test loss = 0.6091, correlation = -0.0395, p-value = 0.8360
# 30
# Epoch 20 gene 516 : Avg. test loss = 0.0231, correlation = -0.0629, p-value = 0.7414
# 30
# Epoch 20 gene 517 : Avg. test loss = 0.1406, correlation = 0.0677, p-value = 0.7223
# 30
# Epoch 20 gene 518 : Avg. test loss = 0.0116, correlation = 0.0153, p-value = 0.9361
# 30
# Epoch 20 gene 519 : Avg. test loss = 0.0135, correlation = 0.1327, p-value = 0.4847
# 30
# Epoch 20 gene 520 : Avg. test loss = 0.0054, correlation = -0.0979, p-value = 0.6069
# 30
# Epoch 20 gene 521 : Avg. test loss = 0.0189, correlation = -0.0143, p-value = 0.9404
# 30
# Epoch 20 gene 522 : Avg. test loss = 0.0146, correlation = -0.1678, p-value = 0.3754
# 30
# Epoch 20 gene 523 : Avg. test loss = 0.0170, correlation = -0.1294, p-value = 0.4954
# 30
# Epoch 20 gene 524 : Avg. test loss = 0.0069, correlation = 0.0375, p-value = 0.8439
# 30
# Epoch 20 gene 525 : Avg. test loss = 0.0356, correlation = 0.2593, p-value = 0.1664
# 30
# Epoch 20 gene 526 : Avg. test loss = 0.0102, correlation = -0.0015, p-value = 0.9936
# 30
# Epoch 20 gene 527 : Avg. test loss = 0.0278, correlation = 0.1825, p-value = 0.3345
# 30
# Epoch 20 gene 528 : Avg. test loss = 0.1538, correlation = 0.1085, p-value = 0.5681
# 30
# Epoch 20 gene 529 : Avg. test loss = 0.0066, correlation = 0.1742, p-value = 0.3572
# 30
# Epoch 20 gene 530 : Avg. test loss = 0.0714, correlation = -0.3862, p-value = 0.0351
# 30
# Epoch 20 gene 531 : Avg. test loss = 0.0143, correlation = -0.1161, p-value = 0.5412
# 30
# Epoch 20 gene 532 : Avg. test loss = 2.9557, correlation = -0.1227, p-value = 0.5182
# 30
# Epoch 20 gene 533 : Avg. test loss = 0.0609, correlation = 0.2523, p-value = 0.1787
# 30
# Epoch 20 gene 534 : Avg. test loss = 0.0066, correlation = 0.1106, p-value = 0.5607
# 30
# Epoch 20 gene 535 : Avg. test loss = 0.0099, correlation = 0.1674, p-value = 0.3765
# 30
# Epoch 20 gene 536 : Avg. test loss = 0.0124, correlation = 0.1142, p-value = 0.5480
# 30
# Epoch 20 gene 537 : Avg. test loss = 0.0056, correlation = -0.0006, p-value = 0.9976
# 30
# Epoch 20 gene 538 : Avg. test loss = 0.0232, correlation = 0.1094, p-value = 0.5649
# 30
# Epoch 20 gene 539 : Avg. test loss = 0.0071, correlation = 0.1444, p-value = 0.4464
# 30
# Epoch 20 gene 540 : Avg. test loss = 0.0151, correlation = -0.0454, p-value = 0.8117
# 30
# Epoch 20 gene 541 : Avg. test loss = 0.0601, correlation = 0.2586, p-value = 0.1677
# 30
# Epoch 20 gene 542 : Avg. test loss = 0.0303, correlation = 0.0818, p-value = 0.6675
# 30
# Epoch 20 gene 543 : Avg. test loss = 0.1975, correlation = 0.1088, p-value = 0.5673
# 30
# Epoch 20 gene 544 : Avg. test loss = 0.2423, correlation = 0.0128, p-value = 0.9465
# 30
# Epoch 20 gene 545 : Avg. test loss = 0.0295, correlation = 0.0424, p-value = 0.8238
# 30
# Epoch 20 gene 546 : Avg. test loss = 0.0176, correlation = -0.0767, p-value = 0.6870
# 30
# Epoch 20 gene 547 : Avg. test loss = 0.0299, correlation = -0.1055, p-value = 0.5791
# 30
# ...
# 971
# Epoch 20 gene 23 : Avg. test loss = 0.0424, correlation = -0.0347, p-value = 0.2799
# 971
# Epoch 20 gene 24 : Avg. test loss = 0.0144, correlation = 0.0205, p-value = 0.5243
# 971
# Epoch 20 gene 25 : Avg. test loss = 0.0113, correlation = -0.0113, p-value = 0.7245
# 971
# Epoch 20 gene 26 : Avg. test loss = 0.0567, correlation = -0.0482, p-value = 0.1332
# 971
# Epoch 20 gene 27 : Avg. test loss = 0.0780, correlation = 0.0070, p-value = 0.8264
# 971
# Epoch 20 gene 28 : Avg. test loss = 0.0235, correlation = -0.0207, p-value = 0.5184
# 971
# Epoch 20 gene 29 : Avg. test loss = 0.0115, correlation = 0.0151, p-value = 0.6394
# 971
# Epoch 20 gene 30 : Avg. test loss = 0.0129, correlation = -0.0432, p-value = 0.1785
# 971
# Epoch 20 gene 31 : Avg. test loss = 0.0228, correlation = 0.0348, p-value = 0.2784
# 971
# Epoch 20 gene 32 : Avg. test loss = 0.0119, correlation = -0.0041, p-value = 0.8987
# 971
# Epoch 20 gene 33 : Avg. test loss = 0.0091, correlation = 0.0325, p-value = 0.3120
# 971
# Epoch 20 gene 34 : Avg. test loss = 0.0683, correlation = 0.0155, p-value = 0.6297
# 971
# Epoch 20 gene 35 : Avg. test loss = 0.0059, correlation = 0.0514, p-value = 0.1096
# 971
# Epoch 20 gene 36 : Avg. test loss = 0.0382, correlation = 0.0395, p-value = 0.2189
# 971
# Epoch 20 gene 37 : Avg. test loss = 0.8527, correlation = 0.0182, p-value = 0.5704
# 971
# Epoch 20 gene 38 : Avg. test loss = 0.0123, correlation = -0.0099, p-value = 0.7582
# 971
# Epoch 20 gene 39 : Avg. test loss = 0.1880, correlation = -0.0268, p-value = 0.4034
# 971
# Epoch 20 gene 40 : Avg. test loss = 0.1215, correlation = -0.0481, p-value = 0.1341
# 971
# Epoch 20 gene 41 : Avg. test loss = 0.0116, correlation = 0.0009, p-value = 0.9786
# 971
# Epoch 20 gene 42 : Avg. test loss = 0.0105, correlation = -0.0055, p-value = 0.8650
# 971
# Epoch 20 gene 43 : Avg. test loss = 0.0097, correlation = -0.0022, p-value = 0.9460
# 971
# Epoch 20 gene 44 : Avg. test loss = 0.0147, correlation = 0.0128, p-value = 0.6910
# 971
# Epoch 20 gene 45 : Avg. test loss = 0.2425, correlation = -0.0407, p-value = 0.2049
# 971
# Epoch 20 gene 46 : Avg. test loss = 0.0057, correlation = 0.0382, p-value = 0.2347
# 971
# Epoch 20 gene 47 : Avg. test loss = 0.0314, correlation = 0.0446, p-value = 0.1652
# 971
# Epoch 20 gene 48 : Avg. test loss = 0.0994, correlation = -0.0043, p-value = 0.8932
# 971
# Epoch 20 gene 49 : Avg. test loss = 0.0654, correlation = 0.0128, p-value = 0.6900
# 971
# Epoch 20 gene 50 : Avg. test loss = 0.0103, correlation = 0.0051, p-value = 0.8746
# 971
# Epoch 20 gene 51 : Avg. test loss = 0.0195, correlation = 0.0261, p-value = 0.4161
# 971
# Epoch 20 gene 52 : Avg. test loss = 0.0610, correlation = -0.0251, p-value = 0.4350
# 971
# Epoch 20 gene 53 : Avg. test loss = 0.0258, correlation = 0.0575, p-value = 0.0733
# 971
# Epoch 20 gene 54 : Avg. test loss = 0.0200, correlation = -0.0275, p-value = 0.3920
# 971
# Epoch 20 gene 55 : Avg. test loss = 0.6917, correlation = 0.0379, p-value = 0.2386
# 971
# Epoch 20 gene 56 : Avg. test loss = 0.0134, correlation = -0.0173, p-value = 0.5912
# 971
# Epoch 20 gene 57 : Avg. test loss = 0.0097, correlation = -0.0289, p-value = 0.3692
# 971
# Epoch 20 gene 58 : Avg. test loss = 0.0807, correlation = 0.0002, p-value = 0.9947
# 971
# Epoch 20 gene 59 : Avg. test loss = 0.0193, correlation = -0.0016, p-value = 0.9613
# 971
# Epoch 20 gene 60 : Avg. test loss = 0.0134, correlation = -0.0583, p-value = 0.0695
# 971
# Epoch 20 gene 61 : Avg. test loss = 0.0166, correlation = 0.0107, p-value = 0.7394
# 971
# Epoch 20 gene 62 : Avg. test loss = 0.0344, correlation = 0.0264, p-value = 0.4119
# 971
# Epoch 20 gene 63 : Avg. test loss = 8.8410, correlation = 0.0068, p-value = 0.8334
# 971
# Epoch 20 gene 64 : Avg. test loss = 0.0465, correlation = -0.0161, p-value = 0.6174
# 971
# Epoch 20 gene 65 : Avg. test loss = 0.0151, correlation = -0.0591, p-value = 0.0655
# 971
# Epoch 20 gene 66 : Avg. test loss = 0.1003, correlation = 0.0045, p-value = 0.8887
# 971
# Epoch 20 gene 67 : Avg. test loss = 0.0317, correlation = 0.0232, p-value = 0.4698
# 971
# Epoch 20 gene 68 : Avg. test loss = 0.0145, correlation = 0.0141, p-value = 0.6609
# 971
# Epoch 20 gene 69 : Avg. test loss = 2.1889, correlation = -0.0355, p-value = 0.2696
# 971
# Epoch 20 gene 70 : Avg. test loss = 0.0201, correlation = -0.0301, p-value = 0.3487
# 971
# Epoch 20 gene 71 : Avg. test loss = 0.3253, correlation = -0.0134, p-value = 0.6773
# 971
# Epoch 20 gene 72 : Avg. test loss = 0.0186, correlation = -0.0349, p-value = 0.2773
# 971
# Epoch 20 gene 73 : Avg. test loss = 0.0777, correlation = -0.0295, p-value = 0.3589
# 971
# Epoch 20 gene 74 : Avg. test loss = 1.8104, correlation = 0.0069, p-value = 0.8303
# 971
# Epoch 20 gene 75 : Avg. test loss = 0.0353, correlation = 0.0219, p-value = 0.4949
# 971
# Epoch 20 gene 76 : Avg. test loss = 0.0231, correlation = 0.0378, p-value = 0.2394
# 971
# Epoch 20 gene 77 : Avg. test loss = 0.1264, correlation = 0.0506, p-value = 0.1152
# 971
# Epoch 20 gene 78 : Avg. test loss = 0.7185, correlation = 0.0057, p-value = 0.8596
# 971
# Epoch 20 gene 79 : Avg. test loss = 0.0154, correlation = -0.0316, p-value = 0.3259
# 971
# Epoch 20 gene 80 : Avg. test loss = 0.0234, correlation = 0.0310, p-value = 0.3339
# 971
# Epoch 20 gene 81 : Avg. test loss = 1.1221, correlation = 0.0193, p-value = 0.5491
# 971
# Epoch 20 gene 82 : Avg. test loss = 0.0118, correlation = -0.0102, p-value = 0.7507
# 971
# Epoch 20 gene 83 : Avg. test loss = 0.0317, correlation = -0.0023, p-value = 0.9431
# 971
# Epoch 20 gene 84 : Avg. test loss = 0.1548, correlation = -0.1081, p-value = 0.0007
# 971
# Epoch 20 gene 85 : Avg. test loss = 0.0420, correlation = -0.0119, p-value = 0.7104
# 971
# Epoch 20 gene 86 : Avg. test loss = 0.0548, correlation = 0.0009, p-value = 0.9783
# 971
# Epoch 20 gene 87 : Avg. test loss = 0.0340, correlation = -0.1129, p-value = 0.0004
# 971
# Epoch 20 gene 88 : Avg. test loss = 0.0266, correlation = -0.0337, p-value = 0.2944
# 971
# Epoch 20 gene 89 : Avg. test loss = 0.0753, correlation = -0.0069, p-value = 0.8302
# 971
# Epoch 20 gene 90 : Avg. test loss = 0.0130, correlation = 0.0448, p-value = 0.1630
# 971
# Epoch 20 gene 91 : Avg. test loss = 0.0270, correlation = 0.0098, p-value = 0.7607
# 971
# Epoch 20 gene 92 : Avg. test loss = 0.0641, correlation = 0.0807, p-value = 0.0118
# 971
# Epoch 20 gene 93 : Avg. test loss = 0.0204, correlation = 0.0864, p-value = 0.0071
# 971
# Epoch 20 gene 94 : Avg. test loss = 0.0200, correlation = 0.0261, p-value = 0.4173
# 971
# Epoch 20 gene 95 : Avg. test loss = 0.0151, correlation = 0.0407, p-value = 0.2047
# 971
# Epoch 20 gene 96 : Avg. test loss = 0.0123, correlation = -0.0258, p-value = 0.4222
# 971
# Epoch 20 gene 97 : Avg. test loss = 0.0215, correlation = -0.0126, p-value = 0.6956
# 971
# Epoch 20 gene 98 : Avg. test loss = 0.0114, correlation = 0.0301, p-value = 0.3496
# 971
# Epoch 20 gene 99 : Avg. test loss = 0.1382, correlation = 0.0175, p-value = 0.5859
# 971
# Epoch 20 gene 100 : Avg. test loss = 0.0799, correlation = 0.0922, p-value = 0.0040
# Metrics for epoch 20 saved to /mnt/data/macaulay/datas/genepedia/B_metrics_epoch_20.csv
# 30
# Epoch 20 gene 1 : Avg. test loss = 0.0062, correlation = -0.1492, p-value = 0.4312
# 30
# Epoch 20 gene 2 : Avg. test loss = 0.0050, correlation = 0.1727, p-value = 0.3614
# 30
# Epoch 20 gene 3 : Avg. test loss = 0.1713, correlation = 0.2033, p-value = 0.2812
# 30
# Epoch 20 gene 4 : Avg. test loss = 0.0655, correlation = -0.1000, p-value = 0.5989
# 30
# Epoch 20 gene 5 : Avg. test loss = 0.0223, correlation = 0.4429, p-value = 0.0142
# 30
# Epoch 20 gene 6 : Avg. test loss = 0.0508, correlation = -0.1089, p-value = 0.5666
# 30
# Epoch 20 gene 7 : Avg. test loss = 0.0179, correlation = 0.0007, p-value = 0.9969
# 30
# Epoch 20 gene 8 : Avg. test loss = 0.0199, correlation = 0.0521, p-value = 0.7847
# 30
# Epoch 20 gene 9 : Avg. test loss = 0.2366, correlation = 0.2308, p-value = 0.2198
# 30
# Epoch 20 gene 10 : Avg. test loss = 0.0248, correlation = -0.1988, p-value = 0.2923
# 30
# Epoch 20 gene 11 : Avg. test loss = 0.0167, correlation = -0.1911, p-value = 0.3118
# 30
# Epoch 20 gene 12 : Avg. test loss = 1.3970, correlation = 0.2940, p-value = 0.1148
# 30
# Epoch 20 gene 13 : Avg. test loss = 0.0075, correlation = -0.0595, p-value = 0.7549
# 30
# Epoch 20 gene 14 : Avg. test loss = 0.0949, correlation = -0.0083, p-value = 0.9654
# 30
# Epoch 20 gene 15 : Avg. test loss = 0.0043, correlation = 0.1657, p-value = 0.3814
# 30
# Epoch 20 gene 16 : Avg. test loss = 0.0195, correlation = 0.1178, p-value = 0.5353
# 30
# Epoch 20 gene 17 : Avg. test loss = 0.0241, correlation = 0.0853, p-value = 0.6542
# 30
# Epoch 20 gene 18 : Avg. test loss = 0.0354, correlation = -0.0682, p-value = 0.7204
# 30
# Epoch 20 gene 19 : Avg. test loss = 0.0918, correlation = 0.1777, p-value = 0.3474
# 30
# Epoch 20 gene 20 : Avg. test loss = 0.1071, correlation = 0.3446, p-value = 0.0622
# 30
# Epoch 20 gene 21 : Avg. test loss = 0.0424, correlation = 0.0365, p-value = 0.8481
# 30
# Epoch 20 gene 22 : Avg. test loss = 0.0084, correlation = -0.2407, p-value = 0.2001
# 30
# Epoch 20 gene 23 : Avg. test loss = 0.0364, correlation = 0.0823, p-value = 0.6654
# 30
# Epoch 20 gene 24 : Avg. test loss = 0.0121, correlation = -0.2251, p-value = 0.2317
# 30
# Epoch 20 gene 25 : Avg. test loss = 0.0107, correlation = -0.1862, p-value = 0.3244
# 30
# Epoch 20 gene 26 : Avg. test loss = 0.0787, correlation = -0.3170, p-value = 0.0879
# 30
# Epoch 20 gene 27 : Avg. test loss = 0.0864, correlation = 0.0223, p-value = 0.9068
# 30
# Epoch 20 gene 28 : Avg. test loss = 0.0163, correlation = 0.1634, p-value = 0.3883
# 30
# Epoch 20 gene 29 : Avg. test loss = 0.0116, correlation = 0.0480, p-value = 0.8011
# 30
# Epoch 20 gene 30 : Avg. test loss = 0.0142, correlation = -0.2289, p-value = 0.2237
# 30
# Epoch 20 gene 31 : Avg. test loss = 0.0254, correlation = 0.1304, p-value = 0.4924
# 30
# Epoch 20 gene 32 : Avg. test loss = 0.0099, correlation = -0.2109, p-value = 0.2633
# 30
# Epoch 20 gene 33 : Avg. test loss = 0.0064, correlation = -0.0572, p-value = 0.7641
# 30
# Epoch 20 gene 34 : Avg. test loss = 0.0555, correlation = -0.0336, p-value = 0.8600
# 30
# Epoch 20 gene 35 : Avg. test loss = 0.0038, correlation = 0.1561, p-value = 0.4100
# 30
# Epoch 20 gene 36 : Avg. test loss = 0.0460, correlation = 0.1061, p-value = 0.5770
# 30
# Epoch 20 gene 37 : Avg. test loss = 1.1947, correlation = -0.0614, p-value = 0.7474
# 30
# Epoch 20 gene 38 : Avg. test loss = 0.0058, correlation = 0.0827, p-value = 0.6638
# 30
# Epoch 20 gene 39 : Avg. test loss = 0.1673, correlation = -0.1647, p-value = 0.3844
# 30
# Epoch 20 gene 40 : Avg. test loss = 0.2232, correlation = -0.4241, p-value = 0.0195
# 30
# Epoch 20 gene 41 : Avg. test loss = 0.0134, correlation = 0.0993, p-value = 0.6016
# 30
# Epoch 20 gene 42 : Avg. test loss = 0.0097, correlation = 0.3113, p-value = 0.0940
# 30
# Epoch 20 gene 43 : Avg. test loss = 0.0091, correlation = -0.2599, p-value = 0.1655
# 30
# Epoch 20 gene 44 : Avg. test loss = 0.0126, correlation = 0.4007, p-value = 0.0282
# 30
# Epoch 20 gene 45 : Avg. test loss = 0.1846, correlation = -0.0865, p-value = 0.6495
# 30
# Epoch 20 gene 46 : Avg. test loss = 0.0042, correlation = 0.2412, p-value = 0.1991
# 30
# Epoch 20 gene 47 : Avg. test loss = 0.0297, correlation = 0.2573, p-value = 0.1699
# 30
# Epoch 20 gene 48 : Avg. test loss = 0.1097, correlation = -0.2364, p-value = 0.2084
# 30
# Epoch 20 gene 49 : Avg. test loss = 0.0635, correlation = -0.2215, p-value = 0.2394
# 30
# Epoch 20 gene 50 : Avg. test loss = 0.0077, correlation = -0.3203, p-value = 0.0844
# 30
# Epoch 20 gene 51 : Avg. test loss = 0.0323, correlation = -0.2134, p-value = 0.2575
# 30
# Epoch 20 gene 52 : Avg. test loss = 0.0658, correlation = -0.3281, p-value = 0.0767
# 30
# Epoch 20 gene 53 : Avg. test loss = 0.0239, correlation = -0.0221, p-value = 0.9077
# 30
# Epoch 20 gene 54 : Avg. test loss = 0.0251, correlation = 0.1070, p-value = 0.5736
# 30
# Epoch 20 gene 55 : Avg. test loss = 0.7635, correlation = -0.0505, p-value = 0.7909
# 30
# Epoch 20 gene 56 : Avg. test loss = 0.0115, correlation = -0.1938, p-value = 0.3048
# 30
# Epoch 20 gene 57 : Avg. test loss = 0.0085, correlation = -0.2226, p-value = 0.2371
# 30
# Epoch 20 gene 58 : Avg. test loss = 0.0920, correlation = 0.1242, p-value = 0.5132
# 30
# Epoch 20 gene 59 : Avg. test loss = 0.0106, correlation = -0.2588, p-value = 0.1673
# 30
# Epoch 20 gene 60 : Avg. test loss = 0.0071, correlation = 0.0147, p-value = 0.9383
# 30
# Epoch 20 gene 61 : Avg. test loss = 0.0239, correlation = -0.1354, p-value = 0.4755
# 30
# Epoch 20 gene 62 : Avg. test loss = 0.0382, correlation = -0.0401, p-value = 0.8335
# 30
# Epoch 20 gene 63 : Avg. test loss = 8.4933, correlation = 0.0597, p-value = 0.7540
# 30
# Epoch 20 gene 64 : Avg. test loss = 0.0359, correlation = 0.3167, p-value = 0.0882
# 30
# Epoch 20 gene 65 : Avg. test loss = 0.0087, correlation = -0.2044, p-value = 0.2785
# 30
# Epoch 20 gene 66 : Avg. test loss = 0.0927, correlation = -0.0048, p-value = 0.9798
# 30
# Epoch 20 gene 67 : Avg. test loss = 0.0364, correlation = -0.1334, p-value = 0.4822
# 30
# Epoch 20 gene 68 : Avg. test loss = 0.0132, correlation = 0.1984, p-value = 0.2932
# 30
# Epoch 20 gene 69 : Avg. test loss = 1.9610, correlation = -0.0571, p-value = 0.7643
# 30
# Epoch 20 gene 70 : Avg. test loss = 0.0126, correlation = -0.1637, p-value = 0.3873
# 30
# Epoch 20 gene 71 : Avg. test loss = 0.2923, correlation = -0.1335, p-value = 0.4819
# 30
# Epoch 20 gene 72 : Avg. test loss = 0.0144, correlation = 0.1903, p-value = 0.3139
# 30
# Epoch 20 gene 73 : Avg. test loss = 0.0734, correlation = 0.1926, p-value = 0.3080
# 30
# Epoch 20 gene 74 : Avg. test loss = 1.8089, correlation = 0.0831, p-value = 0.6626
# 30
# Epoch 20 gene 75 : Avg. test loss = 0.0287, correlation = 0.1870, p-value = 0.3225
# 30
# Epoch 20 gene 76 : Avg. test loss = 0.0212, correlation = -0.0103, p-value = 0.9570
# 30
# Epoch 20 gene 77 : Avg. test loss = 0.1029, correlation = -0.1882, p-value = 0.3192
# 30
# Epoch 20 gene 78 : Avg. test loss = 0.7137, correlation = -0.1958, p-value = 0.2998
# 30
# Epoch 20 gene 79 : Avg. test loss = 0.0091, correlation = 0.0252, p-value = 0.8948
# 30
# Epoch 20 gene 80 : Avg. test loss = 0.0196, correlation = 0.0326, p-value = 0.8643
# 30
# Epoch 20 gene 81 : Avg. test loss = 1.1465, correlation = 0.0808, p-value = 0.6714
# 30
# Epoch 20 gene 82 : Avg. test loss = 0.0067, correlation = 0.1627, p-value = 0.3904
# 30
# Epoch 20 gene 83 : Avg. test loss = 0.0199, correlation = -0.0984, p-value = 0.6051
# 30
# Epoch 20 gene 84 : Avg. test loss = 0.0391, correlation = -0.1090, p-value = 0.5664
# 30
# Epoch 20 gene 85 : Avg. test loss = 0.0337, correlation = -0.1935, p-value = 0.3057
# 30
# Epoch 20 gene 86 : Avg. test loss = 0.0528, correlation = 0.1256, p-value = 0.5085
# 30
# Epoch 20 gene 87 : Avg. test loss = 0.0329, correlation = 0.1629, p-value = 0.3897
# 30
# Epoch 20 gene 88 : Avg. test loss = 0.0330, correlation = -0.2981, p-value = 0.1096
# 30
# Epoch 20 gene 89 : Avg. test loss = 0.0500, correlation = -0.0413, p-value = 0.8285
# 30
# Epoch 20 gene 90 : Avg. test loss = 0.0048, correlation = 0.1303, p-value = 0.4925
# 30
# Epoch 20 gene 91 : Avg. test loss = 0.0336, correlation = -0.2302, p-value = 0.2210
# 30
# Epoch 20 gene 92 : Avg. test loss = 0.0678, correlation = -0.0234, p-value = 0.9022
# 30
# Epoch 20 gene 93 : Avg. test loss = 0.0128, correlation = -0.0316, p-value = 0.8684
# 30
# Epoch 20 gene 94 : Avg. test loss = 0.0124, correlation = 0.0042, p-value = 0.9822
# 30
# Epoch 20 gene 95 : Avg. test loss = 0.0132, correlation = -0.0371, p-value = 0.8455
# 30
# Epoch 20 gene 96 : Avg. test loss = 0.0117, correlation = -0.1471, p-value = 0.4378
# 30
# Epoch 20 gene 97 : Avg. test loss = 0.0181, correlation = -0.2241, p-value = 0.2339
# 30
# Epoch 20 gene 98 : Avg. test loss = 0.0091, correlation = -0.0240, p-value = 0.8997
# 30
# Epoch 20 gene 99 : Avg. test loss = 0.1460, correlation = -0.1270, p-value = 0.5036
# 30
# Epoch 20 gene 100 : Avg. test loss = 0.1079, correlation = -0.3343, p-value = 0.0709
# Metrics for epoch 20 saved to /mnt/data/macaulay/datas/genepedia/C_metrics_epoch_20.csv
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
scp -r macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/training_gene_embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/training_crispr.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/test_gene_embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/test_gene_embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv macaulay@sahu.cs.unm.edu:/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv asahu@kraken.dfci.harvard.edu:/homes/asahu/liulab_home/macaulay/code/datas/

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    m_counter = 0
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        if m_counter == 0:
            print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
            m_counter += 1
    else:
        if m_counter == 0:
            print('No saved model found. Training from scratch.')
            m_counter += 1
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs

    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []

        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            model = load_model(model, epoch, model_save_path)
            train_correlations = []
            train_lossess = []
            test_correlations = []
            test_lossess = []
            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                # Shuffle data
                #combined = combined.sample(frac=1).reset_index(drop=True)
                # display(shuffled_combined)
                # print('shuffled')
                # time.sleep(1000)

                # Split shuffled data back into X and Y
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.1, shuffle=False)
                # display(X_test)
                # display(Y_test)

                # Copy gene name
                batch_gene_name = X_test['Gene'].iloc[0]
                print(batch_gene_name)
                X_train = X_train.drop(columns=["Gene"])
                X_test = X_test.drop(columns=["Gene"])

                # print(X_train.select_dtypes(include=['object']).head())
                # display(X_test)
                # # display(Y_train)
                # display(Y_test)
                # import time
                
                # Convert training data to tensor and create dataloader
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations.append(train_correlation)
                    train_lossess.append(loss.item())

                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    test_correlations.append(correlation)
                    test_lossess.append(test_loss.item())
            
            mean_train_correlation = np.mean(train_correlations)
            mean_train_loss = np.mean(train_lossess)
            mean_test_correlation = np.mean(test_correlations)
            mean_test_loss = np.mean(test_lossess)

            epoch_train_correlations.append(mean_train_correlation)
            epoch_train_losses.append(mean_train_loss)
            epoch_test_correlations.append(mean_test_correlation)
            epoch_test_losses.append(mean_test_loss)

            if j//2 == 0:

                print(f"Epoch {epoch}.{j}: Training Pearson correlation = {mean_train_correlation:.4f}")
                print(f"Epoch {epoch}.{j}.{batch_gene_name}: Pearson correlation = {mean_test_correlation:.4f}")

            with open(os.path.join(model_save_path, f'metrics_by_gene.txt'), 'a') as f:
                if epoch == 1:
                    f.write('Epoch,Gene,gene_correlation\n')
                f.write(f'Epoch{epoch},{batch_gene_name},{mean_test_correlation:.4f}\n')
              


        print(f"Epoch {epoch}: Avg. training loss = {np.mean(epoch_train_losses):.4f}, Training Pearson correlation = {np.mean(epoch_train_correlations):.4f}")
        print(f"Epoch {epoch}: Test loss = {np.mean(epoch_test_losses):.4f}, Pearson correlation = {np.mean(epoch_test_correlations):.4f}")

        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=1,learning_rate=0.001,num_epochs=10,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 227
#     221                 f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
#     222             f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
# --> 227 main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     228                    data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     229                    df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
#     230                    data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     231                    data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     232                    df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
#     233                    data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     234                    data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     235                    df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
#     236                    data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     237                    data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     238                    df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
#     239                    batch_size1=1,learning_rate=0.001,num_epochs=10,
#     240                    model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
#
# Cell In[2], line 84, in main_training_loop(data1_path, data2_path, df_Y_path, data1_test_path_A, data2_test_path_A, df_Y_test_path_A, data1_test_path_B, data2_test_path_B, df_Y_test_path_B, data1_test_path_C, data2_test_path_C, df_Y_test_path_C, batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size)
#      77 def main_training_loop(data1_path, data2_path, df_Y_path,
#      78                                data1_test_path_A, data2_test_path_A, df_Y_test_path_A,
#      79                                data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
#      80                                data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
#      81                                batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
# ---> 84     device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
#      85     # data1 = data1.iloc[:300]
#      86
#      87     # display(data1)
#    (...)
#      95     # start_epoch = 1
#      96     # end_epoch = 20
#      97     from sklearn.model_selection import train_test_split
#
# Cell In[2], line 24, in initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
#      21 print('Device:', device)
#      22 print(f'Number of available GPUs: {torch.cuda.device_count()}')
# ---> 24 data1 = pd.read_csv(data1_path)
#      25 data2 = pd.read_csv(data2_path)
#      26 df_Y = pd.read_csv(df_Y_path)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:814, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1036, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1090, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1165, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1335, in is_extension_array_dtype(arr_or_dtype)
#    1326     # Note: if other EA dtypes are ever held in HybridBlock, exclude those
#    1327     #  here too.
#    1328     # NB: need to check DatetimeTZDtype and not is_datetime64tz_dtype
#    1329     #  to exclude ArrowTimestampUSDtype
#    1330     return isinstance(dtype, ExtensionDtype) and not isinstance(
#    1331         dtype, (DatetimeTZDtype, PeriodDtype)
#    1332     )
# -> 1335 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1336     """
#    1337     Check if an object is a pandas extension array type.
#    1338
#    (...)
#    1378     False
#    1379     """
#    1380     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs


\

    gene_predictions = {}
    gene_actuals = {}


    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []

        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            model = load_model(model, epoch, model_save_path)
            train_correlations = []
            train_lossess = []
            test_correlations = []
            test_lossess = []
            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                
                # Split  data back into X and Y
                datas_X = combined.iloc[:, :-batch_Y.shape[1]]
                datas_Y = combined.iloc[:, -batch_Y.shape[1]:]

                X_train = datas_X.iloc[:int(len(datas_X)-9710)]
                X_test = datas_X.iloc[int(len(datas_X)-9710):]
                Y_train = datas_Y.iloc[:int(len(datas_Y)-9710)]
                Y_test = datas_Y.iloc[int(len(datas_Y)-9710):]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.1, shuffle=False)
                X_train = X_train.drop(columns=["Gene"])
                

                # print(X_train.select_dtypes(include=['object']).head())
                # display(X_test)
                # display(Y_train)
                # display(Y_test)
                # Convert training data to tensor and create dataloader
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations.append(train_correlation)
                    train_lossess.append(loss.item())

                # Evaluate on test data

                model.eval()
                with torch.no_grad():
                    # Convert test data to tensor and evaluate
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    # Aggregate predictions and actual values for each gene
                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

            # Calculate Pearson correlation for each gene
            gene_correlations = {}
            for gene in gene_predictions.keys():
                correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                gene_correlations[gene] = correlation

            # Print or save gene correlations
            for gene, corr in gene_correlations.items():
                print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")
                with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                    if epoch == 1:
                        f.write('Epoch,gene,correlation\n')
                    f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

            # Save model state and metrics
            torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
            with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
                if epoch == 1:
                    f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
                f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')





main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=10,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# Model 11 loaded successfully for epoch 12
# 485500
# Gene PHF23: Pearson Correlation = 0.0500
# Gene CDH10: Pearson Correlation = 0.0192
# Gene INPP4A: Pearson Correlation = -0.0673
# Gene RAB27B: Pearson Correlation = 0.0604
# Gene PSMA4: Pearson Correlation = -0.0066
# Gene MYO16: Pearson Correlation = -0.0100
# Gene LSG1: Pearson Correlation = 0.0955
# Gene PARP3: Pearson Correlation = 0.0140
# Gene TNC: Pearson Correlation = -0.0658
# Gene THAP3: Pearson Correlation = 0.0710
# Gene RIPOR3: Pearson Correlation = -0.0803
# Gene TDP1: Pearson Correlation = -0.0303
# Gene AIFM2: Pearson Correlation = -0.0555
# Gene SPATA7: Pearson Correlation = 0.0810
# Gene MED17: Pearson Correlation = 0.0352
# Gene RETSAT: Pearson Correlation = -0.0083
# Gene CAPG: Pearson Correlation = -0.0384
# Gene AP2S1: Pearson Correlation = -0.0545
# Gene USH2A: Pearson Correlation = 0.0552
# Gene ZPBP: Pearson Correlation = 0.0374
# Gene TG: Pearson Correlation = -0.0017
# Gene ADAM28: Pearson Correlation = -0.0337
# Gene BARX2: Pearson Correlation = 0.0054
# Gene DCUN1D1: Pearson Correlation = 0.0095
# Gene JADE2: Pearson Correlation = -0.0074
# Gene ZIC2: Pearson Correlation = 0.0400
# Gene LCP2: Pearson Correlation = -0.0186
# Gene TRIT1: Pearson Correlation = 0.0155
# Gene ADRB1: Pearson Correlation = 0.0063
# Gene GUCA2B: Pearson Correlation = 0.0204
# Gene CUL7: Pearson Correlation = 0.0188
# Gene CTNNA1: Pearson Correlation = -0.0761
# Gene PHKA2: Pearson Correlation = 0.0261
# Gene CNTLN: Pearson Correlation = 0.0640
# Gene EPHA3: Pearson Correlation = -0.0414
# Gene HSPA5: Pearson Correlation = -0.0190
# Gene DSG2: Pearson Correlation = -0.0148
# Gene GEMIN8: Pearson Correlation = 0.0178
# Gene OFD1: Pearson Correlation = 0.0300
# Gene GPM6B: Pearson Correlation = 0.0208
# Gene MAGEC2: Pearson Correlation = 0.0385
# Gene PREX2: Pearson Correlation = 0.0473
# Gene WDR37: Pearson Correlation = 0.0759
# Gene YTHDC2: Pearson Correlation = 0.0308
# Gene CTPS2: Pearson Correlation = 0.0351
# Gene ATP6V1H: Pearson Correlation = -0.1172
# Gene POLR2B: Pearson Correlation = -0.0005
# Gene ARAP2: Pearson Correlation = 0.0894
# Gene TPR: Pearson Correlation = -0.0698
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Model 11 loaded successfully for epoch 12
# 485500
# Gene PHF23: Pearson Correlation = 0.0500
# Gene CDH10: Pearson Correlation = 0.0192
# Gene INPP4A: Pearson Correlation = -0.0673
# Gene RAB27B: Pearson Correlation = 0.0604
# Gene PSMA4: Pearson Correlation = -0.0066
# Gene MYO16: Pearson Correlation = -0.0100
# Gene LSG1: Pearson Correlation = 0.0955
# Gene PARP3: Pearson Correlation = 0.0140
# Gene TNC: Pearson Correlation = -0.0658
# Gene THAP3: Pearson Correlation = 0.0710
# Gene RIPOR3: Pearson Correlation = -0.0803
# Gene TDP1: Pearson Correlation = -0.0303
# Gene AIFM2: Pearson Correlation = -0.0555
# Gene SPATA7: Pearson Correlation = 0.0810
# Gene MED17: Pearson Correlation = 0.0352
# Gene RETSAT: Pearson Correlation = -0.0083
# Gene CAPG: Pearson Correlation = -0.0384
# Gene AP2S1: Pearson Correlation = -0.0545
# Gene USH2A: Pearson Correlation = 0.0552
# Gene ZPBP: Pearson Correlation = 0.0374
# Gene TG: Pearson Correlation = -0.0017
# Gene ADAM28: Pearson Correlation = -0.0337
# Gene BARX2: Pearson Correlation = 0.0054
# Gene DCUN1D1: Pearson Correlation = 0.0095
# Gene JADE2: Pearson Correlation = -0.0074
# Gene ZIC2: Pearson Correlation = 0.0400
# Gene LCP2: Pearson Correlation = -0.0186
# Gene TRIT1: Pearson Correlation = 0.0155
# Gene ADRB1: Pearson Correlation = 0.0063
# Gene GUCA2B: Pearson Correlation = 0.0204
# Gene CUL7: Pearson Correlation = 0.0188
# Gene CTNNA1: Pearson Correlation = -0.0761
# Gene PHKA2: Pearson Correlation = 0.0261
# Gene CNTLN: Pearson Correlation = 0.0640
# Gene EPHA3: Pearson Correlation = -0.0414
# Gene HSPA5: Pearson Correlation = -0.0190
# Gene DSG2: Pearson Correlation = -0.0148
# Gene GEMIN8: Pearson Correlation = 0.0178
# Gene OFD1: Pearson Correlation = 0.0300
# Gene GPM6B: Pearson Correlation = 0.0208
# Gene MAGEC2: Pearson Correlation = 0.0385
# Gene PREX2: Pearson Correlation = 0.0473
# Gene WDR37: Pearson Correlation = 0.0759
# Gene YTHDC2: Pearson Correlation = 0.0308
# Gene CTPS2: Pearson Correlation = 0.0351
# Gene ATP6V1H: Pearson Correlation = -0.1172
# Gene POLR2B: Pearson Correlation = -0.0005
# Gene ARAP2: Pearson Correlation = 0.0894
# Gene TPR: Pearson Correlation = -0.0698
# Gene NEDD4: Pearson Correlation = 0.0158
# Gene PIGB: Pearson Correlation = -0.0069
# Gene MAPK6: Pearson Correlation = 0.0318
# Gene GNB5: Pearson Correlation = 0.0132
# Gene RAB27A: Pearson Correlation = 0.0668
# Gene HDHD5: Pearson Correlation = 0.0461
# Gene UFD1: Pearson Correlation = 0.0231
# Gene LRP6: Pearson Correlation = -0.0405
# Gene GUCY2C: Pearson Correlation = -0.0609
# Gene SCT: Pearson Correlation = -0.0357
# Gene PHRF1: Pearson Correlation = 0.0439
# Gene ELP1: Pearson Correlation = -0.0016
# Gene NUCB2: Pearson Correlation = 0.0790
# Gene PFN2: Pearson Correlation = -0.0060
# Gene PTPN3: Pearson Correlation = -0.0177
# Gene SPTB: Pearson Correlation = 0.0127
# Gene DAPP1: Pearson Correlation = -0.0600
# Gene FGF10: Pearson Correlation = 0.1008
# Gene SLC44A1: Pearson Correlation = 0.0192
# Gene TMEM260: Pearson Correlation = -0.0233
# Gene SMG6: Pearson Correlation = -0.0375
# Gene EXOC5: Pearson Correlation = 0.0385
# Gene CLTCL1: Pearson Correlation = 0.0468
# Gene FGF22: Pearson Correlation = 0.0416
# Gene FSTL3: Pearson Correlation = 0.0147
# Gene DGCR2: Pearson Correlation = -0.0053
# Gene RNF126: Pearson Correlation = 0.0319
# Gene MNT: Pearson Correlation = -0.0228
# Gene ZXDC: Pearson Correlation = 0.0202
# Gene JMJD6: Pearson Correlation = 0.0159
# Gene POLB: Pearson Correlation = 0.0010
# Gene ST6GALNAC1: Pearson Correlation = 0.0842
# Gene WIPI1: Pearson Correlation = 0.0226
# Gene FRMPD1: Pearson Correlation = -0.0622
# Gene GBA2: Pearson Correlation = -0.0133
# Gene NDST1: Pearson Correlation = -0.0360
# Gene ASNS: Pearson Correlation = 0.0270
# Gene AP3M2: Pearson Correlation = -0.0275
# Gene CNGB1: Pearson Correlation = -0.0163
# Gene ST6GALNAC2: Pearson Correlation = -0.0211
# Gene CHAT: Pearson Correlation = 0.0065
# Gene PABPC1: Pearson Correlation = -0.0102
# Gene TESK2: Pearson Correlation = -0.0060
# Gene CFAP20: Pearson Correlation = 0.0050
# Gene CSNK2A2: Pearson Correlation = 0.0160
# Gene PTPN21: Pearson Correlation = 0.0473
# Gene EIF2B3: Pearson Correlation = -0.0328
# Gene CAMK2A: Pearson Correlation = -0.0315
# Gene TCOF1: Pearson Correlation = -0.0271
# Model 11 loaded successfully for epoch 12
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 485500
# Gene PHF23: Pearson Correlation = 0.0500
# Gene CDH10: Pearson Correlation = 0.0192
# Gene INPP4A: Pearson Correlation = -0.0673
# Gene RAB27B: Pearson Correlation = 0.0604
# Gene PSMA4: Pearson Correlation = -0.0066
# Gene MYO16: Pearson Correlation = -0.0100
# Gene LSG1: Pearson Correlation = 0.0955
# Gene PARP3: Pearson Correlation = 0.0140
# Gene TNC: Pearson Correlation = -0.0658
# Gene THAP3: Pearson Correlation = 0.0710
# Gene RIPOR3: Pearson Correlation = -0.0803
# Gene TDP1: Pearson Correlation = -0.0303
# Gene AIFM2: Pearson Correlation = -0.0555
# Gene SPATA7: Pearson Correlation = 0.0810
# Gene MED17: Pearson Correlation = 0.0352
# Gene RETSAT: Pearson Correlation = -0.0083
# Gene CAPG: Pearson Correlation = -0.0384
# Gene AP2S1: Pearson Correlation = -0.0545
# Gene USH2A: Pearson Correlation = 0.0552
# Gene ZPBP: Pearson Correlation = 0.0374
# Gene TG: Pearson Correlation = -0.0017
# Gene ADAM28: Pearson Correlation = -0.0337
# Gene BARX2: Pearson Correlation = 0.0054
# Gene DCUN1D1: Pearson Correlation = 0.0095
# Gene JADE2: Pearson Correlation = -0.0074
# Gene ZIC2: Pearson Correlation = 0.0400
# Gene LCP2: Pearson Correlation = -0.0186
# Gene TRIT1: Pearson Correlation = 0.0155
# Gene ADRB1: Pearson Correlation = 0.0063
# Gene GUCA2B: Pearson Correlation = 0.0204
# Gene CUL7: Pearson Correlation = 0.0188
# Gene CTNNA1: Pearson Correlation = -0.0761
# Gene PHKA2: Pearson Correlation = 0.0261
# Gene CNTLN: Pearson Correlation = 0.0640
# Gene EPHA3: Pearson Correlation = -0.0414
# Gene HSPA5: Pearson Correlation = -0.0190
# Gene DSG2: Pearson Correlation = -0.0148
# Gene GEMIN8: Pearson Correlation = 0.0178
# Gene OFD1: Pearson Correlation = 0.0300
# Gene GPM6B: Pearson Correlation = 0.0208
# Gene MAGEC2: Pearson Correlation = 0.0385
# Gene PREX2: Pearson Correlation = 0.0473
# Gene WDR37: Pearson Correlation = 0.0759
# Gene YTHDC2: Pearson Correlation = 0.0308
# Gene CTPS2: Pearson Correlation = 0.0351
# Gene ATP6V1H: Pearson Correlation = -0.1172
# Gene POLR2B: Pearson Correlation = -0.0005
# Gene ARAP2: Pearson Correlation = 0.0894
# Gene TPR: Pearson Correlation = -0.0698
# Gene NEDD4: Pearson Correlation = 0.0158
# Gene PIGB: Pearson Correlation = -0.0069
# Gene MAPK6: Pearson Correlation = 0.0318
# Gene GNB5: Pearson Correlation = 0.0132
# Gene RAB27A: Pearson Correlation = 0.0668
# Gene HDHD5: Pearson Correlation = 0.0461
# Gene UFD1: Pearson Correlation = 0.0231
# Gene LRP6: Pearson Correlation = -0.0405
# Gene GUCY2C: Pearson Correlation = -0.0609
# Gene SCT: Pearson Correlation = -0.0357
# Gene PHRF1: Pearson Correlation = 0.0439
# Gene ELP1: Pearson Correlation = -0.0016
# Gene NUCB2: Pearson Correlation = 0.0790
# Gene PFN2: Pearson Correlation = -0.0060
# Gene PTPN3: Pearson Correlation = -0.0177
# Gene SPTB: Pearson Correlation = 0.0127
# Gene DAPP1: Pearson Correlation = -0.0600
# Gene FGF10: Pearson Correlation = 0.1008
# Gene SLC44A1: Pearson Correlation = 0.0192
# Gene TMEM260: Pearson Correlation = -0.0233
# Gene SMG6: Pearson Correlation = -0.0375
# Gene EXOC5: Pearson Correlation = 0.0385
# Gene CLTCL1: Pearson Correlation = 0.0468
# Gene FGF22: Pearson Correlation = 0.0416
# Gene FSTL3: Pearson Correlation = 0.0147
# Gene DGCR2: Pearson Correlation = -0.0053
# Gene RNF126: Pearson Correlation = 0.0319
# Gene MNT: Pearson Correlation = -0.0228
# Gene ZXDC: Pearson Correlation = 0.0202
# Gene JMJD6: Pearson Correlation = 0.0159
# Gene POLB: Pearson Correlation = 0.0010
# Gene ST6GALNAC1: Pearson Correlation = 0.0842
# Gene WIPI1: Pearson Correlation = 0.0226
# Gene FRMPD1: Pearson Correlation = -0.0622
# Gene GBA2: Pearson Correlation = -0.0133
# Gene NDST1: Pearson Correlation = -0.0360
# Gene ASNS: Pearson Correlation = 0.0270
# Gene AP3M2: Pearson Correlation = -0.0275
# Gene CNGB1: Pearson Correlation = -0.0163
# Gene ST6GALNAC2: Pearson Correlation = -0.0211
# Gene CHAT: Pearson Correlation = 0.0065
# Gene PABPC1: Pearson Correlation = -0.0102
# Gene TESK2: Pearson Correlation = -0.0060
# Gene CFAP20: Pearson Correlation = 0.0050
# Gene CSNK2A2: Pearson Correlation = 0.0160
# Gene PTPN21: Pearson Correlation = 0.0473
# Gene EIF2B3: Pearson Correlation = -0.0328
# Gene CAMK2A: Pearson Correlation = -0.0315
# Gene TCOF1: Pearson Correlation = -0.0271
# Gene DIS3: Pearson Correlation = -0.0015
# Gene PIBF1: Pearson Correlation = 0.0549
# Gene TDRD3: Pearson Correlation = -0.0418
# Gene NUFIP1: Pearson Correlation = -0.0046
# Gene PDS5B: Pearson Correlation = -0.0099
# Gene OXCT1: Pearson Correlation = -0.0028
# Gene RRAGB: Pearson Correlation = 0.0157
# Gene EPYC: Pearson Correlation = 0.0636
# Gene CYLD: Pearson Correlation = -0.0792
# Gene SLC27A5: Pearson Correlation = 0.0327
# Gene ZNF324: Pearson Correlation = -0.0480
# Gene ZNF671: Pearson Correlation = -0.0495
# Gene ZNF416: Pearson Correlation = -0.0559
# Gene ZNF586: Pearson Correlation = 0.0637
# Gene ZNF446: Pearson Correlation = 0.0563
# Gene ZNF264: Pearson Correlation = -0.0506
# Gene RPS5: Pearson Correlation = -0.0416
# Gene FAT1: Pearson Correlation = 0.0074
# Gene YTHDC1: Pearson Correlation = 0.0183
# Gene CHMP2B: Pearson Correlation = 0.0503
# Gene SMAP2: Pearson Correlation = -0.0078
# Gene PPIE: Pearson Correlation = 0.0127
# Gene ZMPSTE24: Pearson Correlation = 0.0233
# Gene STARD7: Pearson Correlation = 0.0786
# Gene NOA1: Pearson Correlation = 0.0847
# Gene REST: Pearson Correlation = -0.0303
# Gene HAL: Pearson Correlation = -0.0074
# Gene SSH1: Pearson Correlation = -0.0302
# Gene GSTP1: Pearson Correlation = -0.0262
# Gene APLP2: Pearson Correlation = 0.0349
# Gene FAM234B: Pearson Correlation = -0.0084
# Gene SLCO1A2: Pearson Correlation = -0.0698
# Gene WBP11: Pearson Correlation = 0.0232
# Gene EIF3I: Pearson Correlation = -0.0299
# Gene NKAIN1: Pearson Correlation = 0.0723
# Gene COL16A1: Pearson Correlation = 0.0193
# Gene TXLNA: Pearson Correlation = -0.0151
# Gene APOB: Pearson Correlation = 0.0060
# Gene NCOA1: Pearson Correlation = 0.0049
# Gene AGBL5: Pearson Correlation = -0.0476
# Gene EFR3B: Pearson Correlation = -0.0148
# Gene KIF3C: Pearson Correlation = 0.0003
# Gene RAB10: Pearson Correlation = -0.0172
# Gene GCKR: Pearson Correlation = -0.0115
# Gene HADHA: Pearson Correlation = -0.0305
# Gene MAPRE3: Pearson Correlation = 0.0126
# Gene CAD: Pearson Correlation = -0.0044
# Gene CD59: Pearson Correlation = 0.0060
# Gene CD82: Pearson Correlation = -0.0597
# Model 11 loaded successfully for epoch 12
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/macaulay/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    m_counter = 0
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        if m_counter == 0:
            print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
            m_counter += 1
    else:
        if m_counter == 0:
            print('No saved model found. Training from scratch.')
            m_counter += 1
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs

    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []

        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            model = load_model(model, epoch, model_save_path)
            train_correlations = []
            train_lossess = []
            test_correlations = []
            test_lossess = []
            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                
                # Split  data back into X and Y
                datas_X = combined.iloc[:, :-batch_Y.shape[1]]
                datas_Y = combined.iloc[:, -batch_Y.shape[1]:]

                X_train = datas_X.iloc[:int(len(datas_X)-9710)]
                X_test = datas_X.iloc[int(len(datas_X)-9710):]
                Y_train = datas_Y.iloc[:int(len(datas_Y)-9710)]
                Y_test = datas_Y.iloc[int(len(datas_Y)-9710):]

                # display(X_test)
                # display(Y_test)

                # Copy gene name
                batch_gene_name = X_test['Gene'].iloc[0]
                # print(batch_gene_name)
                X_train = X_train.drop(columns=["Gene"])
                X_test = X_test.drop(columns=["Gene"])

                # print(X_train.select_dtypes(include=['object']).head())
                # display(X_test)
                # # display(Y_train)
                # display(Y_test)
                # import time
                
                # Convert training data to tensor and create dataloader
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations.append(train_correlation)
                    train_lossess.append(loss.item())

                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    # Convert test data to tensor and evaluate
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    # Aggregate predictions and actual values for each gene
                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

            # Calculate Pearson correlation for each gene
            gene_correlations = {}
            for gene in gene_predictions.keys():
                correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                gene_correlations[gene] = correlation

            # Print or save gene correlations
            for gene, corr in gene_correlations.items():
                print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")
                with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                    if epoch == 1:
                        f.write('Epoch,gene,correlation\n')
                    f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

            # Save model state and metrics
            torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
            with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
                if epoch == 1:
                    f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
                f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=1,learning_rate=0.001,num_epochs=10,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np




def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs


    gene_predictions = {}
    gene_actuals = {}



    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []
        test_counter = 0
        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            model = load_model(model, epoch, model_save_path)
            train_correlations = []
            train_lossess = []
            test_correlations = []
            test_lossess = []
            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                # Shuffle data
                combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)
                display(combined)
                


                # Split shuffled data back into X and Y
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.1, shuffle=False)

                if epoch == 1:

                    X_test.to_csv(model_save_path, f'X_test_{test_counter}.csv', index=False)
                    Y_test.to_csv(model_save_path, f'Y_test_{test_counter}.csv', index=False)
                    X_train = X_train.drop(columns=["Gene"])
                    
                    test_counter += 1
                else:
                    X_test = pd.read_csv(os.path.join(model_save_path, f'X_test_{test_counter}.csv'))
                    Y_test = pd.read_csv(os.path.join(model_save_path, f'Y_test_{test_counter}.csv'))
                    X_train = X_train.drop(columns=["Gene"])
                    
                    test_counter += 1

                # Convert training data to tensor and create dataloader
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations.append(train_correlation)
                    train_lossess.append(loss.item())

                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    # Convert test data to tensor and evaluate
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    # Aggregate predictions and actual values for each gene
                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

            # Calculate Pearson correlation for each gene
            gene_correlations = {}
            for gene in gene_predictions.keys():
                correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                gene_correlations[gene] = correlation

            # Print or save gene correlations
            for gene, corr in gene_correlations.items():
                print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")
                with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                    if epoch == 1:
                        f.write('Epoch,gene,correlation\n')
                    f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

        # Save model state and metrics
        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=500,learning_rate=0.001,num_epochs=10,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# Model 40 loaded successfully for epoch 41
# 4855
#        Gene       0_x       1_x       2_x       3_x       4_x       5_x  \
# 0      GDE1  0.013251  0.258344  0.148767 -0.011984 -0.054923  0.024582
# 1     LAMP2  0.004373 -0.052026  0.115090 -0.018382 -0.366196  0.019519
# 2      GDE1  0.013251  0.258344  0.148767 -0.011984 -0.054923  0.024582
# 3     LAMP2  0.004373 -0.052026  0.115090 -0.018382 -0.366196  0.019519
# 4     LAMP2  0.004373 -0.052026  0.115090 -0.018382 -0.366196  0.019519
# ...     ...       ...       ...       ...       ...       ...       ...
# 4850   GDE1  0.013251  0.258344  0.148767 -0.011984 -0.054923  0.024582
# 4851    ZFX  0.013528 -0.073574  0.050425 -0.007168 -0.083504  0.009434
# 4852   ASB4  0.003966 -0.157932  0.034745 -0.003395  0.023854 -0.018922
# 4853   ASB4  0.003966 -0.157932  0.034745 -0.003395  0.023854 -0.018922
# 4854    ZFX  0.013528 -0.073574  0.050425 -0.007168 -0.083504  0.009434
#
#            6_x       7_x       8_x  ...    1891_y    1892_y    1893_y  \
# 0    -0.055574 -0.057606 -0.006614  ...  0.286353  0.624002 -0.025035
# 1    -0.149446 -0.032409 -0.004365  ... -0.172742  0.136557 -0.052210
# 2    -0.055574 -0.057606 -0.006614  ...  0.278565  0.324385 -0.063442
# 3    -0.149446 -0.032409 -0.004365  ... -0.450451 -0.049049 -0.187901
# 4    -0.149446 -0.032409 -0.004365  ...  0.359132  0.155745  0.042304
# ...        ...       ...       ...  ...       ...       ...       ...
# 4850 -0.055574 -0.057606 -0.006614  ... -0.485712 -0.058002 -0.147350
# 4851 -0.243107 -0.036453 -0.003885  ...  0.443331  0.311685  0.045211
# 4852  0.011001 -0.031456 -0.005197  ... -0.183564 -0.193609 -0.424348
# 4853  0.011001 -0.031456 -0.005197  ... -0.279301  0.160942 -0.108084
# 4854 -0.243107 -0.036453 -0.003885  ...  0.477452  0.221611 -0.165262
#
#         1894_y    1895_y    1896_y    1897_y    1898_y    1899_y         Y
# 0    -0.917881 -0.099783  0.187780  0.342172  0.011078 -0.250831 -0.009199
# 1    -0.618007  0.540206  0.036533  0.057426 -0.639297 -0.364172  0.302142
# 2    -0.964686  0.107228  0.799806  0.099090  0.167747 -0.421059  0.139715
# 3    -0.538388  0.397562  0.206421 -0.045652 -0.187902 -0.764973  0.223350
# 4    -0.320793 -0.003410  0.212727  0.084276 -0.159299  0.060637  0.296481
# ...        ...       ...       ...       ...       ...       ...       ...
# 4850 -0.560812  0.551601  0.331454 -0.106176 -0.510723 -0.617542  0.006007
# 4851 -0.834403 -0.088015  0.467807  0.119659 -0.223629 -0.147326 -0.345077
# 4852 -0.473449  0.642013 -0.181230  0.091139 -0.508000 -0.591336  0.185803
# 4853 -0.244876  0.433558  0.201031 -0.339610 -0.513008 -0.662369  0.094623
# 4854 -0.616879  0.100065  0.286878  0.465185  0.136163 -0.407400 -0.465635
#
# [4855 rows x 3802 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 216
#     210                 f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
#     211             f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
# --> 216 main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     217                    data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     218                    df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
#     219                    data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
#     220                    data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     221                    df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
#     222                    data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     223                    data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
#     224                    df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
#     225                    data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
#     226                    data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
#     227                    df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
#     228                    batch_size1=5,learning_rate=0.001,num_epochs=10,
#     229                    model_save_path='/mnt/data/macaulay/datas/genepedia/',test_batch_size=128)
#
# Cell In[6], line 128, in main_training_loop(data1_path, data2_path, df_Y_path, data1_test_path_A, data2_test_path_A, df_Y_test_path_A, data1_test_path_B, data2_test_path_B, df_Y_test_path_B, data1_test_path_C, data2_test_path_C, df_Y_test_path_C, batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size)
#     126 display(combined)
#     127 import time
# --> 128 time.sleep(1000)
#     131 # Split shuffled data back into X and Y
#     132 shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
! cd datas/ && rm *


import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np
import json
import sys



def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    # print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs


    gene_predictions = {}
    gene_actuals = {}



    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)
        max_index = 50 

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []
        test_counter = 0
        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            if j == 0:
                model = load_model(model, epoch, model_save_path)

            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                # Shuffle data
                combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)
                
            

                # Split shuffled data back into X and Y
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.05, shuffle=False)
                # X_test_indices = X_test.index.tolist()  # Get indices of X_test
                # Y_test_indices = Y_test.index.tolist() 


                # if epoch == 1:

                #     sys.exit('stop')
                #     file_name_X = f'X_test_{test_counter}.csv'
                #     file_path_X = os.path.join(model_save_path, file_name_X)
                #     file_name_Y = f'Y_test_{test_counter}.csv'
                #     file_path_Y = os.path.join(model_save_path, file_name_Y)
                #     X_test.to_csv(file_path_X, index=False)
                #     Y_test.to_csv(file_path_Y, index=False)
                #     X_train = X_train.drop(columns=["Gene"])
                    
                #     test_counter += 1
                 
                # else:
                #     sys.exit('stop')
                #     file_name_X = f'X_test_{test_counter}.csv'
                #     file_path_X = os.path.join(model_save_path, file_name_X)
                #     X_test = pd.read_csv(file_path_X)
                #     file_name_Y = f'Y_test_{test_counter}.csv'
                #     file_path_Y = os.path.join(model_save_path, file_name_Y)
                #     Y_test = pd.read_csv(file_path_Y)
                #     X_train = X_train.drop(columns=["Gene"])
                    
                #     test_counter += 1


                # import sys
                # sys.exit('stop')
                # Convert training data to tensor and create dataloader
                X_train = X_train.drop(columns=["Gene"])
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                train_correlations_b = []
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations_b.append(train_correlation)
                epoch_train_losses.append(train_loss / len(train_dataloader))
                epoch_train_correlations.append(np.mean(train_correlations_b))



                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    # Convert test data to tensor and evaluate
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    # Aggregate predictions and actual values for each gene
                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

                # Calculate Pearson correlation for each gene
                gene_correlations = {}
                for gene in gene_predictions.keys():
                    correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                    gene_correlations[gene] = correlation

        # Print or save gene correlations
        for gene, corr in gene_correlations.items():
            print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")

            with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                if epoch == 1:
                    f.write('Epoch,gene,correlation\n')
                f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

        # Save model state and metrics
        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
        print(f'Epoch {epoch} completed')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=1,learning_rate=0.001,num_epochs=6,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)

                #    model_save_path='/mnt/data/macaulay/datas/model_datas/',test_batch_size=128)

# model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
# Out:
# Device: cuda
# Number of available GPUs: 1
# Training data loaded successfully
# Model initialized successfully
# No saved model found. Training from scratch.
# Gene ZFX: Pearson Correlation = 0.0390
# Gene LAMP2: Pearson Correlation = -0.0142
# Gene ITGA2B: Pearson Correlation = 0.0706
# Gene ASB4: Pearson Correlation = 0.0536
# Gene GDE1: Pearson Correlation = -0.1093
# Gene REX1BD: Pearson Correlation = -0.1915
# Gene CRLF1: Pearson Correlation = 0.1670
# Gene OSBPL7: Pearson Correlation = 0.0709
# Gene TMEM98: Pearson Correlation = 0.0469
# Gene YBX2: Pearson Correlation = 0.0517
# Gene KRT33A: Pearson Correlation = 0.0871
# Gene ABCC8: Pearson Correlation = 0.0427
# Gene CACNG3: Pearson Correlation = 0.0575
# Gene TMEM132A: Pearson Correlation = 0.1294
# Gene AP2B1: Pearson Correlation = 0.0556
# Gene TAC1: Pearson Correlation = 0.0902
# Gene ZNF263: Pearson Correlation = 0.0818
# Gene CX3CL1: Pearson Correlation = -0.0353
# Gene SPATA20: Pearson Correlation = 0.0329
# Gene CACNA1G: Pearson Correlation = 0.1588
# Gene TNFRSF12A: Pearson Correlation = 0.0505
# Gene DLX6: Pearson Correlation = 0.1650
# Gene MAP3K9: Pearson Correlation = 0.0750
# Gene RALA: Pearson Correlation = 0.2319
# Gene BAIAP2L1: Pearson Correlation = 0.0981
# Gene KDM7A: Pearson Correlation = 0.0948
# Gene ETV1: Pearson Correlation = 0.1549
# Gene AGK: Pearson Correlation = 0.2035
# Gene TTC22: Pearson Correlation = 0.0635
# Gene PHTF2: Pearson Correlation = 0.0434
# Gene CCL26: Pearson Correlation = 0.0173
# Gene FARP2: Pearson Correlation = 0.0615
# Gene USH1C: Pearson Correlation = 0.0696
# Gene GGCT: Pearson Correlation = 0.1970
# Gene DBF4: Pearson Correlation = 0.1739
# Gene TBXA2R: Pearson Correlation = 0.1362
# Gene IFRD1: Pearson Correlation = 0.0784
# Gene LGALS14: Pearson Correlation = 0.1995
# Gene COX10: Pearson Correlation = -0.0265
# Gene GTF2IRD1: Pearson Correlation = 0.0874
# Gene PAF1: Pearson Correlation = 0.1359
# Gene VPS41: Pearson Correlation = 0.0267
# Gene ARHGAP44: Pearson Correlation = 0.1075
# Gene ELAC2: Pearson Correlation = 0.0974
# Gene SCIN: Pearson Correlation = 0.1805
# Gene ARSD: Pearson Correlation = 0.0879
# Gene PNPLA4: Pearson Correlation = 0.0268
# Gene MYH13: Pearson Correlation = 0.0882
# Gene ADIPOR2: Pearson Correlation = -0.0129
# Gene CDKL3: Pearson Correlation = 0.1460
# Epoch 1 completed
# Model 1 loaded successfully for epoch 2
# Gene ZFX: Pearson Correlation = 0.0253
# Gene LAMP2: Pearson Correlation = 0.0846
# Gene ITGA2B: Pearson Correlation = 0.0879
# Gene ASB4: Pearson Correlation = 0.0225
# Gene GDE1: Pearson Correlation = -0.0314
# Gene REX1BD: Pearson Correlation = -0.0521
# Gene CRLF1: Pearson Correlation = 0.1444
# Gene OSBPL7: Pearson Correlation = 0.0867
# Gene TMEM98: Pearson Correlation = 0.0741
# Gene YBX2: Pearson Correlation = 0.0411
# Gene KRT33A: Pearson Correlation = 0.0850
# Gene ABCC8: Pearson Correlation = 0.0153
# Gene CACNG3: Pearson Correlation = 0.0533
# Gene TMEM132A: Pearson Correlation = 0.1663
# Gene AP2B1: Pearson Correlation = 0.0408
# Gene TAC1: Pearson Correlation = 0.1030
# Gene ZNF263: Pearson Correlation = 0.0938
# Gene CX3CL1: Pearson Correlation = 0.0332
# Gene SPATA20: Pearson Correlation = 0.0441
# Gene CACNA1G: Pearson Correlation = 0.1471
# Gene TNFRSF12A: Pearson Correlation = 0.0988
# Gene DLX6: Pearson Correlation = 0.1622
# Gene MAP3K9: Pearson Correlation = 0.1206
# Gene RALA: Pearson Correlation = 0.1821
# Gene BAIAP2L1: Pearson Correlation = 0.0476
# Gene KDM7A: Pearson Correlation = 0.0986
# Gene ETV1: Pearson Correlation = 0.1031
# Gene AGK: Pearson Correlation = 0.1212
# Gene TTC22: Pearson Correlation = 0.0341
# Gene PHTF2: Pearson Correlation = 0.0888
# Gene CCL26: Pearson Correlation = 0.0699
# Gene FARP2: Pearson Correlation = 0.0931
# Gene USH1C: Pearson Correlation = 0.1268
# Gene GGCT: Pearson Correlation = 0.1996
# Gene DBF4: Pearson Correlation = 0.1479
# Gene TBXA2R: Pearson Correlation = 0.1098
# Gene IFRD1: Pearson Correlation = 0.0717
# Gene LGALS14: Pearson Correlation = 0.1788
# Gene COX10: Pearson Correlation = 0.0477
# Gene GTF2IRD1: Pearson Correlation = 0.1436
# Gene PAF1: Pearson Correlation = 0.1453
# Gene VPS41: Pearson Correlation = 0.0855
# Gene ARHGAP44: Pearson Correlation = 0.1291
# Gene ELAC2: Pearson Correlation = 0.1158
# Gene SCIN: Pearson Correlation = 0.1697
# Gene ARSD: Pearson Correlation = 0.0758
# Gene PNPLA4: Pearson Correlation = 0.0649
# Gene MYH13: Pearson Correlation = 0.1057
# Gene ADIPOR2: Pearson Correlation = 0.0119
# Gene CDKL3: Pearson Correlation = 0.1746
# Epoch 2 completed
# Model 2 loaded successfully for epoch 3
# Gene ZFX: Pearson Correlation = 0.0833
# Gene LAMP2: Pearson Correlation = 0.0916
# Gene ITGA2B: Pearson Correlation = 0.0930
# Gene ASB4: Pearson Correlation = 0.0008
# Gene GDE1: Pearson Correlation = -0.0216
# Gene REX1BD: Pearson Correlation = 0.0075
# Gene CRLF1: Pearson Correlation = 0.1244
# Gene OSBPL7: Pearson Correlation = 0.1150
# Gene TMEM98: Pearson Correlation = 0.0973
# Gene YBX2: Pearson Correlation = 0.0540
# Gene KRT33A: Pearson Correlation = 0.1146
# Gene ABCC8: Pearson Correlation = 0.0360
# Gene CACNG3: Pearson Correlation = 0.0750
# Gene TMEM132A: Pearson Correlation = 0.1868
# Gene AP2B1: Pearson Correlation = 0.0312
# Gene TAC1: Pearson Correlation = 0.1088
# Gene ZNF263: Pearson Correlation = 0.0809
# Gene CX3CL1: Pearson Correlation = 0.0519
# Gene SPATA20: Pearson Correlation = 0.0413
# Gene CACNA1G: Pearson Correlation = 0.1406
# Gene TNFRSF12A: Pearson Correlation = 0.1240
# Gene DLX6: Pearson Correlation = 0.1512
# Gene MAP3K9: Pearson Correlation = 0.1247
# Gene RALA: Pearson Correlation = 0.1770
# Gene BAIAP2L1: Pearson Correlation = 0.0502
# Gene KDM7A: Pearson Correlation = 0.1136
# Gene ETV1: Pearson Correlation = 0.1127
# Gene AGK: Pearson Correlation = 0.1114
# Gene TTC22: Pearson Correlation = 0.0675
# Gene PHTF2: Pearson Correlation = 0.1085
# Gene CCL26: Pearson Correlation = 0.0746
# Gene FARP2: Pearson Correlation = 0.1079
# Gene USH1C: Pearson Correlation = 0.1513
# Gene GGCT: Pearson Correlation = 0.2013
# Gene DBF4: Pearson Correlation = 0.1630
# Gene TBXA2R: Pearson Correlation = 0.1182
# Gene IFRD1: Pearson Correlation = 0.0873
# Gene LGALS14: Pearson Correlation = 0.1929
# Gene COX10: Pearson Correlation = 0.0851
# Gene GTF2IRD1: Pearson Correlation = 0.1581
# Gene PAF1: Pearson Correlation = 0.1377
# Gene VPS41: Pearson Correlation = 0.0993
# Gene ARHGAP44: Pearson Correlation = 0.1026
# Gene ELAC2: Pearson Correlation = 0.1148
# Gene SCIN: Pearson Correlation = 0.1623
# Gene ARSD: Pearson Correlation = 0.1143
# Gene PNPLA4: Pearson Correlation = 0.0892
# Gene MYH13: Pearson Correlation = 0.1122
# Gene ADIPOR2: Pearson Correlation = 0.0242
# Gene CDKL3: Pearson Correlation = 0.1699
# Epoch 3 completed
# Model 3 loaded successfully for epoch 4
# Gene ZFX: Pearson Correlation = 0.0954
# Gene LAMP2: Pearson Correlation = 0.0903
# Gene ITGA2B: Pearson Correlation = 0.1008
# Gene ASB4: Pearson Correlation = 0.0041
# Gene GDE1: Pearson Correlation = 0.0053
# Gene REX1BD: Pearson Correlation = 0.0255
# Gene CRLF1: Pearson Correlation = 0.1215
# Gene OSBPL7: Pearson Correlation = 0.1132
# Gene TMEM98: Pearson Correlation = 0.1126
# Gene YBX2: Pearson Correlation = 0.0602
# Gene KRT33A: Pearson Correlation = 0.1303
# Gene ABCC8: Pearson Correlation = 0.0533
# Gene CACNG3: Pearson Correlation = 0.0837
# Gene TMEM132A: Pearson Correlation = 0.2075
# Gene AP2B1: Pearson Correlation = 0.0427
# Gene TAC1: Pearson Correlation = 0.1322
# Gene ZNF263: Pearson Correlation = 0.0883
# Gene CX3CL1: Pearson Correlation = 0.0716
# Gene SPATA20: Pearson Correlation = 0.0508
# Gene CACNA1G: Pearson Correlation = 0.1604
# Gene TNFRSF12A: Pearson Correlation = 0.1248
# Gene DLX6: Pearson Correlation = 0.1448
# Gene MAP3K9: Pearson Correlation = 0.1247
# Gene RALA: Pearson Correlation = 0.1652
# Gene BAIAP2L1: Pearson Correlation = 0.0558
# Gene KDM7A: Pearson Correlation = 0.1202
# Gene ETV1: Pearson Correlation = 0.1145
# Gene AGK: Pearson Correlation = 0.1104
# Gene TTC22: Pearson Correlation = 0.0863
# Gene PHTF2: Pearson Correlation = 0.1164
# Gene CCL26: Pearson Correlation = 0.0957
# Gene FARP2: Pearson Correlation = 0.1278
# Gene USH1C: Pearson Correlation = 0.1576
# Gene GGCT: Pearson Correlation = 0.1867
# Gene DBF4: Pearson Correlation = 0.1661
# Gene TBXA2R: Pearson Correlation = 0.1221
# Gene IFRD1: Pearson Correlation = 0.0992
# Gene LGALS14: Pearson Correlation = 0.1854
# Gene COX10: Pearson Correlation = 0.1010
# Gene GTF2IRD1: Pearson Correlation = 0.1593
# Gene PAF1: Pearson Correlation = 0.1283
# Gene VPS41: Pearson Correlation = 0.1176
# Gene ARHGAP44: Pearson Correlation = 0.1125
# Gene ELAC2: Pearson Correlation = 0.1290
# Gene SCIN: Pearson Correlation = 0.1563
# Gene ARSD: Pearson Correlation = 0.1255
# Gene PNPLA4: Pearson Correlation = 0.0963
# Gene MYH13: Pearson Correlation = 0.1369
# Gene ADIPOR2: Pearson Correlation = 0.0267
# Gene CDKL3: Pearson Correlation = 0.1690
# Epoch 4 completed
# Model 4 loaded successfully for epoch 5
# Gene ZFX: Pearson Correlation = 0.1050
# Gene LAMP2: Pearson Correlation = 0.0972
# Gene ITGA2B: Pearson Correlation = 0.1119
# Gene ASB4: Pearson Correlation = -0.0057
# Gene GDE1: Pearson Correlation = 0.0149
# Gene REX1BD: Pearson Correlation = 0.0415
# Gene CRLF1: Pearson Correlation = 0.1226
# Gene OSBPL7: Pearson Correlation = 0.1164
# Gene TMEM98: Pearson Correlation = 0.1044
# Gene YBX2: Pearson Correlation = 0.0704
# Gene KRT33A: Pearson Correlation = 0.1344
# Gene ABCC8: Pearson Correlation = 0.0512
# Gene CACNG3: Pearson Correlation = 0.0753
# Gene TMEM132A: Pearson Correlation = 0.2172
# Gene AP2B1: Pearson Correlation = 0.0445
# Gene TAC1: Pearson Correlation = 0.1435
# Gene ZNF263: Pearson Correlation = 0.0911
# Gene CX3CL1: Pearson Correlation = 0.0906
# Gene SPATA20: Pearson Correlation = 0.0706
# Gene CACNA1G: Pearson Correlation = 0.1699
# Gene TNFRSF12A: Pearson Correlation = 0.1368
# Gene DLX6: Pearson Correlation = 0.1553
# Gene MAP3K9: Pearson Correlation = 0.1428
# Gene RALA: Pearson Correlation = 0.1696
# Gene BAIAP2L1: Pearson Correlation = 0.0701
# Gene KDM7A: Pearson Correlation = 0.1251
# Gene ETV1: Pearson Correlation = 0.1232
# Gene AGK: Pearson Correlation = 0.1107
# Gene TTC22: Pearson Correlation = 0.0903
# Gene PHTF2: Pearson Correlation = 0.1197
# Gene CCL26: Pearson Correlation = 0.1022
# Gene FARP2: Pearson Correlation = 0.1339
# Gene USH1C: Pearson Correlation = 0.1678
# Gene GGCT: Pearson Correlation = 0.1794
# Gene DBF4: Pearson Correlation = 0.1755
# Gene TBXA2R: Pearson Correlation = 0.1178
# Gene IFRD1: Pearson Correlation = 0.1043
# Gene LGALS14: Pearson Correlation = 0.1785
# Gene COX10: Pearson Correlation = 0.1013
# Gene GTF2IRD1: Pearson Correlation = 0.1510
# Gene PAF1: Pearson Correlation = 0.1258
# Gene VPS41: Pearson Correlation = 0.1331
# Gene ARHGAP44: Pearson Correlation = 0.1171
# Gene ELAC2: Pearson Correlation = 0.1397
# Gene SCIN: Pearson Correlation = 0.1582
# Gene ARSD: Pearson Correlation = 0.1329
# Gene PNPLA4: Pearson Correlation = 0.1039
# Gene MYH13: Pearson Correlation = 0.1415
# Gene ADIPOR2: Pearson Correlation = 0.0296
# Gene CDKL3: Pearson Correlation = 0.1765
# Epoch 5 completed
# Model 5 loaded successfully for epoch 6
# Gene ZFX: Pearson Correlation = 0.1171
# Gene LAMP2: Pearson Correlation = 0.1028
# Gene ITGA2B: Pearson Correlation = 0.1220
# Gene ASB4: Pearson Correlation = 0.0016
# Gene GDE1: Pearson Correlation = 0.0245
# Gene REX1BD: Pearson Correlation = 0.0566
# Gene CRLF1: Pearson Correlation = 0.1288
# Gene OSBPL7: Pearson Correlation = 0.1236
# Gene TMEM98: Pearson Correlation = 0.1025
# Gene YBX2: Pearson Correlation = 0.0770
# Gene KRT33A: Pearson Correlation = 0.1414
# Gene ABCC8: Pearson Correlation = 0.0614
# Gene CACNG3: Pearson Correlation = 0.0774
# Gene TMEM132A: Pearson Correlation = 0.2215
# Gene AP2B1: Pearson Correlation = 0.0465
# Gene TAC1: Pearson Correlation = 0.1481
# Gene ZNF263: Pearson Correlation = 0.0992
# Gene CX3CL1: Pearson Correlation = 0.0979
# Gene SPATA20: Pearson Correlation = 0.0747
# Gene CACNA1G: Pearson Correlation = 0.1768
# Gene TNFRSF12A: Pearson Correlation = 0.1426
# Gene DLX6: Pearson Correlation = 0.1634
# Gene MAP3K9: Pearson Correlation = 0.1562
# Gene RALA: Pearson Correlation = 0.1737
# Gene BAIAP2L1: Pearson Correlation = 0.0816
# Gene KDM7A: Pearson Correlation = 0.1417
# Gene ETV1: Pearson Correlation = 0.1392
# Gene AGK: Pearson Correlation = 0.1112
# Gene TTC22: Pearson Correlation = 0.0970
# Gene PHTF2: Pearson Correlation = 0.1264
# Gene CCL26: Pearson Correlation = 0.1106
# Gene FARP2: Pearson Correlation = 0.1429
# Gene USH1C: Pearson Correlation = 0.1688
# Gene GGCT: Pearson Correlation = 0.1776
# Gene DBF4: Pearson Correlation = 0.1858
# Gene TBXA2R: Pearson Correlation = 0.1186
# Gene IFRD1: Pearson Correlation = 0.1054
# Gene LGALS14: Pearson Correlation = 0.1802
# Gene COX10: Pearson Correlation = 0.1090
# Gene GTF2IRD1: Pearson Correlation = 0.1548
# Gene PAF1: Pearson Correlation = 0.1279
# Gene VPS41: Pearson Correlation = 0.1391
# Gene ARHGAP44: Pearson Correlation = 0.1176
# Gene ELAC2: Pearson Correlation = 0.1423
# Gene SCIN: Pearson Correlation = 0.1546
# Gene ARSD: Pearson Correlation = 0.1324
# Gene PNPLA4: Pearson Correlation = 0.1107
# Gene MYH13: Pearson Correlation = 0.1471
# Gene ADIPOR2: Pearson Correlation = 0.0279
# Gene CDKL3: Pearson Correlation = 0.1808
# Epoch 6 completed

# %%
! cd datas/ && rm *


import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np
import json
import sys



def initialize_environment(data1_path, data2_path, df_Y_path, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')

    data1 = pd.read_csv(data1_path)
    data2 = pd.read_csv(data2_path)
    df_Y = pd.read_csv(df_Y_path)
    print('Training data loaded successfully')

    loss_fn = nn.MSELoss()
    input_dim = data1.shape[1] + data2.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')
    
    
    return device, data1, data2, df_Y, model, optimizer, loss_fn

def cartesian_product(data1, data2):
    data1['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(data1, data2, on='key').drop(columns=['key'])
    # print(len(combined_data))
    
    return combined_data

def cartesian_product_generator(data1, data2, df_Y, batch_size1):
    for i in range(0, len(data1), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = data1.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y

def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


# Main Training Loop
def main_training_loop(data1_path, data2_path, df_Y_path, 
                               data1_test_path_A, data2_test_path_A, df_Y_test_path_A, 
                               data1_test_path_B, data2_test_path_B, df_Y_test_path_B,
                               data1_test_path_C, data2_test_path_C, df_Y_test_path_C,
                               batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size=128):
    

    device, data1, data2, df_Y, model, optimizer, loss_fn = initialize_environment(data1_path, data2_path, df_Y_path, learning_rate)
    # data1 = data1.iloc[:300]

    # display(data1)
    # display(data2)
    # display(df_Y)



    # import time

    # start_epoch = 1
    # end_epoch = 20
    from sklearn.model_selection import train_test_split
    from scipy.stats import pearsonr
    # print(len(data1))
    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs


    gene_predictions = {}
    gene_actuals = {}



    for epoch in range(start_epoch, end_epoch):
        max_index = (len(data1) // batch_size1) * batch_size1
        # print(max_index)
        # # time.sleep(10000)
        max_index = 50 

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []
        test_counter = 0
        for j in range(0, max_index, batch_size1):
            batched_data1 = data1.iloc[j:j+batch_size1]
            model.train()
            if j == 0:
                model = load_model(model, epoch, model_save_path)

            for batch_X, batch_Y in cartesian_product_generator(batched_data1, data2, df_Y, batch_size1):
                
                # Concatenate X and Y DataFrames along the columns axis
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)            

                # Shuffle data
                combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)
                
            

                # Split shuffled data back into X and Y
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                # Then use train_test_split to split the shuffled data into training and test sets
                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.05, shuffle=False)
                # X_test_indices = X_test.index.tolist()  # Get indices of X_test
                # Y_test_indices = Y_test.index.tolist() 


                # if epoch == 1:

                #     sys.exit('stop')
                #     file_name_X = f'X_test_{test_counter}.csv'
                #     file_path_X = os.path.join(model_save_path, file_name_X)
                #     file_name_Y = f'Y_test_{test_counter}.csv'
                #     file_path_Y = os.path.join(model_save_path, file_name_Y)
                #     X_test.to_csv(file_path_X, index=False)
                #     Y_test.to_csv(file_path_Y, index=False)
                #     X_train = X_train.drop(columns=["Gene"])
                    
                #     test_counter += 1
                 
                # else:
                #     sys.exit('stop')
                #     file_name_X = f'X_test_{test_counter}.csv'
                #     file_path_X = os.path.join(model_save_path, file_name_X)
                #     X_test = pd.read_csv(file_path_X)
                #     file_name_Y = f'Y_test_{test_counter}.csv'
                #     file_path_Y = os.path.join(model_save_path, file_name_Y)
                #     Y_test = pd.read_csv(file_path_Y)
                #     X_train = X_train.drop(columns=["Gene"])
                    
                #     test_counter += 1


                # import sys
                # sys.exit('stop')
                # Convert training data to tensor and create dataloader
                X_train = X_train.drop(columns=["Gene"])
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                train_correlations_b = []
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations_b.append(train_correlation)
                epoch_train_losses.append(train_loss / len(train_dataloader))
                epoch_train_correlations.append(np.mean(train_correlations_b))



                # Evaluate on test data
                model.eval()
                with torch.no_grad():
                    # Convert test data to tensor and evaluate
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    # Convert tensors to numpy arrays for correlation computation
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    # Aggregate predictions and actual values for each gene
                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

                # Calculate Pearson correlation for each gene
                gene_correlations = {}
                for gene in gene_predictions.keys():
                    correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                    gene_correlations[gene] = correlation

        # Print or save gene correlations
        for gene, corr in gene_correlations.items():
            print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")

            with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                if epoch == 1:
                    f.write('Epoch,gene,correlation\n')
                f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

        # Save model state and metrics
        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
        print(f'Epoch {epoch} completed')




main_training_loop(data1_path="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_path="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_path='/mnt/data/macaulay/datas/training_crispr.csv',
                   data1_test_path_A="/mnt/data/macaulay/datas/training_gene_embeddings.csv",
                   data2_test_path_A="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_A='/mnt/data/macaulay/datas/A_test_gene__Y_crispr.csv',
                   data1_test_path_B="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_B="/mnt/data/macaulay/datas/training_omicExpression_Embeddings.csv",
                   df_Y_test_path_B='/mnt/data/macaulay/datas/B_test_gene__Y_crispr.csv',
                   data1_test_path_C="/mnt/data/macaulay/datas/test_gene_embeddings.csv",
                   data2_test_path_C="/mnt/data/macaulay/datas/test_omicExpression_Embeddings.csv",
                   df_Y_test_path_C='/mnt/data/macaulay/datas/C_test_gene__Y_crispr.csv',
                   batch_size1=1,learning_rate=0.001,num_epochs=6,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)

                #    model_save_path='/mnt/data/macaulay/datas/model_datas/',test_batch_size=128)

# model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)

# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import os
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
from functions import FullConnectedBlock, NeuralNetwork
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
pd.options.mode.chained_assignment = None
import numpy as np
import json
import sys
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr


def initialize_environment(unirep_train, df_omic_train, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Device:', device)
    print(f'Number of available GPUs: {torch.cuda.device_count()}')
    loss_fn = nn.MSELoss()
    input_dim = unirep_train.shape[1] + df_omic_train.shape[1] - 1
    model = NeuralNetwork(input_dim)
    model = model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    if torch.cuda.device_count() >= 4:
        print("Using 4 GPUs!")
        model = nn.DataParallel(model, device_ids=list(range(4)))
    print('Model initialized successfully')

    return device, model, optimizer, loss_fn


def cartesian_product(unirep_train, data2):
    unirep_train['key'] = 1
    data2['key'] = 1
    combined_data = pd.merge(unirep_train, data2, on='key').drop(columns=['key'])
    return combined_data


def cartesian_product_generator(unirep_train, data2, df_Y, batch_size1):
    for i in range(0, len(unirep_train), batch_size1):
        start_idx = i * len(data2)
        end_idx = (i + batch_size1) * len(data2)
        batch_data1 = unirep_train.iloc[i:i + batch_size1]
        
        batch_X = cartesian_product(batch_data1, data2)
        batch_Y = df_Y.iloc[start_idx:end_idx]
        yield batch_X, batch_Y


def load_model(model, epoch, model_save_path):
    model_path = os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch-1}.pth')

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path))
        print(f'Model {epoch - 1} loaded successfully for epoch {epoch}')
    else:
        print('No saved model found. Training from scratch.')
    return model


def preprocess(unirep, vae, essentiality):
    df_unirep = pd.read_csv(unirep)
    df_essentiality = pd.read_csv(essentiality)
    df_omic = pd.read_csv(vae)
    
    essentiality_train = df_essentiality.iloc[30:, 101:]
    essentiality_test_A = df_essentiality.iloc[:30, 101:]
    essentiality_test_B = df_essentiality.iloc[30:, 1:101]
    essentiality_test_C = df_essentiality.iloc[:30, 1:101]

    flattened_essentiality_train = flatten_to_1D(essentiality_train, type='column')
    flattened_essentiality_test_A = flatten_to_1D(essentiality_test_A, type='column')
    flattened_essentiality_test_B = flatten_to_1D(essentiality_test_B, type='column')
    flattened_essentiality_test_C = flatten_to_1D(essentiality_test_C, type='column')

    print(f'Length of flattened_essentiality_train: {len(flattened_essentiality_train)}')
    print(f'Length of flattened_essentiality_test_A: {len(flattened_essentiality_test_A)}')
    print(f'Length of flattened_essentiality_test_B: {len(flattened_essentiality_test_B)}')
    print(f'Length of flattened_essentiality_test_C: {len(flattened_essentiality_test_C)}')

    df_omic_train = df_omic.iloc[30:, 1:] #train_omic
    df_omic_test = df_omic.iloc[:30, 1:] #test_omic

    unirep_test = df_unirep.iloc[:100] #test_unirep
    unirep_train = df_unirep.iloc[100:] #train_unirep

    return df_omic_train, df_omic_test, unirep_train, unirep_test, flattened_essentiality_train, flattened_essentiality_test_A, flattened_essentiality_test_B, flattened_essentiality_test_C


def flatten_to_1D(df, type='column'):
    if type == 'column':
        df = df.T
    elif type == 'row':
        df = df

    df = df.values.flatten()
    df = pd.DataFrame(df, columns=['Y'])   
    return df


def main_training_loop(unirep_path, vae_path, essentiality_path,
                        batch_size1, learning_rate, num_epochs,
                          model_save_path, test_batch_size=128):
    
    df_omic_train, df_omic_test, unirep_train, unirep_test, flattened_essentiality_train, flattened_essentiality_test_A, flattened_essentiality_test_B, flattened_essentiality_test_C = preprocess(unirep_path, vae_path, essentiality_path)
    device, model, optimizer, loss_fn = initialize_environment(unirep_train, df_omic_train, learning_rate)

    saved_models = os.listdir(model_save_path)
    epochs = [int(file.split('_')[-1].split('.')[0]) for file in saved_models if 'crispr_fc1_model_state_epoch_' in file]
    last_epoch = max(epochs) if epochs else 0
    start_epoch = last_epoch + 1
    end_epoch = start_epoch + num_epochs

    gene_predictions = {}
    gene_actuals = {}

    for epoch in range(start_epoch, end_epoch):
        max_index = (len(unirep_train) // batch_size1) * batch_size1
        max_index = 500

        epoch_train_correlations = []
        epoch_train_losses = []
        epoch_test_correlations = []
        epoch_test_losses = []
        test_counter = 0
        for j in range(0, max_index, batch_size1):
            batched_data1 = unirep_train.iloc[j:j+batch_size1]
            model.train()
            if j == 0:
                model = load_model(model, epoch, model_save_path)

            for batch_X, batch_Y in cartesian_product_generator(batched_data1, df_omic_train, flattened_essentiality_train, batch_size1):
                
                combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)           

                combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)
                
                shuffled_X = combined.iloc[:, :-batch_Y.shape[1]]
                shuffled_Y = combined.iloc[:, -batch_Y.shape[1]:]

                X_train, X_test, Y_train, Y_test = train_test_split(shuffled_X, shuffled_Y, test_size=0.05, shuffle=False)
                X_train = X_train.drop(columns=["Gene"])
                X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
                Y_train_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32).to(device)
                train_data = TensorDataset(X_train_tensor, Y_train_tensor)
                train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
                
                train_loss = 0.0
                train_correlations_b = []
                for inputs, targets in train_dataloader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = loss_fn(outputs, targets)
                    loss.backward()
                    optimizer.step()
                    train_loss += loss.item()
                    train_predictions_np = outputs.detach().cpu().numpy()
                    Y_train_np = targets.cpu().numpy()
                    train_correlation, _ = pearsonr(train_predictions_np.squeeze(), Y_train_np.squeeze())
                    train_correlations_b.append(train_correlation)
                epoch_train_losses.append(train_loss / len(train_dataloader))
                epoch_train_correlations.append(np.mean(train_correlations_b))


                model.eval()
                with torch.no_grad():
                    X_test_tensor = torch.tensor(X_test.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                    Y_test_tensor = torch.tensor(Y_test.values.reshape(-1, 1), dtype=torch.float32).to(device)
                    predictions = model(X_test_tensor)
                    test_loss = loss_fn(predictions, Y_test_tensor)
                    
                    predictions_np = predictions.cpu().numpy()
                    Y_test_np = Y_test_tensor.cpu().numpy()
                    
                    correlation, _ = pearsonr(predictions_np.squeeze(), Y_test_np.squeeze())
                    epoch_test_correlations.append(correlation)
                    epoch_test_losses.append(test_loss.item())

                    for gene in X_test['Gene'].unique():
                        gene_mask = (X_test['Gene'] == gene)
                        X_test_gene = X_test[gene_mask]
                        Y_test_gene = Y_test[gene_mask]

                        X_test_tensor = torch.tensor(X_test_gene.drop(columns=["Gene"]).values, dtype=torch.float32).to(device)
                        Y_test_tensor = torch.tensor(Y_test_gene.values.reshape(-1, 1), dtype=torch.float32).to(device)

                        predictions_gene = model(X_test_tensor)

                        predictions_gene_np = predictions_gene.cpu().numpy().squeeze()
                        Y_test_gene_np = Y_test_tensor.cpu().numpy().squeeze()
                        gene_predictions[gene] = gene_predictions.get(gene, []) + predictions_gene_np.tolist()
                        gene_actuals[gene] = gene_actuals.get(gene, []) + Y_test_gene_np.tolist()

                gene_correlations = {}
                for gene in gene_predictions.keys():
                    correlation, _ = pearsonr(gene_predictions[gene], gene_actuals[gene])
                    gene_correlations[gene] = correlation

        for gene, corr in gene_correlations.items():
            print(f"Gene {gene}: Pearson Correlation = {corr:.4f}")

            with open(os.path.join(model_save_path, f'gene_correlations.txt'), 'a') as f:
                if epoch == 1:
                    f.write('Epoch,gene,correlation\n')
                f.write(f'Epoch{epoch},{gene},{corr:.4f}\n')
                   

        torch.save(model.state_dict(), os.path.join(model_save_path, f'crispr_fc1_model_state_epoch_{epoch}.pth'))
        with open(os.path.join(model_save_path, f'metrics.txt'), 'a') as f:
            if epoch == 1:
                f.write('epoch,train_loss,train_correlation,test_loss,test_correlation\n')
            f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
        print(f'Epoch {epoch} completed')


main_training_loop(unirep_path="/mnt/data/macaulay/datas/processed_gene_embeddings.csv",
                   vae_path="/mnt/data/macaulay/datas/OmicExpression_embeddings/OmicExpression_embeddings_15.csv",
                   essentiality_path='/mnt/data/macaulay/datas/processed_CRISPRGeneEffect.csv',
                   batch_size1=1,learning_rate=0.001,num_epochs=12,
                   model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)

# model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)"
# Out:
# Length of flattened_essentiality_train: 17034253
# Length of flattened_essentiality_test_A: 526290
# Length of flattened_essentiality_test_B: 97100
# Length of flattened_essentiality_test_C: 3000
# Device: cuda
# Number of available GPUs: 1
# Model initialized successfully
# Model 12 loaded successfully for epoch 13
# Gene ZFX: Pearson Correlation = 0.2568
# Gene LAMP2: Pearson Correlation = 0.2464
# Gene ITGA2B: Pearson Correlation = 0.2177
# Gene ASB4: Pearson Correlation = 0.2271
# Gene GDE1: Pearson Correlation = 0.1865
# Gene REX1BD: Pearson Correlation = 0.2863
# Gene CRLF1: Pearson Correlation = 0.1900
# Gene OSBPL7: Pearson Correlation = 0.2670
# Gene TMEM98: Pearson Correlation = 0.2208
# Gene YBX2: Pearson Correlation = 0.2691
# Gene KRT33A: Pearson Correlation = 0.2188
# Gene ABCC8: Pearson Correlation = 0.2253
# Gene CACNG3: Pearson Correlation = 0.2647
# Gene TMEM132A: Pearson Correlation = 0.2591
# Gene AP2B1: Pearson Correlation = 0.2372
# Gene TAC1: Pearson Correlation = 0.2385
# Gene ZNF263: Pearson Correlation = 0.2993
# Gene CX3CL1: Pearson Correlation = 0.2015
# Gene SPATA20: Pearson Correlation = 0.3046
# Gene CACNA1G: Pearson Correlation = 0.2158
# Gene TNFRSF12A: Pearson Correlation = 0.1766
# Gene DLX6: Pearson Correlation = 0.2453
# Gene MAP3K9: Pearson Correlation = 0.1806
# Gene RALA: Pearson Correlation = 0.2992
# Gene BAIAP2L1: Pearson Correlation = 0.2680
# Gene KDM7A: Pearson Correlation = 0.2595
# Gene ETV1: Pearson Correlation = 0.2320
# Gene AGK: Pearson Correlation = 0.2541
# Gene TTC22: Pearson Correlation = 0.2788
# Gene PHTF2: Pearson Correlation = 0.2373
# Gene CCL26: Pearson Correlation = 0.2273
# Gene FARP2: Pearson Correlation = 0.2420
# Gene USH1C: Pearson Correlation = 0.2209
# Gene GGCT: Pearson Correlation = 0.2354
# Gene DBF4: Pearson Correlation = 0.2407
# Gene TBXA2R: Pearson Correlation = 0.2371
# Gene IFRD1: Pearson Correlation = 0.2622
# Gene LGALS14: Pearson Correlation = 0.2385
# Gene COX10: Pearson Correlation = 0.2087
# Gene GTF2IRD1: Pearson Correlation = 0.2897
# Gene PAF1: Pearson Correlation = 0.2500
# Gene VPS41: Pearson Correlation = 0.2269
# Gene ARHGAP44: Pearson Correlation = 0.2243
# Gene ELAC2: Pearson Correlation = 0.2564
# Gene SCIN: Pearson Correlation = 0.2595
# Gene ARSD: Pearson Correlation = 0.2546
# Gene PNPLA4: Pearson Correlation = 0.2271
# Gene MYH13: Pearson Correlation = 0.2225
# Gene ADIPOR2: Pearson Correlation = 0.2651
# Gene CDKL3: Pearson Correlation = 0.2298
# Gene UPP2: Pearson Correlation = 0.2545
# Gene PRSS21: Pearson Correlation = 0.2093
# Gene MARK4: Pearson Correlation = 0.2509
# Gene PROM1: Pearson Correlation = 0.2459
# Gene CCDC124: Pearson Correlation = 0.2386
# Gene CEACAM21: Pearson Correlation = 0.1861
# Gene PAFAH1B1: Pearson Correlation = 0.2271
# Gene NOS2: Pearson Correlation = 0.2488
# Gene DNAH9: Pearson Correlation = 0.2414
# Gene SLC13A2: Pearson Correlation = 0.2109
# Gene GAS7: Pearson Correlation = 0.2892
# Gene TRAPPC6A: Pearson Correlation = 0.2737
# Gene MATK: Pearson Correlation = 0.2235
# Gene CEACAM7: Pearson Correlation = 0.1988
# Gene CD79B: Pearson Correlation = 0.2538
# Gene SCN4A: Pearson Correlation = 0.2608
# Gene ST7L: Pearson Correlation = 0.2928
# Gene TKTL1: Pearson Correlation = 0.2734
# Gene PAX6: Pearson Correlation = 0.2258
# Gene RPUSD1: Pearson Correlation = 0.2766
# Gene RHBDF1: Pearson Correlation = 0.2686
# Gene LUC7L: Pearson Correlation = 0.2286
# Gene CACNA2D2: Pearson Correlation = 0.2449
# Gene BAIAP3: Pearson Correlation = 0.2848
# Gene TSR3: Pearson Correlation = 0.2681
# Gene PIGQ: Pearson Correlation = 0.2698
# Gene CRAMP1: Pearson Correlation = 0.2367
# Gene TEAD3: Pearson Correlation = 0.2835
# Gene SELE: Pearson Correlation = 0.1579
# Gene DNAJC11: Pearson Correlation = 0.2606
# Gene FMO3: Pearson Correlation = 0.2272
# Gene MYLIP: Pearson Correlation = 0.2781
# Gene NOX1: Pearson Correlation = 0.2580
# Gene E2F2: Pearson Correlation = 0.2877
# Gene PSMB1: Pearson Correlation = 0.2463
# Gene SYN1: Pearson Correlation = 0.2629
# Gene JARID2: Pearson Correlation = 0.2472
# Gene CDKL5: Pearson Correlation = 0.2153
# Gene CAMK1G: Pearson Correlation = 0.2168
# Gene NADK: Pearson Correlation = 0.2677
# Gene TFAP2B: Pearson Correlation = 0.2655
# Gene TFAP2D: Pearson Correlation = 0.2706
# Gene DLEC1: Pearson Correlation = 0.2428
# Gene CYTH3: Pearson Correlation = 0.2608
# Gene ADAM22: Pearson Correlation = 0.1689
# Gene SYPL1: Pearson Correlation = 0.2576
# Gene CYB561: Pearson Correlation = 0.2676
# Gene SPAG9: Pearson Correlation = 0.2462
# Gene CELSR3: Pearson Correlation = 0.1539
# Gene AASS: Pearson Correlation = 0.2766
# Gene PLEKHG6: Pearson Correlation = 0.2751
# Gene SS18L2: Pearson Correlation = 0.2965
# Gene MPND: Pearson Correlation = 0.2562
# Gene MGST1: Pearson Correlation = 0.2576
# Gene CRY1: Pearson Correlation = 0.2608
# Gene PGLYRP1: Pearson Correlation = 0.2515
# Gene NFIX: Pearson Correlation = 0.2743
# Gene ST3GAL1: Pearson Correlation = 0.2487
# Gene MMP25: Pearson Correlation = 0.2608
# Gene IL32: Pearson Correlation = 0.2823
# Gene PKD1: Pearson Correlation = 0.2170
# Gene MED24: Pearson Correlation = 0.2880
# Gene RHOBTB2: Pearson Correlation = 0.2440
# Gene HEATR5B: Pearson Correlation = 0.2281
# Gene SEC62: Pearson Correlation = 0.2313
# Gene RPS20: Pearson Correlation = 0.2999
# Gene CSDE1: Pearson Correlation = 0.2700
# Gene UBE3C: Pearson Correlation = 0.2587
# Gene REV3L: Pearson Correlation = 0.2212
# Gene TENM1: Pearson Correlation = 0.2044
# Gene PAX7: Pearson Correlation = 0.2594
# Gene MASP2: Pearson Correlation = 0.1708
# Gene IYD: Pearson Correlation = 0.2325
# Gene FAM76A: Pearson Correlation = 0.2841
# Gene TRAF3IP3: Pearson Correlation = 0.2582
# Gene POMT2: Pearson Correlation = 0.2422
# Gene VTA1: Pearson Correlation = 0.2898
# Gene MLXIPL: Pearson Correlation = 0.2633
# Gene BAZ1B: Pearson Correlation = 0.2601
# Gene RANBP9: Pearson Correlation = 0.2662
# Gene ETV7: Pearson Correlation = 0.2262
# Gene SPRTN: Pearson Correlation = 0.2226
# Gene DYRK4: Pearson Correlation = 0.2374
# Gene ZNF207: Pearson Correlation = 0.2838
# Gene UQCRC1: Pearson Correlation = 0.2442
# Gene STARD3NL: Pearson Correlation = 0.2601
# Gene CD9: Pearson Correlation = 0.2207
# Gene HHATL: Pearson Correlation = 0.2372
# Gene NCAPD2: Pearson Correlation = 0.2485
# Gene IFFO1: Pearson Correlation = 0.2247
# Gene GIPR: Pearson Correlation = 0.2261
# Gene PHF7: Pearson Correlation = 0.2816
# Gene SEMA3G: Pearson Correlation = 0.2550
# Gene NISCH: Pearson Correlation = 0.2453
# Gene STAB1: Pearson Correlation = 0.1660
# Gene FUZ: Pearson Correlation = 0.3116
# Gene SLC6A13: Pearson Correlation = 0.1945
# Gene IDS: Pearson Correlation = 0.2950
# Gene PRSS3: Pearson Correlation = 0.1815
# Gene ZNF200: Pearson Correlation = 0.3129
# Gene CD4: Pearson Correlation = 0.2267
# Gene LRRC23: Pearson Correlation = 0.2369
# Gene BTK: Pearson Correlation = 0.2575
# Gene HFE: Pearson Correlation = 0.2648
# Gene SCMH1: Pearson Correlation = 0.2268
# Gene FYN: Pearson Correlation = 0.2492
# Gene HIVEP2: Pearson Correlation = 0.2158
# Gene FMO1: Pearson Correlation = 0.2190
# Gene ELOA: Pearson Correlation = 0.1997
# Gene LYPLA2: Pearson Correlation = 0.2725
# Gene CLCN6: Pearson Correlation = 0.2099
# Gene MRC2: Pearson Correlation = 0.1563
# Gene NME2: Pearson Correlation = 0.2457
# Gene SLC6A7: Pearson Correlation = 0.2028
# Gene TSPAN9: Pearson Correlation = 0.2680
# Gene BTBD7: Pearson Correlation = 0.2783
# Gene APBA3: Pearson Correlation = 0.2890
# Gene MKS1: Pearson Correlation = 0.2809
# Gene ABHD5: Pearson Correlation = 0.2146
# Gene ANOS1: Pearson Correlation = 0.1873
# Gene AKAP8L: Pearson Correlation = 0.2417
# Gene MBTD1: Pearson Correlation = 0.2836
# Gene UTP18: Pearson Correlation = 0.1897
# Gene RNF216: Pearson Correlation = 0.2593
# Gene TTC19: Pearson Correlation = 0.2948
# Gene PTBP1: Pearson Correlation = 0.2072
# Gene DPF1: Pearson Correlation = 0.2895
# Gene SYT7: Pearson Correlation = 0.2265
# Gene LARS2: Pearson Correlation = 0.2453
# Gene PIK3C2A: Pearson Correlation = 0.2572
# Gene PLAUR: Pearson Correlation = 0.1493
# Gene ANLN: Pearson Correlation = 0.2073
# Gene WIZ: Pearson Correlation = 0.2522
# Gene RABGAP1: Pearson Correlation = 0.2348
# Gene DCN: Pearson Correlation = 0.1875
# Gene QPCTL: Pearson Correlation = 0.2421
# Gene PPP5C: Pearson Correlation = 0.3138
# Gene CEP68: Pearson Correlation = 0.2288
# Gene MAP4K3: Pearson Correlation = 0.2045
# Gene ZBTB32: Pearson Correlation = 0.2746
# Gene TYROBP: Pearson Correlation = 0.2131
# Gene GABRA3: Pearson Correlation = 0.2699
# Gene BRCA1: Pearson Correlation = 0.2153
# Gene ERCC1: Pearson Correlation = 0.2572
# Gene CD22: Pearson Correlation = 0.1730
# Gene MBTPS2: Pearson Correlation = 0.1917
# Gene PRICKLE3: Pearson Correlation = 0.3056
# Gene LTF: Pearson Correlation = 0.2360
# Gene EXTL3: Pearson Correlation = 0.2515
# Gene NR1H4: Pearson Correlation = 0.2465
# Gene ELOVL5: Pearson Correlation = 0.2739
# Gene ALOX5: Pearson Correlation = 0.3036
# Gene KDM5D: Pearson Correlation = 0.2709
# Gene CALCOCO1: Pearson Correlation = 0.2223
# Gene UBR7: Pearson Correlation = 0.2786
# Gene EHD3: Pearson Correlation = 0.3091
# Gene PSMC4: Pearson Correlation = 0.2588
# Gene MAN2B2: Pearson Correlation = 0.2940
# Gene SLC7A14: Pearson Correlation = 0.2219
# Gene CLDN11: Pearson Correlation = 0.2974
# Gene SLC25A39: Pearson Correlation = 0.2638
# Gene MVP: Pearson Correlation = 0.2699
# Gene NUB1: Pearson Correlation = 0.2983
# Gene PGM3: Pearson Correlation = 0.2740
# Gene RWDD2A: Pearson Correlation = 0.2681
# Gene CLK1: Pearson Correlation = 0.2191
# Gene POLR3B: Pearson Correlation = 0.2744
# Gene ANGEL1: Pearson Correlation = 0.3505
# Gene RNF14: Pearson Correlation = 0.2544
# Gene DNASE1L1: Pearson Correlation = 0.2841
# Gene DDX11: Pearson Correlation = 0.1593
# Gene HEBP1: Pearson Correlation = 0.2416
# Gene GPRC5A: Pearson Correlation = 0.2811
# Gene MAMLD1: Pearson Correlation = 0.2930
# Gene CD6: Pearson Correlation = 0.1572
# Gene TACC3: Pearson Correlation = 0.2271
# Gene UFL1: Pearson Correlation = 0.2563
# Gene POLA2: Pearson Correlation = 0.2737
# Gene ZC3H3: Pearson Correlation = 0.2102
# Gene CAPN1: Pearson Correlation = 0.2296
# Gene ACP3: Pearson Correlation = 0.2518
# Gene MDH1: Pearson Correlation = 0.3136
# Gene SLC30A9: Pearson Correlation = 0.2422
# Gene MTMR11: Pearson Correlation = 0.2596
# Gene COX15: Pearson Correlation = 0.2478
# Gene CCDC88C: Pearson Correlation = 0.2389
# Gene YAF2: Pearson Correlation = 0.2344
# Gene ZMYND11: Pearson Correlation = 0.2923
# Gene WAS: Pearson Correlation = 0.2824
# Gene DPEP1: Pearson Correlation = 0.2085
# Gene BID: Pearson Correlation = 0.2958
# Gene MATR3: Pearson Correlation = 0.2266
# Gene NPC1L1: Pearson Correlation = 0.2271
# Gene XYLT2: Pearson Correlation = 0.2680
# Gene STMN4: Pearson Correlation = 0.2749
# Gene NUDCD3: Pearson Correlation = 0.2735
# Gene ISL1: Pearson Correlation = 0.2646
# Gene CHDH: Pearson Correlation = 0.2205
# Gene IL20RA: Pearson Correlation = 0.1959
# Gene CLCA1: Pearson Correlation = 0.2312
# Gene CLCA4: Pearson Correlation = 0.2491
# Gene GLT8D1: Pearson Correlation = 0.2391
# Gene ATP2C1: Pearson Correlation = 0.2268
# Gene IGF1: Pearson Correlation = 0.2600
# Gene SLC38A5: Pearson Correlation = 0.2494
# Gene RALBP1: Pearson Correlation = 0.2888
# Gene RUFY3: Pearson Correlation = 0.2662
# Gene CNTN1: Pearson Correlation = 0.1845
# Gene SLC11A1: Pearson Correlation = 0.2547
# Gene WWTR1: Pearson Correlation = 0.3252
# Gene AGPS: Pearson Correlation = 0.2435
# Gene ATP1A2: Pearson Correlation = 0.2238
# Gene TTC27: Pearson Correlation = 0.3190
# Gene ZNF582: Pearson Correlation = 0.3074
# Gene VSIG2: Pearson Correlation = 0.2363
# Gene PHLDB1: Pearson Correlation = 0.2598
# Gene MARCO: Pearson Correlation = 0.2412
# Gene CYP24A1: Pearson Correlation = 0.2220
# Gene PRDM11: Pearson Correlation = 0.2878
# Gene SYT13: Pearson Correlation = 0.2472
# Gene SNAI2: Pearson Correlation = 0.2779
# Gene CD74: Pearson Correlation = 0.2920
# Gene HGF: Pearson Correlation = 0.1754
# Gene ZRANB1: Pearson Correlation = 0.2644
# Gene NCDN: Pearson Correlation = 0.2395
# Gene ADGRA2: Pearson Correlation = 0.2335
# Gene ZFP64: Pearson Correlation = 0.2330
# Gene MNAT1: Pearson Correlation = 0.2467
# Gene SAMD4A: Pearson Correlation = 0.2881
# Gene RUNX3: Pearson Correlation = 0.3009
# Gene MRE11: Pearson Correlation = 0.2348
# Gene PLEKHB1: Pearson Correlation = 0.3004
# Gene SERPINB1: Pearson Correlation = 0.2796
# Gene CYP3A43: Pearson Correlation = 0.2145
# Gene SLC7A9: Pearson Correlation = 0.2529
# Gene SPAST: Pearson Correlation = 0.2898
# Gene NRXN3: Pearson Correlation = 0.2478
# Gene OSBPL5: Pearson Correlation = 0.2986
# Gene AQR: Pearson Correlation = 0.2428
# Gene CPS1: Pearson Correlation = 0.2480
# Gene C8B: Pearson Correlation = 0.1774
# Gene FHL1: Pearson Correlation = 0.3024
# Gene RTF2: Pearson Correlation = 0.2329
# Gene GABRA1: Pearson Correlation = 0.2630
# Gene NLRP2: Pearson Correlation = 0.2306
# Gene SLC45A4: Pearson Correlation = 0.2222
# Gene RNF10: Pearson Correlation = 0.2642
# Gene ZNF839: Pearson Correlation = 0.2524
# Gene ZDHHC6: Pearson Correlation = 0.2378
# Gene GRAMD1B: Pearson Correlation = 0.2986
# Gene RNH1: Pearson Correlation = 0.2251
# Gene NDUFS1: Pearson Correlation = 0.2492
# Gene RB1CC1: Pearson Correlation = 0.2752
# Gene ERP44: Pearson Correlation = 0.2627
# Gene ALAS1: Pearson Correlation = 0.2950
# Gene BIRC3: Pearson Correlation = 0.2477
# Gene AKAP11: Pearson Correlation = 0.2391
# Gene GLRX2: Pearson Correlation = 0.2819
# Gene SNAPC1: Pearson Correlation = 0.2670
# Gene DERA: Pearson Correlation = 0.2285
# Gene STRAP: Pearson Correlation = 0.1862
# Gene ABCC2: Pearson Correlation = 0.2209
# Gene DEF6: Pearson Correlation = 0.2673
# Gene PLEKHO1: Pearson Correlation = 0.2718
# Gene GCLM: Pearson Correlation = 0.2416
# Gene UBR2: Pearson Correlation = 0.2588
# Gene EHD2: Pearson Correlation = 0.2753
# Gene DEPDC1: Pearson Correlation = 0.2620
# Gene CCDC28A: Pearson Correlation = 0.2699
# Gene RRAGD: Pearson Correlation = 0.3130
# Gene HSF2: Pearson Correlation = 0.2663
# Gene PHF20: Pearson Correlation = 0.2245
# Gene HSD17B6: Pearson Correlation = 0.2672
# Gene NR1H3: Pearson Correlation = 0.2537
# Gene TYMP: Pearson Correlation = 0.2198
# Gene NCAPH2: Pearson Correlation = 0.2455
# Gene TOMM34: Pearson Correlation = 0.2954
# Gene SEC63: Pearson Correlation = 0.2487
# Gene KPNA6: Pearson Correlation = 0.2547
# Gene VIM: Pearson Correlation = 0.2551
# Gene FAS: Pearson Correlation = 0.2389
# Gene RNASET2: Pearson Correlation = 0.2733
# Gene CD44: Pearson Correlation = 0.1997
# Gene KCNG1: Pearson Correlation = 0.2385
# Gene AGPAT4: Pearson Correlation = 0.2682
# Gene SLAMF7: Pearson Correlation = 0.1935
# Gene BTN3A1: Pearson Correlation = 0.2234
# Gene MIPEP: Pearson Correlation = 0.1986
# Gene PRKCH: Pearson Correlation = 0.2089
# Gene INSRR: Pearson Correlation = 0.2178
# Gene IFNGR1: Pearson Correlation = 0.2164
# Gene B4GALT7: Pearson Correlation = 0.2711
# Gene SH2D2A: Pearson Correlation = 0.2659
# Gene VRK2: Pearson Correlation = 0.2268
# Gene TNFRSF1B: Pearson Correlation = 0.1986
# Gene VEZT: Pearson Correlation = 0.2419
# Gene POU2F2: Pearson Correlation = 0.2557
# Gene BRD9: Pearson Correlation = 0.2550
# Gene SNX1: Pearson Correlation = 0.2563
# Gene TBPL1: Pearson Correlation = 0.2372
# Gene BCLAF1: Pearson Correlation = 0.1803
# Gene SLC39A9: Pearson Correlation = 0.2371
# Gene ANK1: Pearson Correlation = 0.2693
# Gene IBSP: Pearson Correlation = 0.2397
# Gene TFB1M: Pearson Correlation = 0.2208
# Gene RABEP1: Pearson Correlation = 0.2114
# Gene HMGB3: Pearson Correlation = 0.2717
# Gene NUP160: Pearson Correlation = 0.2790
# Gene BAK1: Pearson Correlation = 0.2699
# Gene MUSK: Pearson Correlation = 0.1832
# Gene IKZF2: Pearson Correlation = 0.2599
# Gene GRN: Pearson Correlation = 0.1490
# Gene FAM13B: Pearson Correlation = 0.2597
# Gene ARHGAP31: Pearson Correlation = 0.2609
# Gene CENPQ: Pearson Correlation = 0.2728
# Gene SARS1: Pearson Correlation = 0.2833
# Gene RANBP3: Pearson Correlation = 0.2772
# Gene ARID4A: Pearson Correlation = 0.2575
# Gene EIPR1: Pearson Correlation = 0.2547
# Gene PNPLA6: Pearson Correlation = 0.3002
# Gene IFT88: Pearson Correlation = 0.2777
# Gene ALG1: Pearson Correlation = 0.2843
# Gene CHPF2: Pearson Correlation = 0.2575
# Gene FUT8: Pearson Correlation = 0.2664
# Gene UBA6: Pearson Correlation = 0.2533
# Gene GAB2: Pearson Correlation = 0.2642
# Gene ATP6V0A1: Pearson Correlation = 0.2485
# Gene PIAS1: Pearson Correlation = 0.2803
# Gene SLC4A7: Pearson Correlation = 0.2639
# Gene APBA2: Pearson Correlation = 0.2597
# Gene MAP2K3: Pearson Correlation = 0.2424
# Gene TMSB10: Pearson Correlation = 0.3048
# Gene ASTE1: Pearson Correlation = 0.2529
# Gene RNF19A: Pearson Correlation = 0.2358
# Gene PEX3: Pearson Correlation = 0.2588
# Gene GABARAPL2: Pearson Correlation = 0.2900
# Gene MYOC: Pearson Correlation = 0.2835
# Gene SH3YL1: Pearson Correlation = 0.2481
# Gene FAM136A: Pearson Correlation = 0.2878
# Gene VCL: Pearson Correlation = 0.2563
# Gene DEPDC1B: Pearson Correlation = 0.2976
# Gene DAPK2: Pearson Correlation = 0.2273
# Gene NSMAF: Pearson Correlation = 0.2811
# Gene ADSS2: Pearson Correlation = 0.2533
# Gene STAP1: Pearson Correlation = 0.2824
# Gene TIMP2: Pearson Correlation = 0.2322
# Gene RFC1: Pearson Correlation = 0.2113
# Gene TBC1D23: Pearson Correlation = 0.3014
# Gene CUL3: Pearson Correlation = 0.2861
# Gene MYOM2: Pearson Correlation = 0.1794
# Gene OTC: Pearson Correlation = 0.3045
# Gene CYP46A1: Pearson Correlation = 0.2338
# Gene ZZZ3: Pearson Correlation = 0.2599
# Gene SLC18A1: Pearson Correlation = 0.2306
# Gene USP2: Pearson Correlation = 0.3285
# Gene CASR: Pearson Correlation = 0.2595
# Gene TUBG2: Pearson Correlation = 0.2719
# Gene RPL26L1: Pearson Correlation = 0.2751
# Gene FLT4: Pearson Correlation = 0.2292
# Gene NSUN2: Pearson Correlation = 0.2790
# Gene FBXO42: Pearson Correlation = 0.2551
# Gene MFAP3: Pearson Correlation = 0.2447
# Gene MRI1: Pearson Correlation = 0.2443
# Gene METTL1: Pearson Correlation = 0.2526
# Gene HOXC8: Pearson Correlation = 0.2597
# Gene AGA: Pearson Correlation = 0.2328
# Gene PI4K2B: Pearson Correlation = 0.2850
# Gene BOD1L1: Pearson Correlation = 0.1796
# Gene MAT2B: Pearson Correlation = 0.3078
# Gene TLL1: Pearson Correlation = 0.1812
# Gene EDC4: Pearson Correlation = 0.2739
# Gene TRIO: Pearson Correlation = 0.2644
# Gene VCAN: Pearson Correlation = 0.1833
# Gene CLEC16A: Pearson Correlation = 0.2871
# Gene MSR1: Pearson Correlation = 0.2481
# Gene CDH1: Pearson Correlation = 0.1626
# Gene MTREX: Pearson Correlation = 0.2111
# Gene DNAH5: Pearson Correlation = 0.2603
# Gene ZFYVE16: Pearson Correlation = 0.2524
# Gene RIPOR1: Pearson Correlation = 0.2576
# Gene C6: Pearson Correlation = 0.1712
# Gene RAI14: Pearson Correlation = 0.2767
# Gene SOX30: Pearson Correlation = 0.2819
# Gene PNKP: Pearson Correlation = 0.2887
# Gene BEST2: Pearson Correlation = 0.2364
# Gene PHLPP2: Pearson Correlation = 0.2142
# Gene SPDL1: Pearson Correlation = 0.2513
# Gene STAU2: Pearson Correlation = 0.2812
# Gene SLC66A1: Pearson Correlation = 0.1921
# Gene CTNS: Pearson Correlation = 0.2522
# Gene RTN4R: Pearson Correlation = 0.2329
# Gene PHF23: Pearson Correlation = 0.2861
# Gene CDH10: Pearson Correlation = 0.2019
# Gene INPP4A: Pearson Correlation = 0.2704
# Gene RAB27B: Pearson Correlation = 0.2486
# Gene PSMA4: Pearson Correlation = 0.2939
# Gene MYO16: Pearson Correlation = 0.2632
# Gene LSG1: Pearson Correlation = 0.2667
# Gene PARP3: Pearson Correlation = 0.3092
# Gene TNC: Pearson Correlation = 0.1734
# Gene THAP3: Pearson Correlation = 0.3050
# Gene RIPOR3: Pearson Correlation = 0.2848
# Gene TDP1: Pearson Correlation = 0.2679
# Gene AIFM2: Pearson Correlation = 0.2708
# Gene SPATA7: Pearson Correlation = 0.2823
# Gene MED17: Pearson Correlation = 0.3054
# Gene RETSAT: Pearson Correlation = 0.2908
# Gene CAPG: Pearson Correlation = 0.3061
# Gene AP2S1: Pearson Correlation = 0.2772
# Gene USH2A: Pearson Correlation = 0.1805
# Gene ZPBP: Pearson Correlation = 0.2781
# Gene TG: Pearson Correlation = 0.2220
# Gene ADAM28: Pearson Correlation = 0.2262
# Gene BARX2: Pearson Correlation = 0.2832
# Gene DCUN1D1: Pearson Correlation = 0.3059
# Gene JADE2: Pearson Correlation = 0.2839
# Gene ZIC2: Pearson Correlation = 0.3062
# Gene LCP2: Pearson Correlation = 0.2405
# Gene TRIT1: Pearson Correlation = 0.2679
# Gene ADRB1: Pearson Correlation = 0.2425
# Gene GUCA2B: Pearson Correlation = 0.2497
# Gene CUL7: Pearson Correlation = 0.2434
# Gene CTNNA1: Pearson Correlation = 0.2466
# Gene PHKA2: Pearson Correlation = 0.2264
# Gene CNTLN: Pearson Correlation = 0.2208
# Gene EPHA3: Pearson Correlation = 0.1986
# Gene HSPA5: Pearson Correlation = 0.3064
# Gene DSG2: Pearson Correlation = 0.2013
# Gene GEMIN8: Pearson Correlation = 0.2817
# Gene OFD1: Pearson Correlation = 0.2613
# Gene GPM6B: Pearson Correlation = 0.2517
# Gene MAGEC2: Pearson Correlation = 0.3217
# Gene PREX2: Pearson Correlation = 0.2635
# Gene WDR37: Pearson Correlation = 0.2106
# Gene YTHDC2: Pearson Correlation = 0.2088
# Gene CTPS2: Pearson Correlation = 0.2912
# Gene ATP6V1H: Pearson Correlation = 0.2460
# Gene POLR2B: Pearson Correlation = 0.2815
# Gene ARAP2: Pearson Correlation = 0.2466
# Gene TPR: Pearson Correlation = 0.2359
# Gene CP: Pearson Correlation = 0.2277
# Gene KATNIP: Pearson Correlation = 0.2618
# Gene DTNBP1: Pearson Correlation = 0.2637
# Gene XK: Pearson Correlation = 0.2619
# Gene ANO2: Pearson Correlation = 0.2654
# Gene C12orf4: Pearson Correlation = 0.2952
# Gene SCML1: Pearson Correlation = 0.3007
# Gene ARHGAP6: Pearson Correlation = 0.2644
# Gene FAM184B: Pearson Correlation = 0.2570
# Gene MAP4: Pearson Correlation = 0.2176
# Epoch 13 completed
# Model 13 loaded successfully for epoch 14
# Gene ZFX: Pearson Correlation = 0.2674
# Gene LAMP2: Pearson Correlation = 0.2537
# Gene ITGA2B: Pearson Correlation = 0.2326
# Gene ASB4: Pearson Correlation = 0.2332
# Gene GDE1: Pearson Correlation = 0.2043
# Gene REX1BD: Pearson Correlation = 0.3041
# Gene CRLF1: Pearson Correlation = 0.2054
# Gene OSBPL7: Pearson Correlation = 0.2736
# Gene TMEM98: Pearson Correlation = 0.2301
# Gene YBX2: Pearson Correlation = 0.2753
# Gene KRT33A: Pearson Correlation = 0.2201
# Gene ABCC8: Pearson Correlation = 0.2355
# Gene CACNG3: Pearson Correlation = 0.2749
# Gene TMEM132A: Pearson Correlation = 0.2625
# Gene AP2B1: Pearson Correlation = 0.2280
# Gene TAC1: Pearson Correlation = 0.2508
# Gene ZNF263: Pearson Correlation = 0.2954
# Gene CX3CL1: Pearson Correlation = 0.2073
# Gene SPATA20: Pearson Correlation = 0.3142
# Gene CACNA1G: Pearson Correlation = 0.2300
# Gene TNFRSF12A: Pearson Correlation = 0.1914
# Gene DLX6: Pearson Correlation = 0.2461
# Gene MAP3K9: Pearson Correlation = 0.1937
# Gene RALA: Pearson Correlation = 0.2894
# Gene BAIAP2L1: Pearson Correlation = 0.2775
# Gene KDM7A: Pearson Correlation = 0.2672
# Gene ETV1: Pearson Correlation = 0.2288
# Gene AGK: Pearson Correlation = 0.2493
# Gene TTC22: Pearson Correlation = 0.2862
# Gene PHTF2: Pearson Correlation = 0.2464
# Gene CCL26: Pearson Correlation = 0.2470
# Gene FARP2: Pearson Correlation = 0.2517
# Gene USH1C: Pearson Correlation = 0.2310
# Gene GGCT: Pearson Correlation = 0.2401
# Gene DBF4: Pearson Correlation = 0.2529
# Gene TBXA2R: Pearson Correlation = 0.2475
# Gene IFRD1: Pearson Correlation = 0.2706
# Gene LGALS14: Pearson Correlation = 0.2521
# Gene COX10: Pearson Correlation = 0.2136
# Gene GTF2IRD1: Pearson Correlation = 0.3028
# Gene PAF1: Pearson Correlation = 0.2508
# Gene VPS41: Pearson Correlation = 0.2396
# Gene ARHGAP44: Pearson Correlation = 0.2400
# Gene ELAC2: Pearson Correlation = 0.2549
# Gene SCIN: Pearson Correlation = 0.2664
# Gene ARSD: Pearson Correlation = 0.2650
# Gene PNPLA4: Pearson Correlation = 0.2340
# Gene MYH13: Pearson Correlation = 0.2168
# Gene ADIPOR2: Pearson Correlation = 0.2697
# Gene CDKL3: Pearson Correlation = 0.2197
# Gene UPP2: Pearson Correlation = 0.2505
# Gene PRSS21: Pearson Correlation = 0.2053
# Gene MARK4: Pearson Correlation = 0.2409
# Gene PROM1: Pearson Correlation = 0.2477
# Gene CCDC124: Pearson Correlation = 0.2521
# Gene CEACAM21: Pearson Correlation = 0.1988
# Gene PAFAH1B1: Pearson Correlation = 0.2232
# Gene NOS2: Pearson Correlation = 0.2563
# Gene DNAH9: Pearson Correlation = 0.2425
# Gene SLC13A2: Pearson Correlation = 0.2113
# Gene GAS7: Pearson Correlation = 0.2898
# Gene TRAPPC6A: Pearson Correlation = 0.2839
# Gene MATK: Pearson Correlation = 0.2297
# Gene CEACAM7: Pearson Correlation = 0.2073
# Gene CD79B: Pearson Correlation = 0.2596
# Gene SCN4A: Pearson Correlation = 0.2537
# Gene ST7L: Pearson Correlation = 0.2902
# Gene TKTL1: Pearson Correlation = 0.2724
# Gene PAX6: Pearson Correlation = 0.2240
# Gene RPUSD1: Pearson Correlation = 0.2715
# Gene RHBDF1: Pearson Correlation = 0.2673
# Gene LUC7L: Pearson Correlation = 0.2165
# Gene CACNA2D2: Pearson Correlation = 0.2408
# Gene BAIAP3: Pearson Correlation = 0.2775
# Gene TSR3: Pearson Correlation = 0.2617
# Gene PIGQ: Pearson Correlation = 0.2734
# Gene CRAMP1: Pearson Correlation = 0.2315
# Gene TEAD3: Pearson Correlation = 0.2856
# Gene SELE: Pearson Correlation = 0.1500
# Gene DNAJC11: Pearson Correlation = 0.2602
# Gene FMO3: Pearson Correlation = 0.2226
# Gene MYLIP: Pearson Correlation = 0.2734
# Gene NOX1: Pearson Correlation = 0.2588
# Gene E2F2: Pearson Correlation = 0.2790
# Gene PSMB1: Pearson Correlation = 0.2369
# Gene SYN1: Pearson Correlation = 0.2585
# Gene JARID2: Pearson Correlation = 0.2465
# Gene CDKL5: Pearson Correlation = 0.2166
# Gene CAMK1G: Pearson Correlation = 0.2186
# Gene NADK: Pearson Correlation = 0.2774
# Gene TFAP2B: Pearson Correlation = 0.2676
# Gene TFAP2D: Pearson Correlation = 0.2824
# Gene DLEC1: Pearson Correlation = 0.2560
# Gene CYTH3: Pearson Correlation = 0.2718
# Gene ADAM22: Pearson Correlation = 0.1749
# Gene SYPL1: Pearson Correlation = 0.2686
# Gene CYB561: Pearson Correlation = 0.2790
# Gene SPAG9: Pearson Correlation = 0.2441
# Gene CELSR3: Pearson Correlation = 0.1725
# Gene AASS: Pearson Correlation = 0.2895
# Gene PLEKHG6: Pearson Correlation = 0.2780
# Gene SS18L2: Pearson Correlation = 0.2927
# Gene MPND: Pearson Correlation = 0.2541
# Gene MGST1: Pearson Correlation = 0.2580
# Gene CRY1: Pearson Correlation = 0.2604
# Gene PGLYRP1: Pearson Correlation = 0.2567
# Gene NFIX: Pearson Correlation = 0.2814
# Gene ST3GAL1: Pearson Correlation = 0.2524
# Gene MMP25: Pearson Correlation = 0.2534
# Gene IL32: Pearson Correlation = 0.2876
# Gene PKD1: Pearson Correlation = 0.2170
# Gene MED24: Pearson Correlation = 0.2820
# Gene RHOBTB2: Pearson Correlation = 0.2593
# Gene HEATR5B: Pearson Correlation = 0.2309
# Gene SEC62: Pearson Correlation = 0.2319
# Gene RPS20: Pearson Correlation = 0.2988
# Gene CSDE1: Pearson Correlation = 0.2724
# Gene UBE3C: Pearson Correlation = 0.2585
# Gene REV3L: Pearson Correlation = 0.2273
# Gene TENM1: Pearson Correlation = 0.2146
# Gene PAX7: Pearson Correlation = 0.2644
# Gene MASP2: Pearson Correlation = 0.1648
# Gene IYD: Pearson Correlation = 0.2406
# Gene FAM76A: Pearson Correlation = 0.2913
# Gene TRAF3IP3: Pearson Correlation = 0.2612
# Gene POMT2: Pearson Correlation = 0.2504
# Gene VTA1: Pearson Correlation = 0.2933
# Gene MLXIPL: Pearson Correlation = 0.2692
# Gene BAZ1B: Pearson Correlation = 0.2695
# Gene RANBP9: Pearson Correlation = 0.2779
# Gene ETV7: Pearson Correlation = 0.2373
# Gene SPRTN: Pearson Correlation = 0.2281
# Gene DYRK4: Pearson Correlation = 0.2351
# Gene ZNF207: Pearson Correlation = 0.2829
# Gene UQCRC1: Pearson Correlation = 0.2603
# Gene STARD3NL: Pearson Correlation = 0.2632
# Gene CD9: Pearson Correlation = 0.2414
# Gene HHATL: Pearson Correlation = 0.2498
# Gene NCAPD2: Pearson Correlation = 0.2572
# Gene IFFO1: Pearson Correlation = 0.2274
# Gene GIPR: Pearson Correlation = 0.2273
# Gene PHF7: Pearson Correlation = 0.2820
# Gene SEMA3G: Pearson Correlation = 0.2534
# Gene NISCH: Pearson Correlation = 0.2478
# Gene STAB1: Pearson Correlation = 0.1723
# Gene FUZ: Pearson Correlation = 0.3051
# Gene SLC6A13: Pearson Correlation = 0.1936
# Gene IDS: Pearson Correlation = 0.2858
# Gene PRSS3: Pearson Correlation = 0.1748
# Gene ZNF200: Pearson Correlation = 0.3010
# Gene CD4: Pearson Correlation = 0.2276
# Gene LRRC23: Pearson Correlation = 0.2320
# Gene BTK: Pearson Correlation = 0.2494
# Gene HFE: Pearson Correlation = 0.2521
# Gene SCMH1: Pearson Correlation = 0.2263
# Gene FYN: Pearson Correlation = 0.2478
# Gene HIVEP2: Pearson Correlation = 0.2074
# Gene FMO1: Pearson Correlation = 0.2250
# Gene ELOA: Pearson Correlation = 0.2006
# Gene LYPLA2: Pearson Correlation = 0.2759
# Gene CLCN6: Pearson Correlation = 0.2138
# Gene MRC2: Pearson Correlation = 0.1628
# Gene NME2: Pearson Correlation = 0.2591
# Gene SLC6A7: Pearson Correlation = 0.2131
# Gene TSPAN9: Pearson Correlation = 0.2696
# Gene BTBD7: Pearson Correlation = 0.2844
# Gene APBA3: Pearson Correlation = 0.2947
# Gene MKS1: Pearson Correlation = 0.2790
# Gene ABHD5: Pearson Correlation = 0.2248
# Gene ANOS1: Pearson Correlation = 0.1986
# Gene AKAP8L: Pearson Correlation = 0.2426
# Gene MBTD1: Pearson Correlation = 0.2860
# Gene UTP18: Pearson Correlation = 0.2064
# Gene RNF216: Pearson Correlation = 0.2688
# Gene TTC19: Pearson Correlation = 0.2906
# Gene PTBP1: Pearson Correlation = 0.2065
# Gene DPF1: Pearson Correlation = 0.2762
# Gene SYT7: Pearson Correlation = 0.2304
# Gene LARS2: Pearson Correlation = 0.2559
# Gene PIK3C2A: Pearson Correlation = 0.2594
# Gene PLAUR: Pearson Correlation = 0.1620
# Gene ANLN: Pearson Correlation = 0.2170
# Gene WIZ: Pearson Correlation = 0.2608
# Gene RABGAP1: Pearson Correlation = 0.2461
# Gene DCN: Pearson Correlation = 0.2027
# Gene QPCTL: Pearson Correlation = 0.2428
# Gene PPP5C: Pearson Correlation = 0.3081
# Gene CEP68: Pearson Correlation = 0.2296
# Gene MAP4K3: Pearson Correlation = 0.2110
# Gene ZBTB32: Pearson Correlation = 0.2743
# Gene TYROBP: Pearson Correlation = 0.2224
# Gene GABRA3: Pearson Correlation = 0.2659
# Gene BRCA1: Pearson Correlation = 0.2187
# Gene ERCC1: Pearson Correlation = 0.2666
# Gene CD22: Pearson Correlation = 0.1786
# Gene MBTPS2: Pearson Correlation = 0.1994
# Gene PRICKLE3: Pearson Correlation = 0.3114
# Gene LTF: Pearson Correlation = 0.2311
# Gene EXTL3: Pearson Correlation = 0.2451
# Gene NR1H4: Pearson Correlation = 0.2415
# Gene ELOVL5: Pearson Correlation = 0.2791
# Gene ALOX5: Pearson Correlation = 0.3054
# Gene KDM5D: Pearson Correlation = 0.2688
# Gene CALCOCO1: Pearson Correlation = 0.2121
# Gene UBR7: Pearson Correlation = 0.2731
# Gene EHD3: Pearson Correlation = 0.3052
# Gene PSMC4: Pearson Correlation = 0.2567
# Gene MAN2B2: Pearson Correlation = 0.2960
# Gene SLC7A14: Pearson Correlation = 0.2340
# Gene CLDN11: Pearson Correlation = 0.3109
# Gene SLC25A39: Pearson Correlation = 0.2644
# Gene MVP: Pearson Correlation = 0.2685
# Gene NUB1: Pearson Correlation = 0.2986
# Gene PGM3: Pearson Correlation = 0.2696
# Gene RWDD2A: Pearson Correlation = 0.2656
# Gene CLK1: Pearson Correlation = 0.2244
# Gene POLR3B: Pearson Correlation = 0.2733
# Gene ANGEL1: Pearson Correlation = 0.3351
# Gene RNF14: Pearson Correlation = 0.2512
# Gene DNASE1L1: Pearson Correlation = 0.2873
# Gene DDX11: Pearson Correlation = 0.1643
# Gene HEBP1: Pearson Correlation = 0.2450
# Gene GPRC5A: Pearson Correlation = 0.2848
# Gene MAMLD1: Pearson Correlation = 0.2913
# Gene CD6: Pearson Correlation = 0.1632
# Gene TACC3: Pearson Correlation = 0.2417
# Gene UFL1: Pearson Correlation = 0.2653
# Gene POLA2: Pearson Correlation = 0.2784
# Gene ZC3H3: Pearson Correlation = 0.2124
# Gene CAPN1: Pearson Correlation = 0.2314
# Gene ACP3: Pearson Correlation = 0.2559
# Gene MDH1: Pearson Correlation = 0.3228
# Gene SLC30A9: Pearson Correlation = 0.2406
# Gene MTMR11: Pearson Correlation = 0.2704
# Gene COX15: Pearson Correlation = 0.2569
# Gene CCDC88C: Pearson Correlation = 0.2326
# Gene YAF2: Pearson Correlation = 0.2422
# Gene ZMYND11: Pearson Correlation = 0.2898
# Gene WAS: Pearson Correlation = 0.2783
# Gene DPEP1: Pearson Correlation = 0.2053
# Gene BID: Pearson Correlation = 0.2879
# Gene MATR3: Pearson Correlation = 0.2250
# Gene NPC1L1: Pearson Correlation = 0.2311
# Gene XYLT2: Pearson Correlation = 0.2620
# Gene STMN4: Pearson Correlation = 0.2739
# Gene NUDCD3: Pearson Correlation = 0.2682
# Gene ISL1: Pearson Correlation = 0.2678
# Gene CHDH: Pearson Correlation = 0.2197
# Gene IL20RA: Pearson Correlation = 0.2041
# Gene CLCA1: Pearson Correlation = 0.2306
# Gene CLCA4: Pearson Correlation = 0.2431
# Gene GLT8D1: Pearson Correlation = 0.2397
# Gene ATP2C1: Pearson Correlation = 0.2276
# Gene IGF1: Pearson Correlation = 0.2556
# Gene SLC38A5: Pearson Correlation = 0.2472
# Gene RALBP1: Pearson Correlation = 0.2923
# Gene RUFY3: Pearson Correlation = 0.2727
# Gene CNTN1: Pearson Correlation = 0.1837
# Gene SLC11A1: Pearson Correlation = 0.2502
# Gene WWTR1: Pearson Correlation = 0.3181
# Gene AGPS: Pearson Correlation = 0.2456
# Gene ATP1A2: Pearson Correlation = 0.2293
# Gene TTC27: Pearson Correlation = 0.3036
# Gene ZNF582: Pearson Correlation = 0.3056
# Gene VSIG2: Pearson Correlation = 0.2359
# Gene PHLDB1: Pearson Correlation = 0.2586
# Gene MARCO: Pearson Correlation = 0.2445
# Gene CYP24A1: Pearson Correlation = 0.2139
# Gene PRDM11: Pearson Correlation = 0.2841
# Gene SYT13: Pearson Correlation = 0.2520
# Gene SNAI2: Pearson Correlation = 0.2804
# Gene CD74: Pearson Correlation = 0.2957
# Gene HGF: Pearson Correlation = 0.1746
# Gene ZRANB1: Pearson Correlation = 0.2615
# Gene NCDN: Pearson Correlation = 0.2486
# Gene ADGRA2: Pearson Correlation = 0.2332
# Gene ZFP64: Pearson Correlation = 0.2434
# Gene MNAT1: Pearson Correlation = 0.2552
# Gene SAMD4A: Pearson Correlation = 0.2942
# Gene RUNX3: Pearson Correlation = 0.3065
# Gene MRE11: Pearson Correlation = 0.2451
# Gene PLEKHB1: Pearson Correlation = 0.3004
# Gene SERPINB1: Pearson Correlation = 0.2789
# Gene CYP3A43: Pearson Correlation = 0.2145
# Gene SLC7A9: Pearson Correlation = 0.2452
# Gene SPAST: Pearson Correlation = 0.2999
# Gene NRXN3: Pearson Correlation = 0.2506
# Gene OSBPL5: Pearson Correlation = 0.3005
# Gene AQR: Pearson Correlation = 0.2492
# Gene CPS1: Pearson Correlation = 0.2508
# Gene C8B: Pearson Correlation = 0.1866
# Gene FHL1: Pearson Correlation = 0.3059
# Gene RTF2: Pearson Correlation = 0.2475
# Gene GABRA1: Pearson Correlation = 0.2646
# Gene NLRP2: Pearson Correlation = 0.2321
# Gene SLC45A4: Pearson Correlation = 0.2336
# Gene RNF10: Pearson Correlation = 0.2762
# Gene ZNF839: Pearson Correlation = 0.2661
# Gene ZDHHC6: Pearson Correlation = 0.2406
# Gene GRAMD1B: Pearson Correlation = 0.2988
# Gene RNH1: Pearson Correlation = 0.2178
# Gene NDUFS1: Pearson Correlation = 0.2535
# Gene RB1CC1: Pearson Correlation = 0.2706
# Gene ERP44: Pearson Correlation = 0.2655
# Gene ALAS1: Pearson Correlation = 0.2990
# Gene BIRC3: Pearson Correlation = 0.2592
# Gene AKAP11: Pearson Correlation = 0.2505
# Gene GLRX2: Pearson Correlation = 0.2766
# Gene SNAPC1: Pearson Correlation = 0.2824
# Gene DERA: Pearson Correlation = 0.2411
# Gene STRAP: Pearson Correlation = 0.1861
# Gene ABCC2: Pearson Correlation = 0.2227
# Gene DEF6: Pearson Correlation = 0.2693
# Gene PLEKHO1: Pearson Correlation = 0.2822
# Gene GCLM: Pearson Correlation = 0.2579
# Gene UBR2: Pearson Correlation = 0.2684
# Gene EHD2: Pearson Correlation = 0.2868
# Gene DEPDC1: Pearson Correlation = 0.2725
# Gene CCDC28A: Pearson Correlation = 0.2854
# Gene RRAGD: Pearson Correlation = 0.3108
# Gene HSF2: Pearson Correlation = 0.2642
# Gene PHF20: Pearson Correlation = 0.2381
# Gene HSD17B6: Pearson Correlation = 0.2752
# Gene NR1H3: Pearson Correlation = 0.2546
# Gene TYMP: Pearson Correlation = 0.2270
# Gene NCAPH2: Pearson Correlation = 0.2558
# Gene TOMM34: Pearson Correlation = 0.2909
# Gene SEC63: Pearson Correlation = 0.2473
# Gene KPNA6: Pearson Correlation = 0.2535
# Gene VIM: Pearson Correlation = 0.2596
# Gene FAS: Pearson Correlation = 0.2476
# Gene RNASET2: Pearson Correlation = 0.2750
# Gene CD44: Pearson Correlation = 0.2038
# Gene KCNG1: Pearson Correlation = 0.2361
# Gene AGPAT4: Pearson Correlation = 0.2675
# Gene SLAMF7: Pearson Correlation = 0.1980
# Gene BTN3A1: Pearson Correlation = 0.2320
# Gene MIPEP: Pearson Correlation = 0.2070
# Gene PRKCH: Pearson Correlation = 0.2230
# Gene INSRR: Pearson Correlation = 0.2252
# Gene IFNGR1: Pearson Correlation = 0.2222
# Gene B4GALT7: Pearson Correlation = 0.2768
# Gene SH2D2A: Pearson Correlation = 0.2741
# Gene VRK2: Pearson Correlation = 0.2367
# Gene TNFRSF1B: Pearson Correlation = 0.2013
# Gene VEZT: Pearson Correlation = 0.2378
# Gene POU2F2: Pearson Correlation = 0.2587
# Gene BRD9: Pearson Correlation = 0.2484
# Gene SNX1: Pearson Correlation = 0.2541
# Gene TBPL1: Pearson Correlation = 0.2473
# Gene BCLAF1: Pearson Correlation = 0.1875
# Gene SLC39A9: Pearson Correlation = 0.2443
# Gene ANK1: Pearson Correlation = 0.2746
# Gene IBSP: Pearson Correlation = 0.2319
# Gene TFB1M: Pearson Correlation = 0.2135
# Gene RABEP1: Pearson Correlation = 0.2200
# Gene HMGB3: Pearson Correlation = 0.2647
# Gene NUP160: Pearson Correlation = 0.2786
# Gene BAK1: Pearson Correlation = 0.2747
# Gene MUSK: Pearson Correlation = 0.1998
# Gene IKZF2: Pearson Correlation = 0.2611
# Gene GRN: Pearson Correlation = 0.1408
# Gene FAM13B: Pearson Correlation = 0.2623
# Gene ARHGAP31: Pearson Correlation = 0.2601
# Gene CENPQ: Pearson Correlation = 0.2671
# Gene SARS1: Pearson Correlation = 0.2829
# Gene RANBP3: Pearson Correlation = 0.2792
# Gene ARID4A: Pearson Correlation = 0.2517
# Gene EIPR1: Pearson Correlation = 0.2419
# Gene PNPLA6: Pearson Correlation = 0.2997
# Gene IFT88: Pearson Correlation = 0.2730
# Gene ALG1: Pearson Correlation = 0.2909
# Gene CHPF2: Pearson Correlation = 0.2597
# Gene FUT8: Pearson Correlation = 0.2764
# Gene UBA6: Pearson Correlation = 0.2551
# Gene GAB2: Pearson Correlation = 0.2713
# Gene ATP6V0A1: Pearson Correlation = 0.2425
# Gene PIAS1: Pearson Correlation = 0.2840
# Gene SLC4A7: Pearson Correlation = 0.2665
# Gene APBA2: Pearson Correlation = 0.2602
# Gene MAP2K3: Pearson Correlation = 0.2406
# Gene TMSB10: Pearson Correlation = 0.3036
# Gene ASTE1: Pearson Correlation = 0.2564
# Gene RNF19A: Pearson Correlation = 0.2375
# Gene PEX3: Pearson Correlation = 0.2608
# Gene GABARAPL2: Pearson Correlation = 0.2920
# Gene MYOC: Pearson Correlation = 0.2733
# Gene SH3YL1: Pearson Correlation = 0.2390
# Gene FAM136A: Pearson Correlation = 0.2821
# Gene VCL: Pearson Correlation = 0.2472
# Gene DEPDC1B: Pearson Correlation = 0.2936
# Gene DAPK2: Pearson Correlation = 0.2277
# Gene NSMAF: Pearson Correlation = 0.2829
# Gene ADSS2: Pearson Correlation = 0.2526
# Gene STAP1: Pearson Correlation = 0.2874
# Gene TIMP2: Pearson Correlation = 0.2281
# Gene RFC1: Pearson Correlation = 0.2076
# Gene TBC1D23: Pearson Correlation = 0.2874
# Gene CUL3: Pearson Correlation = 0.2788
# Gene MYOM2: Pearson Correlation = 0.1856
# Gene OTC: Pearson Correlation = 0.2970
# Gene CYP46A1: Pearson Correlation = 0.2363
# Gene ZZZ3: Pearson Correlation = 0.2594
# Gene SLC18A1: Pearson Correlation = 0.2275
# Gene USP2: Pearson Correlation = 0.3225
# Gene CASR: Pearson Correlation = 0.2534
# Gene TUBG2: Pearson Correlation = 0.2768
# Gene RPL26L1: Pearson Correlation = 0.2795
# Gene FLT4: Pearson Correlation = 0.2257
# Gene NSUN2: Pearson Correlation = 0.2788
# Gene FBXO42: Pearson Correlation = 0.2591
# Gene MFAP3: Pearson Correlation = 0.2489
# Gene MRI1: Pearson Correlation = 0.2500
# Gene METTL1: Pearson Correlation = 0.2524
# Gene HOXC8: Pearson Correlation = 0.2559
# Gene AGA: Pearson Correlation = 0.2408
# Gene PI4K2B: Pearson Correlation = 0.2850
# Gene BOD1L1: Pearson Correlation = 0.1872
# Gene MAT2B: Pearson Correlation = 0.3115
# Gene TLL1: Pearson Correlation = 0.1827
# Gene EDC4: Pearson Correlation = 0.2659
# Gene TRIO: Pearson Correlation = 0.2600
# Gene VCAN: Pearson Correlation = 0.1868
# Gene CLEC16A: Pearson Correlation = 0.2815
# Gene MSR1: Pearson Correlation = 0.2407
# Gene CDH1: Pearson Correlation = 0.1516
# Gene MTREX: Pearson Correlation = 0.1983
# Gene DNAH5: Pearson Correlation = 0.2607
# Gene ZFYVE16: Pearson Correlation = 0.2510
# Gene RIPOR1: Pearson Correlation = 0.2575
# Gene C6: Pearson Correlation = 0.1639
# Gene RAI14: Pearson Correlation = 0.2786
# Gene SOX30: Pearson Correlation = 0.2906
# Gene PNKP: Pearson Correlation = 0.2921
# Gene BEST2: Pearson Correlation = 0.2404
# Gene PHLPP2: Pearson Correlation = 0.2221
# Gene SPDL1: Pearson Correlation = 0.2587
# Gene STAU2: Pearson Correlation = 0.2900
# Gene SLC66A1: Pearson Correlation = 0.2099
# Gene CTNS: Pearson Correlation = 0.2660
# Gene RTN4R: Pearson Correlation = 0.2406
# Gene PHF23: Pearson Correlation = 0.2844
# Gene CDH10: Pearson Correlation = 0.2012
# Gene INPP4A: Pearson Correlation = 0.2736
# Gene RAB27B: Pearson Correlation = 0.2607
# Gene PSMA4: Pearson Correlation = 0.2886
# Gene MYO16: Pearson Correlation = 0.2684
# Gene LSG1: Pearson Correlation = 0.2735
# Gene PARP3: Pearson Correlation = 0.3121
# Gene TNC: Pearson Correlation = 0.1680
# Gene THAP3: Pearson Correlation = 0.2993
# Gene RIPOR3: Pearson Correlation = 0.2847
# Gene TDP1: Pearson Correlation = 0.2727
# Gene AIFM2: Pearson Correlation = 0.2744
# Gene SPATA7: Pearson Correlation = 0.2852
# Gene MED17: Pearson Correlation = 0.3038
# Gene RETSAT: Pearson Correlation = 0.2954
# Gene CAPG: Pearson Correlation = 0.3008
# Gene AP2S1: Pearson Correlation = 0.2811
# Gene USH2A: Pearson Correlation = 0.1834
# Gene ZPBP: Pearson Correlation = 0.2800
# Gene TG: Pearson Correlation = 0.2232
# Gene ADAM28: Pearson Correlation = 0.2353
# Gene BARX2: Pearson Correlation = 0.2868
# Gene DCUN1D1: Pearson Correlation = 0.3066
# Gene JADE2: Pearson Correlation = 0.2872
# Gene ZIC2: Pearson Correlation = 0.3055
# Gene LCP2: Pearson Correlation = 0.2404
# Gene TRIT1: Pearson Correlation = 0.2688
# Gene ADRB1: Pearson Correlation = 0.2421
# Gene GUCA2B: Pearson Correlation = 0.2433
# Gene CUL7: Pearson Correlation = 0.2444
# Gene CTNNA1: Pearson Correlation = 0.2417
# Gene PHKA2: Pearson Correlation = 0.2340
# Gene CNTLN: Pearson Correlation = 0.2243
# Gene EPHA3: Pearson Correlation = 0.2025
# Gene HSPA5: Pearson Correlation = 0.2920
# Gene DSG2: Pearson Correlation = 0.1968
# Gene GEMIN8: Pearson Correlation = 0.2825
# Gene OFD1: Pearson Correlation = 0.2555
# Gene GPM6B: Pearson Correlation = 0.2469
# Gene MAGEC2: Pearson Correlation = 0.3143
# Gene PREX2: Pearson Correlation = 0.2598
# Gene WDR37: Pearson Correlation = 0.2042
# Gene YTHDC2: Pearson Correlation = 0.2116
# Gene CTPS2: Pearson Correlation = 0.2880
# Gene ATP6V1H: Pearson Correlation = 0.2467
# Gene POLR2B: Pearson Correlation = 0.2768
# Gene ARAP2: Pearson Correlation = 0.2419
# Gene TPR: Pearson Correlation = 0.2303
# Gene CP: Pearson Correlation = 0.2265
# Gene KATNIP: Pearson Correlation = 0.2745
# Gene DTNBP1: Pearson Correlation = 0.2693
# Gene XK: Pearson Correlation = 0.2608
# Gene ANO2: Pearson Correlation = 0.2739
# Gene C12orf4: Pearson Correlation = 0.2921
# Gene SCML1: Pearson Correlation = 0.3013
# Gene ARHGAP6: Pearson Correlation = 0.2662
# Gene FAM184B: Pearson Correlation = 0.2562
# Gene MAP4: Pearson Correlation = 0.2144
# Epoch 14 completed
# Model 14 loaded successfully for epoch 15
# Gene ZFX: Pearson Correlation = 0.2674
# Gene LAMP2: Pearson Correlation = 0.2564
# Gene ITGA2B: Pearson Correlation = 0.2337
# Gene ASB4: Pearson Correlation = 0.2340
# Gene GDE1: Pearson Correlation = 0.2077
# Gene REX1BD: Pearson Correlation = 0.3043
# Gene CRLF1: Pearson Correlation = 0.2154
# Gene OSBPL7: Pearson Correlation = 0.2777
# Gene TMEM98: Pearson Correlation = 0.2328
# Gene YBX2: Pearson Correlation = 0.2761
# Gene KRT33A: Pearson Correlation = 0.2249
# Gene ABCC8: Pearson Correlation = 0.2365
# Gene CACNG3: Pearson Correlation = 0.2773
# Gene TMEM132A: Pearson Correlation = 0.2676
# Gene AP2B1: Pearson Correlation = 0.2312
# Gene TAC1: Pearson Correlation = 0.2518
# Gene ZNF263: Pearson Correlation = 0.2995
# Gene CX3CL1: Pearson Correlation = 0.2079
# Gene SPATA20: Pearson Correlation = 0.3204
# Gene CACNA1G: Pearson Correlation = 0.2369
# Gene TNFRSF12A: Pearson Correlation = 0.1920
# Gene DLX6: Pearson Correlation = 0.2434
# Gene MAP3K9: Pearson Correlation = 0.2010
# Gene RALA: Pearson Correlation = 0.2886
# Gene BAIAP2L1: Pearson Correlation = 0.2816
# Gene KDM7A: Pearson Correlation = 0.2651
# Gene ETV1: Pearson Correlation = 0.2376
# Gene AGK: Pearson Correlation = 0.2567
# Gene TTC22: Pearson Correlation = 0.2874
# Gene PHTF2: Pearson Correlation = 0.2567
# Gene CCL26: Pearson Correlation = 0.2495
# Gene FARP2: Pearson Correlation = 0.2551
# Gene USH1C: Pearson Correlation = 0.2369
# Gene GGCT: Pearson Correlation = 0.2464
# Gene DBF4: Pearson Correlation = 0.2620
# Gene TBXA2R: Pearson Correlation = 0.2517
# Gene IFRD1: Pearson Correlation = 0.2616
# Gene LGALS14: Pearson Correlation = 0.2556
# Gene COX10: Pearson Correlation = 0.2189
# Gene GTF2IRD1: Pearson Correlation = 0.2991
# Gene PAF1: Pearson Correlation = 0.2511
# Gene VPS41: Pearson Correlation = 0.2361
# Gene ARHGAP44: Pearson Correlation = 0.2462
# Gene ELAC2: Pearson Correlation = 0.2605
# Gene SCIN: Pearson Correlation = 0.2719
# Gene ARSD: Pearson Correlation = 0.2671
# Gene PNPLA4: Pearson Correlation = 0.2349
# Gene MYH13: Pearson Correlation = 0.2227
# Gene ADIPOR2: Pearson Correlation = 0.2760
# Gene CDKL3: Pearson Correlation = 0.2207
# Gene UPP2: Pearson Correlation = 0.2522
# Gene PRSS21: Pearson Correlation = 0.2084
# Gene MARK4: Pearson Correlation = 0.2473
# Gene PROM1: Pearson Correlation = 0.2524
# Gene CCDC124: Pearson Correlation = 0.2578
# Gene CEACAM21: Pearson Correlation = 0.2087
# Gene PAFAH1B1: Pearson Correlation = 0.2280
# Gene NOS2: Pearson Correlation = 0.2654
# Gene DNAH9: Pearson Correlation = 0.2431
# Gene SLC13A2: Pearson Correlation = 0.2102
# Gene GAS7: Pearson Correlation = 0.2911
# Gene TRAPPC6A: Pearson Correlation = 0.2860
# Gene MATK: Pearson Correlation = 0.2326
# Gene CEACAM7: Pearson Correlation = 0.2104
# Gene CD79B: Pearson Correlation = 0.2620
# Gene SCN4A: Pearson Correlation = 0.2548
# Gene ST7L: Pearson Correlation = 0.2954
# Gene TKTL1: Pearson Correlation = 0.2739
# Gene PAX6: Pearson Correlation = 0.2279
# Gene RPUSD1: Pearson Correlation = 0.2686
# Gene RHBDF1: Pearson Correlation = 0.2696
# Gene LUC7L: Pearson Correlation = 0.2190
# Gene CACNA2D2: Pearson Correlation = 0.2501
# Gene BAIAP3: Pearson Correlation = 0.2824
# Gene TSR3: Pearson Correlation = 0.2625
# Gene PIGQ: Pearson Correlation = 0.2792
# Gene CRAMP1: Pearson Correlation = 0.2381
# Gene TEAD3: Pearson Correlation = 0.2896
# Gene SELE: Pearson Correlation = 0.1527
# Gene DNAJC11: Pearson Correlation = 0.2664
# Gene FMO3: Pearson Correlation = 0.2283
# Gene MYLIP: Pearson Correlation = 0.2795
# Gene NOX1: Pearson Correlation = 0.2600
# Gene E2F2: Pearson Correlation = 0.2766
# Gene PSMB1: Pearson Correlation = 0.2427
# Gene SYN1: Pearson Correlation = 0.2639
# Gene JARID2: Pearson Correlation = 0.2513
# Gene CDKL5: Pearson Correlation = 0.2269
# Gene CAMK1G: Pearson Correlation = 0.2244
# Gene NADK: Pearson Correlation = 0.2831
# Gene TFAP2B: Pearson Correlation = 0.2694
# Gene TFAP2D: Pearson Correlation = 0.2835
# Gene DLEC1: Pearson Correlation = 0.2541
# Gene CYTH3: Pearson Correlation = 0.2698
# Gene ADAM22: Pearson Correlation = 0.1795
# Gene SYPL1: Pearson Correlation = 0.2688
# Gene CYB561: Pearson Correlation = 0.2801
# Gene SPAG9: Pearson Correlation = 0.2432
# Gene CELSR3: Pearson Correlation = 0.1731
# Gene AASS: Pearson Correlation = 0.2833
# Gene PLEKHG6: Pearson Correlation = 0.2755
# Gene SS18L2: Pearson Correlation = 0.2877
# Gene MPND: Pearson Correlation = 0.2496
# Gene MGST1: Pearson Correlation = 0.2637
# Gene CRY1: Pearson Correlation = 0.2618
# Gene PGLYRP1: Pearson Correlation = 0.2550
# Gene NFIX: Pearson Correlation = 0.2846
# Gene ST3GAL1: Pearson Correlation = 0.2520
# Gene MMP25: Pearson Correlation = 0.2560
# Gene IL32: Pearson Correlation = 0.2841
# Gene PKD1: Pearson Correlation = 0.2145
# Gene MED24: Pearson Correlation = 0.2792
# Gene RHOBTB2: Pearson Correlation = 0.2572
# Gene HEATR5B: Pearson Correlation = 0.2249
# Gene SEC62: Pearson Correlation = 0.2327
# Gene RPS20: Pearson Correlation = 0.2919
# Gene CSDE1: Pearson Correlation = 0.2709
# Gene UBE3C: Pearson Correlation = 0.2523
# Gene REV3L: Pearson Correlation = 0.2335
# Gene TENM1: Pearson Correlation = 0.2173
# Gene PAX7: Pearson Correlation = 0.2624
# Gene MASP2: Pearson Correlation = 0.1643
# Gene IYD: Pearson Correlation = 0.2354
# Gene FAM76A: Pearson Correlation = 0.2926
# Gene TRAF3IP3: Pearson Correlation = 0.2666
# Gene POMT2: Pearson Correlation = 0.2545
# Gene VTA1: Pearson Correlation = 0.2926
# Gene MLXIPL: Pearson Correlation = 0.2729
# Gene BAZ1B: Pearson Correlation = 0.2699
# Gene RANBP9: Pearson Correlation = 0.2793
# Gene ETV7: Pearson Correlation = 0.2340
# Gene SPRTN: Pearson Correlation = 0.2255
# Gene DYRK4: Pearson Correlation = 0.2331
# Gene ZNF207: Pearson Correlation = 0.2802
# Gene UQCRC1: Pearson Correlation = 0.2563
# Gene STARD3NL: Pearson Correlation = 0.2668
# Gene CD9: Pearson Correlation = 0.2448
# Gene HHATL: Pearson Correlation = 0.2501
# Gene NCAPD2: Pearson Correlation = 0.2559
# Gene IFFO1: Pearson Correlation = 0.2317
# Gene GIPR: Pearson Correlation = 0.2354
# Gene PHF7: Pearson Correlation = 0.2831
# Gene SEMA3G: Pearson Correlation = 0.2526
# Gene NISCH: Pearson Correlation = 0.2432
# Gene STAB1: Pearson Correlation = 0.1752
# Gene FUZ: Pearson Correlation = 0.3013
# Gene SLC6A13: Pearson Correlation = 0.1988
# Gene IDS: Pearson Correlation = 0.2871
# Gene PRSS3: Pearson Correlation = 0.1791
# Gene ZNF200: Pearson Correlation = 0.2988
# Gene CD4: Pearson Correlation = 0.2306
# Gene LRRC23: Pearson Correlation = 0.2368
# Gene BTK: Pearson Correlation = 0.2499
# Gene HFE: Pearson Correlation = 0.2596
# ...
# Gene EHD2: Pearson Correlation = 0.2915
# Gene DEPDC1: Pearson Correlation = 0.2688
# Gene CCDC28A: Pearson Correlation = 0.2788
# Gene RRAGD: Pearson Correlation = 0.3051
# Gene HSF2: Pearson Correlation = 0.2647
# Gene PHF20: Pearson Correlation = 0.2460
# Gene HSD17B6: Pearson Correlation = 0.2754
# Gene NR1H3: Pearson Correlation = 0.2587
# Gene TYMP: Pearson Correlation = 0.2329
# Gene NCAPH2: Pearson Correlation = 0.2652
# Gene TOMM34: Pearson Correlation = 0.2916
# Gene SEC63: Pearson Correlation = 0.2616
# Gene KPNA6: Pearson Correlation = 0.2689
# Gene VIM: Pearson Correlation = 0.2577
# Gene FAS: Pearson Correlation = 0.2544
# Gene RNASET2: Pearson Correlation = 0.2806
# Gene CD44: Pearson Correlation = 0.2106
# Gene KCNG1: Pearson Correlation = 0.2475
# Gene AGPAT4: Pearson Correlation = 0.2738
# Gene SLAMF7: Pearson Correlation = 0.2089
# Gene BTN3A1: Pearson Correlation = 0.2418
# Gene MIPEP: Pearson Correlation = 0.2216
# Gene PRKCH: Pearson Correlation = 0.2288
# Gene INSRR: Pearson Correlation = 0.2384
# Gene IFNGR1: Pearson Correlation = 0.2318
# Gene B4GALT7: Pearson Correlation = 0.2808
# Gene SH2D2A: Pearson Correlation = 0.2747
# Gene VRK2: Pearson Correlation = 0.2402
# Gene TNFRSF1B: Pearson Correlation = 0.2096
# Gene VEZT: Pearson Correlation = 0.2509
# Gene POU2F2: Pearson Correlation = 0.2700
# Gene BRD9: Pearson Correlation = 0.2594
# Gene SNX1: Pearson Correlation = 0.2626
# Gene TBPL1: Pearson Correlation = 0.2510
# Gene BCLAF1: Pearson Correlation = 0.2074
# Gene SLC39A9: Pearson Correlation = 0.2508
# Gene ANK1: Pearson Correlation = 0.2795
# Gene IBSP: Pearson Correlation = 0.2434
# Gene TFB1M: Pearson Correlation = 0.2331
# Gene RABEP1: Pearson Correlation = 0.2276
# Gene HMGB3: Pearson Correlation = 0.2672
# Gene NUP160: Pearson Correlation = 0.2780
# Gene BAK1: Pearson Correlation = 0.2704
# Gene MUSK: Pearson Correlation = 0.2030
# Gene IKZF2: Pearson Correlation = 0.2563
# Gene GRN: Pearson Correlation = 0.1367
# Gene FAM13B: Pearson Correlation = 0.2613
# Gene ARHGAP31: Pearson Correlation = 0.2617
# Gene CENPQ: Pearson Correlation = 0.2654
# Gene SARS1: Pearson Correlation = 0.2788
# Gene RANBP3: Pearson Correlation = 0.2714
# Gene ARID4A: Pearson Correlation = 0.2479
# Gene EIPR1: Pearson Correlation = 0.2322
# Gene PNPLA6: Pearson Correlation = 0.2914
# Gene IFT88: Pearson Correlation = 0.2686
# Gene ALG1: Pearson Correlation = 0.2843
# Gene CHPF2: Pearson Correlation = 0.2672
# Gene FUT8: Pearson Correlation = 0.2747
# Gene UBA6: Pearson Correlation = 0.2479
# Gene GAB2: Pearson Correlation = 0.2699
# Gene ATP6V0A1: Pearson Correlation = 0.2462
# Gene PIAS1: Pearson Correlation = 0.2773
# Gene SLC4A7: Pearson Correlation = 0.2691
# Gene APBA2: Pearson Correlation = 0.2551
# Gene MAP2K3: Pearson Correlation = 0.2397
# Gene TMSB10: Pearson Correlation = 0.2998
# Gene ASTE1: Pearson Correlation = 0.2623
# Gene RNF19A: Pearson Correlation = 0.2400
# Gene PEX3: Pearson Correlation = 0.2609
# Gene GABARAPL2: Pearson Correlation = 0.2859
# Gene MYOC: Pearson Correlation = 0.2720
# Gene SH3YL1: Pearson Correlation = 0.2376
# Gene FAM136A: Pearson Correlation = 0.2786
# Gene VCL: Pearson Correlation = 0.2448
# Gene DEPDC1B: Pearson Correlation = 0.2849
# Gene DAPK2: Pearson Correlation = 0.2313
# Gene NSMAF: Pearson Correlation = 0.2724
# Gene ADSS2: Pearson Correlation = 0.2507
# Gene STAP1: Pearson Correlation = 0.2805
# Gene TIMP2: Pearson Correlation = 0.2204
# Gene RFC1: Pearson Correlation = 0.2213
# Gene TBC1D23: Pearson Correlation = 0.2832
# Gene CUL3: Pearson Correlation = 0.2797
# Gene MYOM2: Pearson Correlation = 0.2058
# Gene OTC: Pearson Correlation = 0.2946
# Gene CYP46A1: Pearson Correlation = 0.2405
# Gene ZZZ3: Pearson Correlation = 0.2577
# Gene SLC18A1: Pearson Correlation = 0.2390
# Gene USP2: Pearson Correlation = 0.3242
# Gene CASR: Pearson Correlation = 0.2620
# Gene TUBG2: Pearson Correlation = 0.2813
# Gene RPL26L1: Pearson Correlation = 0.2767
# Gene FLT4: Pearson Correlation = 0.2307
# Gene NSUN2: Pearson Correlation = 0.2791
# Gene FBXO42: Pearson Correlation = 0.2615
# Gene MFAP3: Pearson Correlation = 0.2517
# Gene MRI1: Pearson Correlation = 0.2618
# Gene METTL1: Pearson Correlation = 0.2635
# Gene HOXC8: Pearson Correlation = 0.2592
# Gene AGA: Pearson Correlation = 0.2515
# Gene PI4K2B: Pearson Correlation = 0.2889
# Gene BOD1L1: Pearson Correlation = 0.2015
# Gene MAT2B: Pearson Correlation = 0.3131
# Gene TLL1: Pearson Correlation = 0.1806
# Gene EDC4: Pearson Correlation = 0.2678
# Gene TRIO: Pearson Correlation = 0.2649
# Gene VCAN: Pearson Correlation = 0.1916
# Gene CLEC16A: Pearson Correlation = 0.2889
# Gene MSR1: Pearson Correlation = 0.2517
# Gene CDH1: Pearson Correlation = 0.1652
# Gene MTREX: Pearson Correlation = 0.2124
# Gene DNAH5: Pearson Correlation = 0.2719
# Gene ZFYVE16: Pearson Correlation = 0.2586
# Gene RIPOR1: Pearson Correlation = 0.2600
# Gene C6: Pearson Correlation = 0.1753
# Gene RAI14: Pearson Correlation = 0.2853
# Gene SOX30: Pearson Correlation = 0.2931
# Gene PNKP: Pearson Correlation = 0.2929
# Gene BEST2: Pearson Correlation = 0.2493
# Gene PHLPP2: Pearson Correlation = 0.2280
# Gene SPDL1: Pearson Correlation = 0.2503
# Gene STAU2: Pearson Correlation = 0.2876
# Gene SLC66A1: Pearson Correlation = 0.2306
# Gene CTNS: Pearson Correlation = 0.2717
# Gene RTN4R: Pearson Correlation = 0.2369
# Gene PHF23: Pearson Correlation = 0.2771
# Gene CDH10: Pearson Correlation = 0.2056
# Gene INPP4A: Pearson Correlation = 0.2805
# Gene RAB27B: Pearson Correlation = 0.2651
# Gene PSMA4: Pearson Correlation = 0.2875
# Gene MYO16: Pearson Correlation = 0.2737
# Gene LSG1: Pearson Correlation = 0.2697
# Gene PARP3: Pearson Correlation = 0.2991
# Gene TNC: Pearson Correlation = 0.1743
# Gene THAP3: Pearson Correlation = 0.2874
# Gene RIPOR3: Pearson Correlation = 0.2783
# Gene TDP1: Pearson Correlation = 0.2635
# Gene AIFM2: Pearson Correlation = 0.2693
# Gene SPATA7: Pearson Correlation = 0.2715
# Gene MED17: Pearson Correlation = 0.2936
# Gene RETSAT: Pearson Correlation = 0.2944
# Gene CAPG: Pearson Correlation = 0.2895
# Gene AP2S1: Pearson Correlation = 0.2685
# Gene USH2A: Pearson Correlation = 0.1854
# Gene ZPBP: Pearson Correlation = 0.2720
# Gene TG: Pearson Correlation = 0.2232
# Gene ADAM28: Pearson Correlation = 0.2235
# Gene BARX2: Pearson Correlation = 0.2822
# Gene DCUN1D1: Pearson Correlation = 0.2932
# Gene JADE2: Pearson Correlation = 0.2767
# Gene ZIC2: Pearson Correlation = 0.3005
# Gene LCP2: Pearson Correlation = 0.2415
# Gene TRIT1: Pearson Correlation = 0.2833
# Gene ADRB1: Pearson Correlation = 0.2455
# Gene GUCA2B: Pearson Correlation = 0.2475
# Gene CUL7: Pearson Correlation = 0.2594
# Gene CTNNA1: Pearson Correlation = 0.2458
# Gene PHKA2: Pearson Correlation = 0.2372
# Gene CNTLN: Pearson Correlation = 0.2221
# Gene EPHA3: Pearson Correlation = 0.2005
# Gene HSPA5: Pearson Correlation = 0.2830
# Gene DSG2: Pearson Correlation = 0.1983
# Gene GEMIN8: Pearson Correlation = 0.2756
# Gene OFD1: Pearson Correlation = 0.2517
# Gene GPM6B: Pearson Correlation = 0.2474
# Gene MAGEC2: Pearson Correlation = 0.3076
# Gene PREX2: Pearson Correlation = 0.2636
# Gene WDR37: Pearson Correlation = 0.2058
# Gene YTHDC2: Pearson Correlation = 0.2133
# Gene CTPS2: Pearson Correlation = 0.2934
# Gene ATP6V1H: Pearson Correlation = 0.2499
# Gene POLR2B: Pearson Correlation = 0.2794
# Gene ARAP2: Pearson Correlation = 0.2444
# Gene TPR: Pearson Correlation = 0.2261
# Gene CP: Pearson Correlation = 0.2256
# Gene KATNIP: Pearson Correlation = 0.2733
# Gene DTNBP1: Pearson Correlation = 0.2684
# Gene XK: Pearson Correlation = 0.2640
# Gene ANO2: Pearson Correlation = 0.2741
# Gene C12orf4: Pearson Correlation = 0.2914
# Gene SCML1: Pearson Correlation = 0.2889
# Gene ARHGAP6: Pearson Correlation = 0.2590
# Gene FAM184B: Pearson Correlation = 0.2540
# Gene MAP4: Pearson Correlation = 0.2139
# Epoch 20 completed
# Model 20 loaded successfully for epoch 21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 223
#     219             f.write(f'{epoch},{np.mean(epoch_train_losses):.4f},{np.mean(epoch_train_correlations):.4f},{np.mean(epoch_test_losses):.4f},{np.mean(epoch_test_correlations):.4f}\n')
#     220         print(f'Epoch {epoch} completed')
# --> 223 main_training_loop(unirep_path="/mnt/data/macaulay/datas/processed_gene_embeddings.csv",
#     224                    vae_path="/mnt/data/macaulay/datas/OmicExpression_embeddings/OmicExpression_embeddings_15.csv",
#     225                    essentiality_path='/mnt/data/macaulay/datas/processed_CRISPRGeneEffect.csv',
#     226                    batch_size1=1,learning_rate=0.001,num_epochs=12,
#     227                    model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)
#     229 # model_save_path='/home/macaulay/macaulay/GenePedia/datas/',test_batch_size=128)"
#
# Cell In[1], line 138, in main_training_loop(unirep_path, vae_path, essentiality_path, batch_size1, learning_rate, num_epochs, model_save_path, test_batch_size)
#     135 if j == 0:
#     136     model = load_model(model, epoch, model_save_path)
# --> 138 for batch_X, batch_Y in cartesian_product_generator(batched_data1, df_omic_train, flattened_essentiality_train, batch_size1):
#     140     combined = pd.concat([batch_X.reset_index(drop=True), batch_Y.reset_index(drop=True)], axis=1)
#     142     combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)
#
# Cell In[1], line 51, in cartesian_product_generator(unirep_train, data2, df_Y, batch_size1)
#      48 end_idx = (i + batch_size1) * len(data2)
#      49 batch_data1 = unirep_train.iloc[i:i + batch_size1]
# ---> 51 batch_X = cartesian_product(batch_data1, data2)
#      52 batch_Y = df_Y.iloc[start_idx:end_idx]
#      53 yield batch_X, batch_Y
#
# Cell In[1], line 41, in cartesian_product(unirep_train, data2)
#      39 unirep_train['key'] = 1
#      40 data2['key'] = 1
# ---> 41 combined_data = pd.merge(unirep_train, data2, on='key').drop(columns=['key'])
#      42 return combined_data
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py:737, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     730 self._cross = cross_col
#     732 # note this function has side effects
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
# --> 737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
#     741 self._maybe_coerce_merge_keys()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1274, in _MergeOperation._get_merge_keys(self)
#    1271     self.left = self.left._drop_labels_or_levels(left_drop)
#    1273 if right_drop:
# -> 1274     self.right = self.right._drop_labels_or_levels(right_drop)
#    1276 return left_keys, right_keys, join_names
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:1856, in NDFrame._drop_labels_or_levels(self, keys, axis)
#    1854     # Handle dropping columns labels
#    1855     if labels_to_drop:
# -> 1856         dropped.drop(labels_to_drop, axis=1, inplace=True)
#    1857 else:
#    1858     # Handle dropping column levels
#    1859     if levels_to_drop:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4630, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4627     new_axis = axis.take(indexer)
#    4629 bm_axis = self.ndim - axis_num - 1
# -> 4630 new_mgr = self._mgr.reindex_indexer(
#    4631     new_axis,
#    4632     indexer,
#    4633     axis=bm_axis,
#    4634     allow_dups=True,
#    4635     copy=None,
#    4636     only_slice=only_slice,
#    4637 )
#    4638 result = self._constructor(new_mgr)
#    4639 if self.ndim == 1:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:740, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     737     raise IndexError("Requested axis not found in manager")
#     739 if axis == 0:
# --> 740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#    (...)
#     755         for blk in self.blocks
#     756     ]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:898, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     896                     blocks.append(nb)
#     897             else:
# --> 898                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     899                 blocks.append(nb)
#     901 return blocks
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/array_algos/take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
